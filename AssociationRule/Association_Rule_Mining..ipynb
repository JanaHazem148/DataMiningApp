# %% [markdown]
# # Transaction Data Cleaning, Preprocessing, and Association Rule Mining
#
# ## Overview
# This notebook provides a complete solution for:
# 1. **Loading messy transaction data**
# 2. **Cleaning and preprocessing** multiple data quality issues
# 3. **Performing association rule mining** to discover patterns
# 4. **Visualizing and interpreting results**
#
# ---

# %% [markdown]
# ## STEP 1: Import Required Libraries
#
# **Explanation:** We need these libraries for data manipulation, analysis, and association rule mining.
#
# **Libraries used:**
# - `pandas`: Data manipulation and analysis
# - `numpy`: Numerical operations
# - `datetime`: Date parsing and standardization
# - `mlxtend`: Association rule mining (Apriori algorithm)
# - `re`: Regular expressions for text cleaning

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import re
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ---
# ## STEP 2: Load the Raw Data
#
# **Explanation:** Load the CSV file to examine the original messy data with all its issues.
#
# **What to look for:**
# - Missing values
# - Duplicate transactions
# - Inconsistent formats
# - Data type issues

# %%
# Load the data
df_raw = pd.read_csv('unclean_movie_transactions_data.csv', on_bad_lines='skip')

print(f"✓ Data loaded successfully!")
print(f"✓ Total rows: {len(df_raw)}")
print(f"✓ Total columns: {len(df_raw.columns)}")
print("\n" + "="*100)
# Out:
# ✓ Data loaded successfully!
# ✓ Total rows: 64
# ✓ Total columns: 11
#
# ====================================================================================================

# %%
# Display the complete raw dataset
print("COMPLETE RAW DATA:")
print("="*100)
print(df_raw.to_string())
# Out:
# COMPLETE RAW DATA:
# ====================================================================================================
#    transaction_id         date      customer_name                     movie_title ticket_type  ticket_quantity  ticket_price                   concession_items  concession_total payment_method  total_amount
# 0          TXN001   2024-01-15         John Smith                  Dune: Part Two       ADULT                2          15.5                 Popcorn,Soda,Candy             28.50    Credit Card         59.50
# 1          TXN002   01/15/2024      Sarah Johnson                  Dune: Part Two       adult                2          15.5                 popcorn;soda;candy             28.50    Credit Card         59.50
# 2          TXN003          NaN      Michael Brown                      The Batman      Senior                1          12.0                   Popcorn, , ,Soda             15.75           Cash           NaN
# 3          TXN004   2024-01-16        Emily Davis                     Oppenheimer     STUDENT                3          13.0               Nachos;Pretzel;Water             22.00     Debit Card         61.00
# 4          TXN001   2024-01-15         John Smith                  Dune: Part Two       ADULT                2          15.5                 Popcorn,Soda,Candy             28.50    Credit Card         59.50
# 5          TXN005   16-01-2024      Robert Wilson                          Barbie       Adult                4           NaN         Hot Dog;Popcorn;Soda;Candy             45.25    Credit Card        107.25
# 6          TXN006   2024/01/17       Jennifer Lee                     Poor Things       adult                2          15.5                Popcorn,, , , ,Soda             18.00           Cash         49.00
# 7          TXN007   01-17-2024     David Martinez      Killers of the Flower Moon       CHILD                2          10.0                      Candy;Popcorn             12.50    Credit Card         32.50
# 8          TXN008   2024-01-17      Lisa Anderson                   THE HOLDOVERS      Senior                1          12.0                                NaN              0.00           Cash         12.00
# 9          TXN009          NaN       James Taylor                   The Holdovers      SENIOR                1          12.0                      Water,Pretzel              8.50     Debit Card         20.50
# 10         TXN010   2024-01-18        Mary Thomas                        Napoleon       Adult                3          15.5            Popcorn;Soda; ; ;Nachos             38.75    Credit Card         85.25
# 11         TXN004   2024-01-16        Emily Davis                     Oppenheimer     STUDENT                3          13.0               Nachos;Pretzel;Water             22.00     Debit Card         61.00
# 12         TXN011   18/01/2024  Christopher Moore                           Wonka       CHILD                4          10.0                Candy,Popcorn,Soda,             35.00           Cash         75.00
# 13         TXN012   2024-01-19     Amanda Jackson              godzilla minus one       adult                2           NaN                       Hot Dog,Soda             16.50    Credit Card           NaN
# 14         TXN013   19-01-2024      Matthew White                The Color Purple     Student                2          13.0            Popcorn; ; ;Candy;Water             24.00     Debit Card         50.00
# 15         TXN014          NaN      Daniel Harris                         Ferrari       ADULT                1          15.5                        Nachos,Soda             18.25           Cash         33.75
# 16         TXN015   2024/01/20     Jessica Martin                American Fiction       adult                3          15.5                ,Popcorn,Soda,Candy             32.00    Credit Card         78.50
# 17         TXN016   20-01-2024      Paul Thompson                      MEAN GIRLS       Adult                2          15.5                    Pretzel;Water;              14.75     Debit Card         45.75
# 18         TXN017   2024-01-20       Karen Garcia                      Mean Girls       ADULT                2          15.5                     pretzel,water,             14.75     Debit Card         45.75
# 19         TXN018   01/21/2024   Steven Rodriguez                   The Beekeeper      Senior                1          12.0              Popcorn,, ,Soda,Candy             21.50            NaN         33.50
# 20         TXN019    2024/1/22     Laura Martinez                       migration       Child                3          10.0                 Candy;Popcorn;Soda             27.00           Cash         57.00
# 21         TXN020   2024-01-22          Kevin Lee    Aquaman and the Lost Kingdom     student                2          13.0               Hot Dog;,Nachos;Soda             25.50    Credit Card         51.50
# 22         TXN021   22/01/2024       Nancy Walker                   The Iron Claw       ADULT                1           NaN                      Popcorn,Water             13.25           Cash           NaN
# 23         TXN015   2024/01/20     Jessica Martin                American Fiction       adult                3          15.5                ,Popcorn,Soda,Candy             32.00    Credit Card         78.50
# 24         TXN022   2024-01-23         Brian Hall                  anyone but you       Adult                2          15.5               Soda, ,Candy,Popcorn             29.00     Debit Card         60.00
# 25         TXN023    23/1/2024      Rebecca Allen                  Anyone But You       ADULT                2          15.5                 soda;candy;popcorn             29.00     Debit Card           NaN
# 26         TXN024   23-01-2024       George Young                         Maestro      Senior                1          12.0                                NaN              0.00           Cash         12.00
# 27         TXN025   2024/01/24      Michelle King             Society of the Snow       adult                4          15.5        Popcorn;Soda;Hot Dog;Nachos             52.00    Credit Card        114.00
# 28         TXN026   24-01-2024     Charles Wright                      NIGHT SWIM       Child                3          10.0                    Candy, ,Popcorn             18.75           Cash         48.75
# 29         TXN027   2024-01-25    Elizabeth Lopez                      Night Swim       CHILD                3          10.0                      candy;popcorn             18.75           Cash         48.75
# 30         TXN028          NaN       William Hill                        Saltburn     Student                1          13.0             Pretzel;Water; ; ;Soda             17.25     Debit Card         30.25
# 31         TXN029   25/01/2024      Barbara Scott            The Zone of Interest       ADULT                2           NaN                      ,Popcorn,Soda             19.50    Credit Card           NaN
# 32         TXN030   2024-01-26      Richard Green             all of us strangers       adult                1          15.5                    Hot Dog,Nachos,             20.00           Cash         35.50
# 33         TXN031    26-1-2024       Thomas Baker    The Hunger Games: The Ballad       ADULT                3          15.5          Popcorn;Soda;Candy;Nachos             42.00    credit card         88.50
# 34         TXN033     27/01/24    Donald Campbell                            WISH       child                4          10.0             candy, , ,popcorn,soda             33.00     Debit card         73.00
# 35         TXN034    2024-1-28  Patricia Mitchell                            Wish       CHILD                4          10.0                 Candy;Popcorn;Soda             33.00     Debit Card         73.00
# 36         TXN035     01-28-24       Mark Roberts           The Boy and the Heron       Adult                2          15.5            Hot Dog, ,Nachos, ,Soda             28.75    CREDIT CARD         59.75
# 37         TXN036   28/01/2024     Carol Phillips           THE BOY AND THE HERON       adult                2          15.5                hot dog;nachos;soda             28.75    Credit Card         59.75
# 38         TXN037          NaN       Betty Turner                           Wonka     Student                1          13.0                       , , ,Popcorn              5.50           cash         18.50
# 39         TXN038   2024-01-29      Jeffrey Evans    AQUAMAN AND THE LOST KINGDOM      SENIOR                1          12.0                         Candy,Soda             11.00           Cash         23.00
# 40         TXN031    26-1-2024       Thomas Baker    The Hunger Games: The Ballad       ADULT                3          15.5          Popcorn;Soda;Candy;Nachos             42.00    credit card         88.50
# 41         TXN039   29-01-2024    Dorothy Collins                       Freelance       adult                2           NaN         Popcorn,Hot Dog,Soda,Candy             36.50     Debit Card           NaN
# 42         TXN040    2024/1/30      Jason Stewart  Renaissance: A Film By Beyoncé       Adult                3          15.5              Nachos; ; ;Soda;Water             23.25    Credit Card         69.75
# 43         TXN041   30/01/2024       Helen Morris     taylor swift: the eras tour       ADULT                4          15.5             , ,Popcorn,Candy,Soda,             39.00    credit card        101.00
# 44         TXN042   2024-01-31        Gary Rogers     Taylor Swift: The Eras Tour       adult                4          15.5                 popcorn;candy;soda             39.00    Credit Card        101.00
# 45         TXN043    31-1-2024       Shirley Reed                            Nyad      Senior                1          12.0                    Water, ,Pretzel              8.25           Cash         20.25
# 46         TXN044   2024/01/31         Larry Cook                          MEMORY     Student                2          13.0             Hot Dog;Popcorn; ;Soda             24.50     Debit Card         50.50
# 47         TXN045     01/31/24     Deborah Bailey                          Memory     student                2          13.0               hot dog,popcorn,soda             24.50     debit card         50.50
# 48         TXN046   Feb 1 2024     Gregory Cooper                             Leo       CHILD                3           NaN              , ,Candy,Popcorn,Soda             29.25           Cash           NaN
# 49         TXN047   2024-02-01    Ruth Richardson                             leo       Child                3          10.0                 candy;popcorn;soda             29.25           CASH         59.25
# 50         TXN048   01-02-2024          Frank Cox                     The Marvels       adult                2          15.5              Nachos,Soda, , ,Candy             27.00    Credit Card         58.00
# 51         TXN049   2024.02.02       Maria Howard                     THE MARVELS       ADULT                2          15.5                  nachos;soda;candy             27.00    credit card         58.00
# 52         TXN050          NaN         Aaron Ward            Trolls Band Together       CHILD                5          10.0  Popcorn,Candy,Soda,Hot Dog,Nachos             48.00           Cash         98.00
# 53         TXN051     2-2-2024        Judy Torres            trolls band together       child                5          10.0  popcorn;candy;soda;hot dog;nachos             48.00           cash         98.00
# 54         TXN052   02/02/2024     Henry Peterson                  Next Goal Wins       Adult                1          15.5                       , , , ,Water              3.50     Debit Card         19.00
# 55         TXN053   2024-02-03        Pamela Gray                  next goal wins       ADULT                1           NaN                              water              3.50     Debit card           NaN
# 56         TXN054     3/2/2024     Walter Ramirez                       The Shift      Senior                2          12.0               Pretzel;Soda; ;Candy             19.75           Cash         43.75
# 57         TXN055     2024-2-4     Virginia James                    Silent Night     student                1          13.0           Popcorn, , , ,Soda,Candy             18.00    Credit Card         31.00
# 58         TXN056  04-Feb-2024      Arthur Watson                    SILENT NIGHT     Student                1          13.0                 popcorn;soda;candy             18.00    credit card         31.00
# 59         TXN057   2024/02/05      Teresa Brooks                             NaN       Adult                2          15.5                Hot Dog,Nachos,Soda             28.00     Debit Card         59.00
# 60         TXN058          NaN        Ralph Kelly                  Ricky Stanicky       ADULT                3          15.5                   , ,Popcorn,Candy             24.50           Cash         71.00
# 61         TXN059   05-02-2024    Frances Sanders                  ricky stanicky       adult                3           NaN                      popcorn;candy             24.50           cash           NaN
# 62         TXN060   2024-02-06          Roy Price                  The Bricklayer      Senior                1          12.0                  Water, , ,Pretzel              8.00     Debit Card         20.00
# 63         TXN042   2024-01-31        Gary Rogers     Taylor Swift: The Eras Tour       adult                4          15.5                 popcorn;candy;soda             39.00    Credit Card        101.00

# %%
# Show data types and missing values
print("DATA TYPES:")
print("="*100)
print(df_raw.dtypes)
print("\n" + "="*100)
print("MISSING VALUES SUMMARY:")
print("="*100)
print(df_raw.isnull().sum())
# Out:
# DATA TYPES:
# ====================================================================================================
# transaction_id       object
# date                 object
# customer_name        object
# movie_title          object
# ticket_type          object
# ticket_quantity       int64
# ticket_price        float64
# concession_items     object
# concession_total    float64
# payment_method       object
# total_amount        float64
# dtype: object
#
# ====================================================================================================
# MISSING VALUES SUMMARY:
# ====================================================================================================
# transaction_id      0
# date                7
# customer_name       0
# movie_title         1
# ticket_type         0
# ticket_quantity     0
# ticket_price        8
# concession_items    2
# concession_total    0
# payment_method      1
# total_amount        9
# dtype: int64

# %% [markdown]
# ---
# ## STEP 3: Remove Duplicate Transactions
#
# **Explanation:** Duplicate transaction IDs indicate the same transaction recorded multiple times. This can skew our analysis by:
# - Inflating sales numbers
# - Creating false patterns in association rules
# - Distorting customer behavior analysis
#
# **Solution:** Keep only the first occurrence of each transaction ID.

# %%
# Identify duplicates
print("IDENTIFYING DUPLICATE TRANSACTIONS:")
print("="*100)

duplicates = df_raw[df_raw.duplicated(subset=['transaction_id'], keep=False)]
print(f"Found {len(duplicates)} duplicate records across {duplicates['transaction_id'].nunique()} transaction IDs:")
print("\n")
print(duplicates[['transaction_id', 'date', 'customer_name', 'movie_title', 'total_amount']].to_string())
# Out:
# IDENTIFYING DUPLICATE TRANSACTIONS:
# ====================================================================================================
# Found 10 duplicate records across 5 transaction IDs:
#
#
#    transaction_id        date   customer_name                   movie_title  total_amount
# 0          TXN001  2024-01-15      John Smith                Dune: Part Two          59.5
# 3          TXN004  2024-01-16     Emily Davis                   Oppenheimer          61.0
# 4          TXN001  2024-01-15      John Smith                Dune: Part Two          59.5
# 11         TXN004  2024-01-16     Emily Davis                   Oppenheimer          61.0
# 16         TXN015  2024/01/20  Jessica Martin              American Fiction          78.5
# 23         TXN015  2024/01/20  Jessica Martin              American Fiction          78.5
# 33         TXN031   26-1-2024    Thomas Baker  The Hunger Games: The Ballad          88.5
# 40         TXN031   26-1-2024    Thomas Baker  The Hunger Games: The Ballad          88.5
# 44         TXN042  2024-01-31     Gary Rogers   Taylor Swift: The Eras Tour         101.0
# 63         TXN042  2024-01-31     Gary Rogers   Taylor Swift: The Eras Tour         101.0

# %%
# Remove duplicates
df_step3 = df_raw.drop_duplicates(subset=['transaction_id'], keep='first')

print("DUPLICATE REMOVAL RESULTS:")
print("="*100)
print(f"✓ Removed {len(df_raw) - len(df_step3)} duplicate transactions")
print(f"✓ Rows before: {len(df_raw)}")
print(f"✓ Rows after: {len(df_step3)}")
# Out:
# DUPLICATE REMOVAL RESULTS:
# ====================================================================================================
# ✓ Removed 5 duplicate transactions
# ✓ Rows before: 64
# ✓ Rows after: 59

# %%
# Display complete data after removing duplicates
print("COMPLETE DATA AFTER REMOVING DUPLICATES:")
print("="*100)
print(df_step3.to_string())
# Out:
# COMPLETE DATA AFTER REMOVING DUPLICATES:
# ====================================================================================================
#    transaction_id         date      customer_name                     movie_title ticket_type  ticket_quantity  ticket_price                   concession_items  concession_total payment_method  total_amount
# 0          TXN001   2024-01-15         John Smith                  Dune: Part Two       ADULT                2          15.5                 Popcorn,Soda,Candy             28.50    Credit Card         59.50
# 1          TXN002   01/15/2024      Sarah Johnson                  Dune: Part Two       adult                2          15.5                 popcorn;soda;candy             28.50    Credit Card         59.50
# 2          TXN003          NaN      Michael Brown                      The Batman      Senior                1          12.0                   Popcorn, , ,Soda             15.75           Cash           NaN
# 3          TXN004   2024-01-16        Emily Davis                     Oppenheimer     STUDENT                3          13.0               Nachos;Pretzel;Water             22.00     Debit Card         61.00
# 5          TXN005   16-01-2024      Robert Wilson                          Barbie       Adult                4           NaN         Hot Dog;Popcorn;Soda;Candy             45.25    Credit Card        107.25
# 6          TXN006   2024/01/17       Jennifer Lee                     Poor Things       adult                2          15.5                Popcorn,, , , ,Soda             18.00           Cash         49.00
# 7          TXN007   01-17-2024     David Martinez      Killers of the Flower Moon       CHILD                2          10.0                      Candy;Popcorn             12.50    Credit Card         32.50
# 8          TXN008   2024-01-17      Lisa Anderson                   THE HOLDOVERS      Senior                1          12.0                                NaN              0.00           Cash         12.00
# 9          TXN009          NaN       James Taylor                   The Holdovers      SENIOR                1          12.0                      Water,Pretzel              8.50     Debit Card         20.50
# 10         TXN010   2024-01-18        Mary Thomas                        Napoleon       Adult                3          15.5            Popcorn;Soda; ; ;Nachos             38.75    Credit Card         85.25
# 12         TXN011   18/01/2024  Christopher Moore                           Wonka       CHILD                4          10.0                Candy,Popcorn,Soda,             35.00           Cash         75.00
# 13         TXN012   2024-01-19     Amanda Jackson              godzilla minus one       adult                2           NaN                       Hot Dog,Soda             16.50    Credit Card           NaN
# 14         TXN013   19-01-2024      Matthew White                The Color Purple     Student                2          13.0            Popcorn; ; ;Candy;Water             24.00     Debit Card         50.00
# 15         TXN014          NaN      Daniel Harris                         Ferrari       ADULT                1          15.5                        Nachos,Soda             18.25           Cash         33.75
# 16         TXN015   2024/01/20     Jessica Martin                American Fiction       adult                3          15.5                ,Popcorn,Soda,Candy             32.00    Credit Card         78.50
# 17         TXN016   20-01-2024      Paul Thompson                      MEAN GIRLS       Adult                2          15.5                    Pretzel;Water;              14.75     Debit Card         45.75
# 18         TXN017   2024-01-20       Karen Garcia                      Mean Girls       ADULT                2          15.5                     pretzel,water,             14.75     Debit Card         45.75
# 19         TXN018   01/21/2024   Steven Rodriguez                   The Beekeeper      Senior                1          12.0              Popcorn,, ,Soda,Candy             21.50            NaN         33.50
# 20         TXN019    2024/1/22     Laura Martinez                       migration       Child                3          10.0                 Candy;Popcorn;Soda             27.00           Cash         57.00
# 21         TXN020   2024-01-22          Kevin Lee    Aquaman and the Lost Kingdom     student                2          13.0               Hot Dog;,Nachos;Soda             25.50    Credit Card         51.50
# 22         TXN021   22/01/2024       Nancy Walker                   The Iron Claw       ADULT                1           NaN                      Popcorn,Water             13.25           Cash           NaN
# 24         TXN022   2024-01-23         Brian Hall                  anyone but you       Adult                2          15.5               Soda, ,Candy,Popcorn             29.00     Debit Card         60.00
# 25         TXN023    23/1/2024      Rebecca Allen                  Anyone But You       ADULT                2          15.5                 soda;candy;popcorn             29.00     Debit Card           NaN
# 26         TXN024   23-01-2024       George Young                         Maestro      Senior                1          12.0                                NaN              0.00           Cash         12.00
# 27         TXN025   2024/01/24      Michelle King             Society of the Snow       adult                4          15.5        Popcorn;Soda;Hot Dog;Nachos             52.00    Credit Card        114.00
# 28         TXN026   24-01-2024     Charles Wright                      NIGHT SWIM       Child                3          10.0                    Candy, ,Popcorn             18.75           Cash         48.75
# 29         TXN027   2024-01-25    Elizabeth Lopez                      Night Swim       CHILD                3          10.0                      candy;popcorn             18.75           Cash         48.75
# 30         TXN028          NaN       William Hill                        Saltburn     Student                1          13.0             Pretzel;Water; ; ;Soda             17.25     Debit Card         30.25
# 31         TXN029   25/01/2024      Barbara Scott            The Zone of Interest       ADULT                2           NaN                      ,Popcorn,Soda             19.50    Credit Card           NaN
# 32         TXN030   2024-01-26      Richard Green             all of us strangers       adult                1          15.5                    Hot Dog,Nachos,             20.00           Cash         35.50
# 33         TXN031    26-1-2024       Thomas Baker    The Hunger Games: The Ballad       ADULT                3          15.5          Popcorn;Soda;Candy;Nachos             42.00    credit card         88.50
# 34         TXN033     27/01/24    Donald Campbell                            WISH       child                4          10.0             candy, , ,popcorn,soda             33.00     Debit card         73.00
# 35         TXN034    2024-1-28  Patricia Mitchell                            Wish       CHILD                4          10.0                 Candy;Popcorn;Soda             33.00     Debit Card         73.00
# 36         TXN035     01-28-24       Mark Roberts           The Boy and the Heron       Adult                2          15.5            Hot Dog, ,Nachos, ,Soda             28.75    CREDIT CARD         59.75
# 37         TXN036   28/01/2024     Carol Phillips           THE BOY AND THE HERON       adult                2          15.5                hot dog;nachos;soda             28.75    Credit Card         59.75
# 38         TXN037          NaN       Betty Turner                           Wonka     Student                1          13.0                       , , ,Popcorn              5.50           cash         18.50
# 39         TXN038   2024-01-29      Jeffrey Evans    AQUAMAN AND THE LOST KINGDOM      SENIOR                1          12.0                         Candy,Soda             11.00           Cash         23.00
# 41         TXN039   29-01-2024    Dorothy Collins                       Freelance       adult                2           NaN         Popcorn,Hot Dog,Soda,Candy             36.50     Debit Card           NaN
# 42         TXN040    2024/1/30      Jason Stewart  Renaissance: A Film By Beyoncé       Adult                3          15.5              Nachos; ; ;Soda;Water             23.25    Credit Card         69.75
# 43         TXN041   30/01/2024       Helen Morris     taylor swift: the eras tour       ADULT                4          15.5             , ,Popcorn,Candy,Soda,             39.00    credit card        101.00
# 44         TXN042   2024-01-31        Gary Rogers     Taylor Swift: The Eras Tour       adult                4          15.5                 popcorn;candy;soda             39.00    Credit Card        101.00
# 45         TXN043    31-1-2024       Shirley Reed                            Nyad      Senior                1          12.0                    Water, ,Pretzel              8.25           Cash         20.25
# 46         TXN044   2024/01/31         Larry Cook                          MEMORY     Student                2          13.0             Hot Dog;Popcorn; ;Soda             24.50     Debit Card         50.50
# 47         TXN045     01/31/24     Deborah Bailey                          Memory     student                2          13.0               hot dog,popcorn,soda             24.50     debit card         50.50
# 48         TXN046   Feb 1 2024     Gregory Cooper                             Leo       CHILD                3           NaN              , ,Candy,Popcorn,Soda             29.25           Cash           NaN
# 49         TXN047   2024-02-01    Ruth Richardson                             leo       Child                3          10.0                 candy;popcorn;soda             29.25           CASH         59.25
# 50         TXN048   01-02-2024          Frank Cox                     The Marvels       adult                2          15.5              Nachos,Soda, , ,Candy             27.00    Credit Card         58.00
# 51         TXN049   2024.02.02       Maria Howard                     THE MARVELS       ADULT                2          15.5                  nachos;soda;candy             27.00    credit card         58.00
# 52         TXN050          NaN         Aaron Ward            Trolls Band Together       CHILD                5          10.0  Popcorn,Candy,Soda,Hot Dog,Nachos             48.00           Cash         98.00
# 53         TXN051     2-2-2024        Judy Torres            trolls band together       child                5          10.0  popcorn;candy;soda;hot dog;nachos             48.00           cash         98.00
# 54         TXN052   02/02/2024     Henry Peterson                  Next Goal Wins       Adult                1          15.5                       , , , ,Water              3.50     Debit Card         19.00
# 55         TXN053   2024-02-03        Pamela Gray                  next goal wins       ADULT                1           NaN                              water              3.50     Debit card           NaN
# 56         TXN054     3/2/2024     Walter Ramirez                       The Shift      Senior                2          12.0               Pretzel;Soda; ;Candy             19.75           Cash         43.75
# 57         TXN055     2024-2-4     Virginia James                    Silent Night     student                1          13.0           Popcorn, , , ,Soda,Candy             18.00    Credit Card         31.00
# 58         TXN056  04-Feb-2024      Arthur Watson                    SILENT NIGHT     Student                1          13.0                 popcorn;soda;candy             18.00    credit card         31.00
# 59         TXN057   2024/02/05      Teresa Brooks                             NaN       Adult                2          15.5                Hot Dog,Nachos,Soda             28.00     Debit Card         59.00
# 60         TXN058          NaN        Ralph Kelly                  Ricky Stanicky       ADULT                3          15.5                   , ,Popcorn,Candy             24.50           Cash         71.00
# 61         TXN059   05-02-2024    Frances Sanders                  ricky stanicky       adult                3           NaN                      popcorn;candy             24.50           cash           NaN
# 62         TXN060   2024-02-06          Roy Price                  The Bricklayer      Senior                1          12.0                  Water, , ,Pretzel              8.00     Debit Card         20.00

# %% [markdown]
# ---
# ## STEP 4: Standardize Date Formats
#
# **Explanation:** Dates come in many different formats:
# - `2024-01-15` (ISO format)
# - `01/15/2024` (US format)
# - `16-01-2024` (European format)
# - `Feb 1 2024` (Text format)
# - And many more...
#
# **Problem:** Inconsistent date formats make it impossible to:
# - Sort transactions chronologically
# - Analyze trends over time
# - Filter by date range
#
# **Solution:** Parse all formats and convert to standard format: `YYYY-MM-DD`

# %%
# Show original date formats
print("ORIGINAL DATE FORMATS (Sample):")
print("="*100)
print(df_step3[['transaction_id', 'date']].head(20).to_string())
# Out:
# ORIGINAL DATE FORMATS (Sample):
# ====================================================================================================
#    transaction_id        date
# 0          TXN001  2024-01-15
# 1          TXN002  01/15/2024
# 2          TXN003         NaN
# 3          TXN004  2024-01-16
# 5          TXN005  16-01-2024
# 6          TXN006  2024/01/17
# 7          TXN007  01-17-2024
# 8          TXN008  2024-01-17
# 9          TXN009         NaN
# 10         TXN010  2024-01-18
# 12         TXN011  18/01/2024
# 13         TXN012  2024-01-19
# 14         TXN013  19-01-2024
# 15         TXN014         NaN
# 16         TXN015  2024/01/20
# 17         TXN016  20-01-2024
# 18         TXN017  2024-01-20
# 19         TXN018  01/21/2024
# 20         TXN019   2024/1/22
# 21         TXN020  2024-01-22

# %%
# Define date parsing function
def parse_date(date_str):
    """
    Parse multiple date formats and return standardized date
    """
    if pd.isna(date_str) or date_str == '' or str(date_str).lower() in ['n/a', 'null', 'none']:
        return None
    
    date_str = str(date_str).strip()
    
    # List of possible date formats
    date_formats = [
        '%Y-%m-%d',      # 2024-01-15
        '%m/%d/%Y',      # 01/15/2024
        '%d-%m-%Y',      # 16-01-2024
        '%Y/%m/%d',      # 2024/01/17
        '%d/%m/%Y',      # 17/01/2024
        '%Y/%m/%d',      # 2024/1/22
        '%d/%m/%Y',      # 23/1/2024
        '%Y.%m.%d',      # 2024.01.27
        '%d/%m/%y',      # 27/01/24
        '%m-%d-%y',      # 01-28-24
        '%d-%m-%Y',      # 23-01-2024
        '%Y-%m-%d',      # 2024-1-28
        '%d-%m-%y',      # 26-1-2024
        '%b %d %Y',      # Feb 1 2024
        '%d-%b-%Y',      # 04-Feb-2024
        '%d/%m/%Y',      # 3/2/2024
    ]
    
    for fmt in date_formats:
        try:
            return pd.to_datetime(date_str, format=fmt).strftime('%Y-%m-%d')
        except:
            continue
    
    return None

print("✓ Date parsing function defined")
# Out:
# ✓ Date parsing function defined

# %%
# Apply date standardization
df_step4 = df_step3.copy()
df_step4['date'] = df_step4['date'].apply(parse_date)
df_step4['date'] = pd.to_datetime(df_step4['date'], errors='coerce')

print("DATE STANDARDIZATION RESULTS:")
print("="*100)
print(f"✓ Dates standardized to YYYY-MM-DD format")
print(f"✓ Valid dates: {df_step4['date'].notna().sum()}")
print(f"✓ Missing dates: {df_step4['date'].isna().sum()}")
# Out:
# DATE STANDARDIZATION RESULTS:
# ====================================================================================================
# ✓ Dates standardized to YYYY-MM-DD format
# ✓ Valid dates: 50
# ✓ Missing dates: 9

# %%
# Display complete data with standardized dates
print("COMPLETE DATA AFTER DATE STANDARDIZATION:")
print("="*100)
print(df_step4.to_string())
# Out:
# COMPLETE DATA AFTER DATE STANDARDIZATION:
# ====================================================================================================
#    transaction_id       date      customer_name                     movie_title ticket_type  ticket_quantity  ticket_price                   concession_items  concession_total payment_method  total_amount
# 0          TXN001 2024-01-15         John Smith                  Dune: Part Two       ADULT                2          15.5                 Popcorn,Soda,Candy             28.50    Credit Card         59.50
# 1          TXN002 2024-01-15      Sarah Johnson                  Dune: Part Two       adult                2          15.5                 popcorn;soda;candy             28.50    Credit Card         59.50
# 2          TXN003        NaT      Michael Brown                      The Batman      Senior                1          12.0                   Popcorn, , ,Soda             15.75           Cash           NaN
# 3          TXN004 2024-01-16        Emily Davis                     Oppenheimer     STUDENT                3          13.0               Nachos;Pretzel;Water             22.00     Debit Card         61.00
# 5          TXN005 2024-01-16      Robert Wilson                          Barbie       Adult                4           NaN         Hot Dog;Popcorn;Soda;Candy             45.25    Credit Card        107.25
# 6          TXN006 2024-01-17       Jennifer Lee                     Poor Things       adult                2          15.5                Popcorn,, , , ,Soda             18.00           Cash         49.00
# 7          TXN007        NaT     David Martinez      Killers of the Flower Moon       CHILD                2          10.0                      Candy;Popcorn             12.50    Credit Card         32.50
# 8          TXN008 2024-01-17      Lisa Anderson                   THE HOLDOVERS      Senior                1          12.0                                NaN              0.00           Cash         12.00
# 9          TXN009        NaT       James Taylor                   The Holdovers      SENIOR                1          12.0                      Water,Pretzel              8.50     Debit Card         20.50
# 10         TXN010 2024-01-18        Mary Thomas                        Napoleon       Adult                3          15.5            Popcorn;Soda; ; ;Nachos             38.75    Credit Card         85.25
# 12         TXN011 2024-01-18  Christopher Moore                           Wonka       CHILD                4          10.0                Candy,Popcorn,Soda,             35.00           Cash         75.00
# 13         TXN012 2024-01-19     Amanda Jackson              godzilla minus one       adult                2           NaN                       Hot Dog,Soda             16.50    Credit Card           NaN
# 14         TXN013 2024-01-19      Matthew White                The Color Purple     Student                2          13.0            Popcorn; ; ;Candy;Water             24.00     Debit Card         50.00
# 15         TXN014        NaT      Daniel Harris                         Ferrari       ADULT                1          15.5                        Nachos,Soda             18.25           Cash         33.75
# 16         TXN015 2024-01-20     Jessica Martin                American Fiction       adult                3          15.5                ,Popcorn,Soda,Candy             32.00    Credit Card         78.50
# 17         TXN016 2024-01-20      Paul Thompson                      MEAN GIRLS       Adult                2          15.5                    Pretzel;Water;              14.75     Debit Card         45.75
# 18         TXN017 2024-01-20       Karen Garcia                      Mean Girls       ADULT                2          15.5                     pretzel,water,             14.75     Debit Card         45.75
# 19         TXN018 2024-01-21   Steven Rodriguez                   The Beekeeper      Senior                1          12.0              Popcorn,, ,Soda,Candy             21.50            NaN         33.50
# 20         TXN019 2024-01-22     Laura Martinez                       migration       Child                3          10.0                 Candy;Popcorn;Soda             27.00           Cash         57.00
# 21         TXN020 2024-01-22          Kevin Lee    Aquaman and the Lost Kingdom     student                2          13.0               Hot Dog;,Nachos;Soda             25.50    Credit Card         51.50
# 22         TXN021 2024-01-22       Nancy Walker                   The Iron Claw       ADULT                1           NaN                      Popcorn,Water             13.25           Cash           NaN
# 24         TXN022 2024-01-23         Brian Hall                  anyone but you       Adult                2          15.5               Soda, ,Candy,Popcorn             29.00     Debit Card         60.00
# 25         TXN023 2024-01-23      Rebecca Allen                  Anyone But You       ADULT                2          15.5                 soda;candy;popcorn             29.00     Debit Card           NaN
# 26         TXN024 2024-01-23       George Young                         Maestro      Senior                1          12.0                                NaN              0.00           Cash         12.00
# 27         TXN025 2024-01-24      Michelle King             Society of the Snow       adult                4          15.5        Popcorn;Soda;Hot Dog;Nachos             52.00    Credit Card        114.00
# 28         TXN026 2024-01-24     Charles Wright                      NIGHT SWIM       Child                3          10.0                    Candy, ,Popcorn             18.75           Cash         48.75
# 29         TXN027 2024-01-25    Elizabeth Lopez                      Night Swim       CHILD                3          10.0                      candy;popcorn             18.75           Cash         48.75
# 30         TXN028        NaT       William Hill                        Saltburn     Student                1          13.0             Pretzel;Water; ; ;Soda             17.25     Debit Card         30.25
# 31         TXN029 2024-01-25      Barbara Scott            The Zone of Interest       ADULT                2           NaN                      ,Popcorn,Soda             19.50    Credit Card           NaN
# 32         TXN030 2024-01-26      Richard Green             all of us strangers       adult                1          15.5                    Hot Dog,Nachos,             20.00           Cash         35.50
# 33         TXN031 2024-01-26       Thomas Baker    The Hunger Games: The Ballad       ADULT                3          15.5          Popcorn;Soda;Candy;Nachos             42.00    credit card         88.50
# 34         TXN033 2024-01-27    Donald Campbell                            WISH       child                4          10.0             candy, , ,popcorn,soda             33.00     Debit card         73.00
# 35         TXN034 2024-01-28  Patricia Mitchell                            Wish       CHILD                4          10.0                 Candy;Popcorn;Soda             33.00     Debit Card         73.00
# 36         TXN035 2024-01-28       Mark Roberts           The Boy and the Heron       Adult                2          15.5            Hot Dog, ,Nachos, ,Soda             28.75    CREDIT CARD         59.75
# 37         TXN036 2024-01-28     Carol Phillips           THE BOY AND THE HERON       adult                2          15.5                hot dog;nachos;soda             28.75    Credit Card         59.75
# 38         TXN037        NaT       Betty Turner                           Wonka     Student                1          13.0                       , , ,Popcorn              5.50           cash         18.50
# 39         TXN038 2024-01-29      Jeffrey Evans    AQUAMAN AND THE LOST KINGDOM      SENIOR                1          12.0                         Candy,Soda             11.00           Cash         23.00
# 41         TXN039 2024-01-29    Dorothy Collins                       Freelance       adult                2           NaN         Popcorn,Hot Dog,Soda,Candy             36.50     Debit Card           NaN
# 42         TXN040 2024-01-30      Jason Stewart  Renaissance: A Film By Beyoncé       Adult                3          15.5              Nachos; ; ;Soda;Water             23.25    Credit Card         69.75
# 43         TXN041 2024-01-30       Helen Morris     taylor swift: the eras tour       ADULT                4          15.5             , ,Popcorn,Candy,Soda,             39.00    credit card        101.00
# 44         TXN042 2024-01-31        Gary Rogers     Taylor Swift: The Eras Tour       adult                4          15.5                 popcorn;candy;soda             39.00    Credit Card        101.00
# 45         TXN043 2024-01-31       Shirley Reed                            Nyad      Senior                1          12.0                    Water, ,Pretzel              8.25           Cash         20.25
# 46         TXN044 2024-01-31         Larry Cook                          MEMORY     Student                2          13.0             Hot Dog;Popcorn; ;Soda             24.50     Debit Card         50.50
# 47         TXN045        NaT     Deborah Bailey                          Memory     student                2          13.0               hot dog,popcorn,soda             24.50     debit card         50.50
# 48         TXN046 2024-02-01     Gregory Cooper                             Leo       CHILD                3           NaN              , ,Candy,Popcorn,Soda             29.25           Cash           NaN
# 49         TXN047 2024-02-01    Ruth Richardson                             leo       Child                3          10.0                 candy;popcorn;soda             29.25           CASH         59.25
# 50         TXN048 2024-02-01          Frank Cox                     The Marvels       adult                2          15.5              Nachos,Soda, , ,Candy             27.00    Credit Card         58.00
# 51         TXN049 2024-02-02       Maria Howard                     THE MARVELS       ADULT                2          15.5                  nachos;soda;candy             27.00    credit card         58.00
# 52         TXN050        NaT         Aaron Ward            Trolls Band Together       CHILD                5          10.0  Popcorn,Candy,Soda,Hot Dog,Nachos             48.00           Cash         98.00
# 53         TXN051 2024-02-02        Judy Torres            trolls band together       child                5          10.0  popcorn;candy;soda;hot dog;nachos             48.00           cash         98.00
# 54         TXN052 2024-02-02     Henry Peterson                  Next Goal Wins       Adult                1          15.5                       , , , ,Water              3.50     Debit Card         19.00
# 55         TXN053 2024-02-03        Pamela Gray                  next goal wins       ADULT                1           NaN                              water              3.50     Debit card           NaN
# 56         TXN054 2024-03-02     Walter Ramirez                       The Shift      Senior                2          12.0               Pretzel;Soda; ;Candy             19.75           Cash         43.75
# 57         TXN055 2024-02-04     Virginia James                    Silent Night     student                1          13.0           Popcorn, , , ,Soda,Candy             18.00    Credit Card         31.00
# 58         TXN056 2024-02-04      Arthur Watson                    SILENT NIGHT     Student                1          13.0                 popcorn;soda;candy             18.00    credit card         31.00
# 59         TXN057 2024-02-05      Teresa Brooks                             NaN       Adult                2          15.5                Hot Dog,Nachos,Soda             28.00     Debit Card         59.00
# 60         TXN058        NaT        Ralph Kelly                  Ricky Stanicky       ADULT                3          15.5                   , ,Popcorn,Candy             24.50           Cash         71.00
# 61         TXN059 2024-02-05    Frances Sanders                  ricky stanicky       adult                3           NaN                      popcorn;candy             24.50           cash           NaN
# 62         TXN060 2024-02-06          Roy Price                  The Bricklayer      Senior                1          12.0                  Water, , ,Pretzel              8.00     Debit Card         20.00

# %% [markdown]
# ---
# ## STEP 5: Standardize Text Capitalization
#
# **Explanation:** Different capitalizations represent the same value:
# - Ticket types: `ADULT`, `adult`, `Adult` → all mean the same thing
# - Movie titles: `THE HOLDOVERS`, `The Holdovers` → same movie
# - Payment methods: `Credit Card`, `credit card`, `CREDIT CARD` → same method
#
# **Problem:** This causes:
# - Incorrect counting of categories
# - Duplicate entries in analysis
# - Incorrect association rules
#
# **Solution:** Convert all text to consistent Title Case format.

# %%
df_step5 = df_step4.copy()

# Show before standardization
print("BEFORE TEXT STANDARDIZATION:")
print("="*100)
print("\nTicket Type Distribution:")
print(df_step5['ticket_type'].value_counts())
print("\nPayment Method Distribution:")
print(df_step5['payment_method'].value_counts())
print(f"\nUnique Movies: {df_step5['movie_title'].nunique()}")
# Out:
# BEFORE TEXT STANDARDIZATION:
# ====================================================================================================
#
# Ticket Type Distribution:
# ticket_type
# ADULT      11
# adult      11
# Adult       8
# Senior      7
# CHILD       6
# Student     5
# Child       3
# student     3
# SENIOR      2
# child       2
# STUDENT     1
# Name: count, dtype: int64
#
# Payment Method Distribution:
# payment_method
# Cash           17
# Credit Card    15
# Debit Card     14
# credit card     4
# cash            3
# Debit card      2
# CREDIT CARD     1
# debit card      1
# CASH            1
# Name: count, dtype: int64
#
# Unique Movies: 56

# %%
# Standardize text fields
df_step5['ticket_type'] = df_step5['ticket_type'].str.strip().str.title()
df_step5['movie_title'] = df_step5['movie_title'].str.strip().str.title()
df_step5['payment_method'] = df_step5['payment_method'].str.strip().str.title()

print("AFTER TEXT STANDARDIZATION:")
print("="*100)
print("\nTicket Type Distribution:")
print(df_step5['ticket_type'].value_counts())
print("\nPayment Method Distribution:")
print(df_step5['payment_method'].value_counts())
print(f"\nUnique Movies: {df_step5['movie_title'].nunique()}")
print("\n✓ All text fields standardized to Title Case")
# Out:
# AFTER TEXT STANDARDIZATION:
# ====================================================================================================
#
# Ticket Type Distribution:
# ticket_type
# Adult      30
# Child      11
# Senior      9
# Student     9
# Name: count, dtype: int64
#
# Payment Method Distribution:
# payment_method
# Cash           21
# Credit Card    20
# Debit Card     17
# Name: count, dtype: int64
#
# Unique Movies: 41
#
# ✓ All text fields standardized to Title Case

# %%
# Display complete data after text standardization
print("COMPLETE DATA AFTER TEXT STANDARDIZATION:")
print("="*100)
print(df_step5.to_string())
# Out:
# COMPLETE DATA AFTER TEXT STANDARDIZATION:
# ====================================================================================================
#    transaction_id       date      customer_name                     movie_title ticket_type  ticket_quantity  ticket_price                   concession_items  concession_total payment_method  total_amount
# 0          TXN001 2024-01-15         John Smith                  Dune: Part Two       Adult                2          15.5                 Popcorn,Soda,Candy             28.50    Credit Card         59.50
# 1          TXN002 2024-01-15      Sarah Johnson                  Dune: Part Two       Adult                2          15.5                 popcorn;soda;candy             28.50    Credit Card         59.50
# 2          TXN003        NaT      Michael Brown                      The Batman      Senior                1          12.0                   Popcorn, , ,Soda             15.75           Cash           NaN
# 3          TXN004 2024-01-16        Emily Davis                     Oppenheimer     Student                3          13.0               Nachos;Pretzel;Water             22.00     Debit Card         61.00
# 5          TXN005 2024-01-16      Robert Wilson                          Barbie       Adult                4           NaN         Hot Dog;Popcorn;Soda;Candy             45.25    Credit Card        107.25
# 6          TXN006 2024-01-17       Jennifer Lee                     Poor Things       Adult                2          15.5                Popcorn,, , , ,Soda             18.00           Cash         49.00
# 7          TXN007        NaT     David Martinez      Killers Of The Flower Moon       Child                2          10.0                      Candy;Popcorn             12.50    Credit Card         32.50
# 8          TXN008 2024-01-17      Lisa Anderson                   The Holdovers      Senior                1          12.0                                NaN              0.00           Cash         12.00
# 9          TXN009        NaT       James Taylor                   The Holdovers      Senior                1          12.0                      Water,Pretzel              8.50     Debit Card         20.50
# 10         TXN010 2024-01-18        Mary Thomas                        Napoleon       Adult                3          15.5            Popcorn;Soda; ; ;Nachos             38.75    Credit Card         85.25
# 12         TXN011 2024-01-18  Christopher Moore                           Wonka       Child                4          10.0                Candy,Popcorn,Soda,             35.00           Cash         75.00
# 13         TXN012 2024-01-19     Amanda Jackson              Godzilla Minus One       Adult                2           NaN                       Hot Dog,Soda             16.50    Credit Card           NaN
# 14         TXN013 2024-01-19      Matthew White                The Color Purple     Student                2          13.0            Popcorn; ; ;Candy;Water             24.00     Debit Card         50.00
# 15         TXN014        NaT      Daniel Harris                         Ferrari       Adult                1          15.5                        Nachos,Soda             18.25           Cash         33.75
# 16         TXN015 2024-01-20     Jessica Martin                American Fiction       Adult                3          15.5                ,Popcorn,Soda,Candy             32.00    Credit Card         78.50
# 17         TXN016 2024-01-20      Paul Thompson                      Mean Girls       Adult                2          15.5                    Pretzel;Water;              14.75     Debit Card         45.75
# 18         TXN017 2024-01-20       Karen Garcia                      Mean Girls       Adult                2          15.5                     pretzel,water,             14.75     Debit Card         45.75
# 19         TXN018 2024-01-21   Steven Rodriguez                   The Beekeeper      Senior                1          12.0              Popcorn,, ,Soda,Candy             21.50            NaN         33.50
# 20         TXN019 2024-01-22     Laura Martinez                       Migration       Child                3          10.0                 Candy;Popcorn;Soda             27.00           Cash         57.00
# 21         TXN020 2024-01-22          Kevin Lee    Aquaman And The Lost Kingdom     Student                2          13.0               Hot Dog;,Nachos;Soda             25.50    Credit Card         51.50
# 22         TXN021 2024-01-22       Nancy Walker                   The Iron Claw       Adult                1           NaN                      Popcorn,Water             13.25           Cash           NaN
# 24         TXN022 2024-01-23         Brian Hall                  Anyone But You       Adult                2          15.5               Soda, ,Candy,Popcorn             29.00     Debit Card         60.00
# 25         TXN023 2024-01-23      Rebecca Allen                  Anyone But You       Adult                2          15.5                 soda;candy;popcorn             29.00     Debit Card           NaN
# 26         TXN024 2024-01-23       George Young                         Maestro      Senior                1          12.0                                NaN              0.00           Cash         12.00
# 27         TXN025 2024-01-24      Michelle King             Society Of The Snow       Adult                4          15.5        Popcorn;Soda;Hot Dog;Nachos             52.00    Credit Card        114.00
# 28         TXN026 2024-01-24     Charles Wright                      Night Swim       Child                3          10.0                    Candy, ,Popcorn             18.75           Cash         48.75
# 29         TXN027 2024-01-25    Elizabeth Lopez                      Night Swim       Child                3          10.0                      candy;popcorn             18.75           Cash         48.75
# 30         TXN028        NaT       William Hill                        Saltburn     Student                1          13.0             Pretzel;Water; ; ;Soda             17.25     Debit Card         30.25
# 31         TXN029 2024-01-25      Barbara Scott            The Zone Of Interest       Adult                2           NaN                      ,Popcorn,Soda             19.50    Credit Card           NaN
# 32         TXN030 2024-01-26      Richard Green             All Of Us Strangers       Adult                1          15.5                    Hot Dog,Nachos,             20.00           Cash         35.50
# 33         TXN031 2024-01-26       Thomas Baker    The Hunger Games: The Ballad       Adult                3          15.5          Popcorn;Soda;Candy;Nachos             42.00    Credit Card         88.50
# 34         TXN033 2024-01-27    Donald Campbell                            Wish       Child                4          10.0             candy, , ,popcorn,soda             33.00     Debit Card         73.00
# 35         TXN034 2024-01-28  Patricia Mitchell                            Wish       Child                4          10.0                 Candy;Popcorn;Soda             33.00     Debit Card         73.00
# 36         TXN035 2024-01-28       Mark Roberts           The Boy And The Heron       Adult                2          15.5            Hot Dog, ,Nachos, ,Soda             28.75    Credit Card         59.75
# 37         TXN036 2024-01-28     Carol Phillips           The Boy And The Heron       Adult                2          15.5                hot dog;nachos;soda             28.75    Credit Card         59.75
# 38         TXN037        NaT       Betty Turner                           Wonka     Student                1          13.0                       , , ,Popcorn              5.50           Cash         18.50
# 39         TXN038 2024-01-29      Jeffrey Evans    Aquaman And The Lost Kingdom      Senior                1          12.0                         Candy,Soda             11.00           Cash         23.00
# 41         TXN039 2024-01-29    Dorothy Collins                       Freelance       Adult                2           NaN         Popcorn,Hot Dog,Soda,Candy             36.50     Debit Card           NaN
# 42         TXN040 2024-01-30      Jason Stewart  Renaissance: A Film By Beyoncé       Adult                3          15.5              Nachos; ; ;Soda;Water             23.25    Credit Card         69.75
# 43         TXN041 2024-01-30       Helen Morris     Taylor Swift: The Eras Tour       Adult                4          15.5             , ,Popcorn,Candy,Soda,             39.00    Credit Card        101.00
# 44         TXN042 2024-01-31        Gary Rogers     Taylor Swift: The Eras Tour       Adult                4          15.5                 popcorn;candy;soda             39.00    Credit Card        101.00
# 45         TXN043 2024-01-31       Shirley Reed                            Nyad      Senior                1          12.0                    Water, ,Pretzel              8.25           Cash         20.25
# 46         TXN044 2024-01-31         Larry Cook                          Memory     Student                2          13.0             Hot Dog;Popcorn; ;Soda             24.50     Debit Card         50.50
# 47         TXN045        NaT     Deborah Bailey                          Memory     Student                2          13.0               hot dog,popcorn,soda             24.50     Debit Card         50.50
# 48         TXN046 2024-02-01     Gregory Cooper                             Leo       Child                3           NaN              , ,Candy,Popcorn,Soda             29.25           Cash           NaN
# 49         TXN047 2024-02-01    Ruth Richardson                             Leo       Child                3          10.0                 candy;popcorn;soda             29.25           Cash         59.25
# 50         TXN048 2024-02-01          Frank Cox                     The Marvels       Adult                2          15.5              Nachos,Soda, , ,Candy             27.00    Credit Card         58.00
# 51         TXN049 2024-02-02       Maria Howard                     The Marvels       Adult                2          15.5                  nachos;soda;candy             27.00    Credit Card         58.00
# 52         TXN050        NaT         Aaron Ward            Trolls Band Together       Child                5          10.0  Popcorn,Candy,Soda,Hot Dog,Nachos             48.00           Cash         98.00
# 53         TXN051 2024-02-02        Judy Torres            Trolls Band Together       Child                5          10.0  popcorn;candy;soda;hot dog;nachos             48.00           Cash         98.00
# 54         TXN052 2024-02-02     Henry Peterson                  Next Goal Wins       Adult                1          15.5                       , , , ,Water              3.50     Debit Card         19.00
# 55         TXN053 2024-02-03        Pamela Gray                  Next Goal Wins       Adult                1           NaN                              water              3.50     Debit Card           NaN
# 56         TXN054 2024-03-02     Walter Ramirez                       The Shift      Senior                2          12.0               Pretzel;Soda; ;Candy             19.75           Cash         43.75
# 57         TXN055 2024-02-04     Virginia James                    Silent Night     Student                1          13.0           Popcorn, , , ,Soda,Candy             18.00    Credit Card         31.00
# 58         TXN056 2024-02-04      Arthur Watson                    Silent Night     Student                1          13.0                 popcorn;soda;candy             18.00    Credit Card         31.00
# 59         TXN057 2024-02-05      Teresa Brooks                             NaN       Adult                2          15.5                Hot Dog,Nachos,Soda             28.00     Debit Card         59.00
# 60         TXN058        NaT        Ralph Kelly                  Ricky Stanicky       Adult                3          15.5                   , ,Popcorn,Candy             24.50           Cash         71.00
# 61         TXN059 2024-02-05    Frances Sanders                  Ricky Stanicky       Adult                3           NaN                      popcorn;candy             24.50           Cash           NaN
# 62         TXN060 2024-02-06          Roy Price                  The Bricklayer      Senior                1          12.0                  Water, , ,Pretzel              8.00     Debit Card         20.00

# %% [markdown]
# ---
# ## STEP 6: Clean Concession Items
#
# **Explanation:** Concession items have multiple problems:
# 1. **Mixed separators:** Some use commas (`,`), others use semicolons (`;`)
# 2. **Blank items:** Empty strings between separators like `Popcorn, , ,Soda`
# 3. **Inconsistent capitalization:** `Popcorn` vs `popcorn`
#
# **Problem:** These issues prevent accurate analysis of:
# - Which items are purchased together
# - Item popularity
# - Association rules between items
#
# **Solution:**
# - Unify separators to commas
# - Remove blank/empty items
# - Standardize capitalization to Title Case

# %%
# Show examples of messy concession items
print("CONCESSION ITEMS BEFORE CLEANING (Examples):")
print("="*100)
print(df_step5[['transaction_id', 'concession_items']].head(20).to_string())
# Out:
# CONCESSION ITEMS BEFORE CLEANING (Examples):
# ====================================================================================================
#    transaction_id            concession_items
# 0          TXN001          Popcorn,Soda,Candy
# 1          TXN002          popcorn;soda;candy
# 2          TXN003            Popcorn, , ,Soda
# 3          TXN004        Nachos;Pretzel;Water
# 5          TXN005  Hot Dog;Popcorn;Soda;Candy
# 6          TXN006         Popcorn,, , , ,Soda
# 7          TXN007               Candy;Popcorn
# 8          TXN008                         NaN
# 9          TXN009               Water,Pretzel
# 10         TXN010     Popcorn;Soda; ; ;Nachos
# 12         TXN011         Candy,Popcorn,Soda,
# 13         TXN012                Hot Dog,Soda
# 14         TXN013     Popcorn; ; ;Candy;Water
# 15         TXN014                 Nachos,Soda
# 16         TXN015         ,Popcorn,Soda,Candy
# 17         TXN016             Pretzel;Water;
# 18         TXN017              pretzel,water,
# 19         TXN018       Popcorn,, ,Soda,Candy
# 20         TXN019          Candy;Popcorn;Soda
# 21         TXN020        Hot Dog;,Nachos;Soda

# %%
# Define cleaning function
def clean_concession_items(items_str):
    """
    Clean concession items:
    - Handle both comma and semicolon separators
    - Remove blank/empty items
    - Standardize capitalization
    - Return comma-separated string
    """
    if pd.isna(items_str) or items_str == '':
        return ''
    
    items_str = str(items_str)
    
    # Replace semicolons with commas for consistent splitting
    items_str = items_str.replace(';', ',')
    
    # Split by comma
    items = items_str.split(',')
    
    # Clean each item: strip whitespace, remove empty items, title case
    cleaned_items = []
    for item in items:
        item = item.strip()
        if item:  # Only keep non-empty items
            cleaned_items.append(item.title())
    
    # Return comma-separated string
    return ','.join(cleaned_items)

print("✓ Concession item cleaning function defined")
# Out:
# ✓ Concession item cleaning function defined

# %%
# Apply cleaning
df_step6 = df_step5.copy()
df_step6['concession_items'] = df_step6['concession_items'].apply(clean_concession_items)

print("CONCESSION ITEMS AFTER CLEANING:")
print("="*100)
print(df_step6[['transaction_id', 'concession_items']].head(20).to_string())
print("\n✓ Concession items cleaned:")
print("  - Mixed separators (';' and ',') unified to ','")
print("  - Blank items removed")
print("  - Capitalization standardized to Title Case")
# Out:
# CONCESSION ITEMS AFTER CLEANING:
# ====================================================================================================
#    transaction_id            concession_items
# 0          TXN001          Popcorn,Soda,Candy
# 1          TXN002          Popcorn,Soda,Candy
# 2          TXN003                Popcorn,Soda
# 3          TXN004        Nachos,Pretzel,Water
# 5          TXN005  Hot Dog,Popcorn,Soda,Candy
# 6          TXN006                Popcorn,Soda
# 7          TXN007               Candy,Popcorn
# 8          TXN008
# 9          TXN009               Water,Pretzel
# 10         TXN010         Popcorn,Soda,Nachos
# 12         TXN011          Candy,Popcorn,Soda
# 13         TXN012                Hot Dog,Soda
# 14         TXN013         Popcorn,Candy,Water
# 15         TXN014                 Nachos,Soda
# 16         TXN015          Popcorn,Soda,Candy
# 17         TXN016               Pretzel,Water
# 18         TXN017               Pretzel,Water
# 19         TXN018          Popcorn,Soda,Candy
# 20         TXN019          Candy,Popcorn,Soda
# 21         TXN020         Hot Dog,Nachos,Soda
#
# ✓ Concession items cleaned:
#   - Mixed separators (';' and ',') unified to ','
#   - Blank items removed
#   - Capitalization standardized to Title Case

# %%
# Display complete data after concession items cleaning
print("COMPLETE DATA AFTER CONCESSION ITEMS CLEANING:")
print("="*100)
print(df_step6.to_string())
# Out:
# COMPLETE DATA AFTER CONCESSION ITEMS CLEANING:
# ====================================================================================================
#    transaction_id       date      customer_name                     movie_title ticket_type  ticket_quantity  ticket_price                   concession_items  concession_total payment_method  total_amount
# 0          TXN001 2024-01-15         John Smith                  Dune: Part Two       Adult                2          15.5                 Popcorn,Soda,Candy             28.50    Credit Card         59.50
# 1          TXN002 2024-01-15      Sarah Johnson                  Dune: Part Two       Adult                2          15.5                 Popcorn,Soda,Candy             28.50    Credit Card         59.50
# 2          TXN003        NaT      Michael Brown                      The Batman      Senior                1          12.0                       Popcorn,Soda             15.75           Cash           NaN
# 3          TXN004 2024-01-16        Emily Davis                     Oppenheimer     Student                3          13.0               Nachos,Pretzel,Water             22.00     Debit Card         61.00
# 5          TXN005 2024-01-16      Robert Wilson                          Barbie       Adult                4           NaN         Hot Dog,Popcorn,Soda,Candy             45.25    Credit Card        107.25
# 6          TXN006 2024-01-17       Jennifer Lee                     Poor Things       Adult                2          15.5                       Popcorn,Soda             18.00           Cash         49.00
# 7          TXN007        NaT     David Martinez      Killers Of The Flower Moon       Child                2          10.0                      Candy,Popcorn             12.50    Credit Card         32.50
# 8          TXN008 2024-01-17      Lisa Anderson                   The Holdovers      Senior                1          12.0                                                 0.00           Cash         12.00
# 9          TXN009        NaT       James Taylor                   The Holdovers      Senior                1          12.0                      Water,Pretzel              8.50     Debit Card         20.50
# 10         TXN010 2024-01-18        Mary Thomas                        Napoleon       Adult                3          15.5                Popcorn,Soda,Nachos             38.75    Credit Card         85.25
# 12         TXN011 2024-01-18  Christopher Moore                           Wonka       Child                4          10.0                 Candy,Popcorn,Soda             35.00           Cash         75.00
# 13         TXN012 2024-01-19     Amanda Jackson              Godzilla Minus One       Adult                2           NaN                       Hot Dog,Soda             16.50    Credit Card           NaN
# 14         TXN013 2024-01-19      Matthew White                The Color Purple     Student                2          13.0                Popcorn,Candy,Water             24.00     Debit Card         50.00
# 15         TXN014        NaT      Daniel Harris                         Ferrari       Adult                1          15.5                        Nachos,Soda             18.25           Cash         33.75
# 16         TXN015 2024-01-20     Jessica Martin                American Fiction       Adult                3          15.5                 Popcorn,Soda,Candy             32.00    Credit Card         78.50
# 17         TXN016 2024-01-20      Paul Thompson                      Mean Girls       Adult                2          15.5                      Pretzel,Water             14.75     Debit Card         45.75
# 18         TXN017 2024-01-20       Karen Garcia                      Mean Girls       Adult                2          15.5                      Pretzel,Water             14.75     Debit Card         45.75
# 19         TXN018 2024-01-21   Steven Rodriguez                   The Beekeeper      Senior                1          12.0                 Popcorn,Soda,Candy             21.50            NaN         33.50
# 20         TXN019 2024-01-22     Laura Martinez                       Migration       Child                3          10.0                 Candy,Popcorn,Soda             27.00           Cash         57.00
# 21         TXN020 2024-01-22          Kevin Lee    Aquaman And The Lost Kingdom     Student                2          13.0                Hot Dog,Nachos,Soda             25.50    Credit Card         51.50
# 22         TXN021 2024-01-22       Nancy Walker                   The Iron Claw       Adult                1           NaN                      Popcorn,Water             13.25           Cash           NaN
# 24         TXN022 2024-01-23         Brian Hall                  Anyone But You       Adult                2          15.5                 Soda,Candy,Popcorn             29.00     Debit Card         60.00
# 25         TXN023 2024-01-23      Rebecca Allen                  Anyone But You       Adult                2          15.5                 Soda,Candy,Popcorn             29.00     Debit Card           NaN
# 26         TXN024 2024-01-23       George Young                         Maestro      Senior                1          12.0                                                 0.00           Cash         12.00
# 27         TXN025 2024-01-24      Michelle King             Society Of The Snow       Adult                4          15.5        Popcorn,Soda,Hot Dog,Nachos             52.00    Credit Card        114.00
# 28         TXN026 2024-01-24     Charles Wright                      Night Swim       Child                3          10.0                      Candy,Popcorn             18.75           Cash         48.75
# 29         TXN027 2024-01-25    Elizabeth Lopez                      Night Swim       Child                3          10.0                      Candy,Popcorn             18.75           Cash         48.75
# 30         TXN028        NaT       William Hill                        Saltburn     Student                1          13.0                 Pretzel,Water,Soda             17.25     Debit Card         30.25
# 31         TXN029 2024-01-25      Barbara Scott            The Zone Of Interest       Adult                2           NaN                       Popcorn,Soda             19.50    Credit Card           NaN
# 32         TXN030 2024-01-26      Richard Green             All Of Us Strangers       Adult                1          15.5                     Hot Dog,Nachos             20.00           Cash         35.50
# 33         TXN031 2024-01-26       Thomas Baker    The Hunger Games: The Ballad       Adult                3          15.5          Popcorn,Soda,Candy,Nachos             42.00    Credit Card         88.50
# 34         TXN033 2024-01-27    Donald Campbell                            Wish       Child                4          10.0                 Candy,Popcorn,Soda             33.00     Debit Card         73.00
# 35         TXN034 2024-01-28  Patricia Mitchell                            Wish       Child                4          10.0                 Candy,Popcorn,Soda             33.00     Debit Card         73.00
# 36         TXN035 2024-01-28       Mark Roberts           The Boy And The Heron       Adult                2          15.5                Hot Dog,Nachos,Soda             28.75    Credit Card         59.75
# 37         TXN036 2024-01-28     Carol Phillips           The Boy And The Heron       Adult                2          15.5                Hot Dog,Nachos,Soda             28.75    Credit Card         59.75
# 38         TXN037        NaT       Betty Turner                           Wonka     Student                1          13.0                            Popcorn              5.50           Cash         18.50
# 39         TXN038 2024-01-29      Jeffrey Evans    Aquaman And The Lost Kingdom      Senior                1          12.0                         Candy,Soda             11.00           Cash         23.00
# 41         TXN039 2024-01-29    Dorothy Collins                       Freelance       Adult                2           NaN         Popcorn,Hot Dog,Soda,Candy             36.50     Debit Card           NaN
# 42         TXN040 2024-01-30      Jason Stewart  Renaissance: A Film By Beyoncé       Adult                3          15.5                  Nachos,Soda,Water             23.25    Credit Card         69.75
# 43         TXN041 2024-01-30       Helen Morris     Taylor Swift: The Eras Tour       Adult                4          15.5                 Popcorn,Candy,Soda             39.00    Credit Card        101.00
# 44         TXN042 2024-01-31        Gary Rogers     Taylor Swift: The Eras Tour       Adult                4          15.5                 Popcorn,Candy,Soda             39.00    Credit Card        101.00
# 45         TXN043 2024-01-31       Shirley Reed                            Nyad      Senior                1          12.0                      Water,Pretzel              8.25           Cash         20.25
# 46         TXN044 2024-01-31         Larry Cook                          Memory     Student                2          13.0               Hot Dog,Popcorn,Soda             24.50     Debit Card         50.50
# 47         TXN045        NaT     Deborah Bailey                          Memory     Student                2          13.0               Hot Dog,Popcorn,Soda             24.50     Debit Card         50.50
# 48         TXN046 2024-02-01     Gregory Cooper                             Leo       Child                3           NaN                 Candy,Popcorn,Soda             29.25           Cash           NaN
# 49         TXN047 2024-02-01    Ruth Richardson                             Leo       Child                3          10.0                 Candy,Popcorn,Soda             29.25           Cash         59.25
# 50         TXN048 2024-02-01          Frank Cox                     The Marvels       Adult                2          15.5                  Nachos,Soda,Candy             27.00    Credit Card         58.00
# 51         TXN049 2024-02-02       Maria Howard                     The Marvels       Adult                2          15.5                  Nachos,Soda,Candy             27.00    Credit Card         58.00
# 52         TXN050        NaT         Aaron Ward            Trolls Band Together       Child                5          10.0  Popcorn,Candy,Soda,Hot Dog,Nachos             48.00           Cash         98.00
# 53         TXN051 2024-02-02        Judy Torres            Trolls Band Together       Child                5          10.0  Popcorn,Candy,Soda,Hot Dog,Nachos             48.00           Cash         98.00
# 54         TXN052 2024-02-02     Henry Peterson                  Next Goal Wins       Adult                1          15.5                              Water              3.50     Debit Card         19.00
# 55         TXN053 2024-02-03        Pamela Gray                  Next Goal Wins       Adult                1           NaN                              Water              3.50     Debit Card           NaN
# 56         TXN054 2024-03-02     Walter Ramirez                       The Shift      Senior                2          12.0                 Pretzel,Soda,Candy             19.75           Cash         43.75
# 57         TXN055 2024-02-04     Virginia James                    Silent Night     Student                1          13.0                 Popcorn,Soda,Candy             18.00    Credit Card         31.00
# 58         TXN056 2024-02-04      Arthur Watson                    Silent Night     Student                1          13.0                 Popcorn,Soda,Candy             18.00    Credit Card         31.00
# 59         TXN057 2024-02-05      Teresa Brooks                             NaN       Adult                2          15.5                Hot Dog,Nachos,Soda             28.00     Debit Card         59.00
# 60         TXN058        NaT        Ralph Kelly                  Ricky Stanicky       Adult                3          15.5                      Popcorn,Candy             24.50           Cash         71.00
# 61         TXN059 2024-02-05    Frances Sanders                  Ricky Stanicky       Adult                3           NaN                      Popcorn,Candy             24.50           Cash           NaN
# 62         TXN060 2024-02-06          Roy Price                  The Bricklayer      Senior                1          12.0                      Water,Pretzel              8.00     Debit Card         20.00

# %% [markdown]
# ---
# ## STEP 7: Handle Missing Numeric Values
#
# **Explanation:** Some transactions have missing prices or totals:
# - Missing `ticket_price`: Can't calculate revenue per ticket type
# - Missing `total_amount`: Can't calculate total sales
#
# **Strategy:**
# 1. **For missing ticket_price:** Use the average price for that ticket type
# 2. **For missing total_amount:** Calculate it as:
#    - `total_amount = (ticket_quantity × ticket_price) + concession_total`
#
# **Why this works:** Ticket prices are typically fixed by type (Adult, Child, Senior, Student)

# %%
# Analyze missing values
print("MISSING NUMERIC VALUES ANALYSIS:")
print("="*100)
print(f"Missing ticket_price: {df_step6['ticket_price'].isna().sum()}")
print(f"Missing total_amount: {df_step6['total_amount'].isna().sum()}")

# Show transactions with missing values
missing_values = df_step6[df_step6['ticket_price'].isna() | df_step6['total_amount'].isna()]
print(f"\nTransactions with missing numeric values: {len(missing_values)}")
print("\n")
print(missing_values[['transaction_id', 'ticket_type', 'ticket_quantity', 'ticket_price', 
                       'concession_total', 'total_amount']].to_string())
# Out:
# MISSING NUMERIC VALUES ANALYSIS:
# ====================================================================================================
# Missing ticket_price: 8
# Missing total_amount: 9
#
# Transactions with missing numeric values: 10
#
#
#    transaction_id ticket_type  ticket_quantity  ticket_price  concession_total  total_amount
# 2          TXN003      Senior                1          12.0             15.75           NaN
# 5          TXN005       Adult                4           NaN             45.25        107.25
# 13         TXN012       Adult                2           NaN             16.50           NaN
# 22         TXN021       Adult                1           NaN             13.25           NaN
# 25         TXN023       Adult                2          15.5             29.00           NaN
# 31         TXN029       Adult                2           NaN             19.50           NaN
# 41         TXN039       Adult                2           NaN             36.50           NaN
# 48         TXN046       Child                3           NaN             29.25           NaN
# 55         TXN053       Adult                1           NaN              3.50           NaN
# 61         TXN059       Adult                3           NaN             24.50           NaN

# %%
# Calculate average prices by ticket type
ticket_type_avg_prices = df_step6.groupby('ticket_type')['ticket_price'].mean()

print("AVERAGE PRICES BY TICKET TYPE:")
print("="*100)
print(ticket_type_avg_prices)
print("\nThese averages will be used to fill missing ticket prices")
# Out:
# AVERAGE PRICES BY TICKET TYPE:
# ====================================================================================================
# ticket_type
# Adult      15.5
# Child      10.0
# Senior     12.0
# Student    13.0
# Name: ticket_price, dtype: float64
#
# These averages will be used to fill missing ticket prices

# %%
# Fill missing values
df_step7 = df_step6.copy()

for idx, row in df_step7.iterrows():
    # If ticket_price is missing, fill with average for that ticket type
    if pd.isna(row['ticket_price']):
        ticket_type = row['ticket_type']
        if ticket_type in ticket_type_avg_prices.index:
            df_step7.at[idx, 'ticket_price'] = round(ticket_type_avg_prices[ticket_type], 2)
    
    # If total_amount is missing, calculate it
    if pd.isna(row['total_amount']):
        ticket_total = row['ticket_quantity'] * row['ticket_price']
        concession_total = row['concession_total'] if not pd.isna(row['concession_total']) else 0
        df_step7.at[idx, 'total_amount'] = round(ticket_total + concession_total, 2)

print("MISSING VALUES HANDLING RESULTS:")
print("="*100)
print("✓ Missing ticket prices filled with ticket type averages")
print("✓ Missing total amounts calculated from components")
print(f"\nVerification:")
print(f"  Missing ticket_price: {df_step7['ticket_price'].isna().sum()}")
print(f"  Missing total_amount: {df_step7['total_amount'].isna().sum()}")
# Out:
# MISSING VALUES HANDLING RESULTS:
# ====================================================================================================
# ✓ Missing ticket prices filled with ticket type averages
# ✓ Missing total amounts calculated from components
#
# Verification:
#   Missing ticket_price: 0
#   Missing total_amount: 7

# %%
# Display complete data after handling missing values
print("COMPLETE DATA AFTER HANDLING MISSING VALUES:")
print("="*100)
print(df_step7.to_string())
# Out:
# COMPLETE DATA AFTER HANDLING MISSING VALUES:
# ====================================================================================================
#    transaction_id       date      customer_name                     movie_title ticket_type  ticket_quantity  ticket_price                   concession_items  concession_total payment_method  total_amount
# 0          TXN001 2024-01-15         John Smith                  Dune: Part Two       Adult                2          15.5                 Popcorn,Soda,Candy             28.50    Credit Card         59.50
# 1          TXN002 2024-01-15      Sarah Johnson                  Dune: Part Two       Adult                2          15.5                 Popcorn,Soda,Candy             28.50    Credit Card         59.50
# 2          TXN003        NaT      Michael Brown                      The Batman      Senior                1          12.0                       Popcorn,Soda             15.75           Cash         27.75
# 3          TXN004 2024-01-16        Emily Davis                     Oppenheimer     Student                3          13.0               Nachos,Pretzel,Water             22.00     Debit Card         61.00
# 5          TXN005 2024-01-16      Robert Wilson                          Barbie       Adult                4          15.5         Hot Dog,Popcorn,Soda,Candy             45.25    Credit Card        107.25
# 6          TXN006 2024-01-17       Jennifer Lee                     Poor Things       Adult                2          15.5                       Popcorn,Soda             18.00           Cash         49.00
# 7          TXN007        NaT     David Martinez      Killers Of The Flower Moon       Child                2          10.0                      Candy,Popcorn             12.50    Credit Card         32.50
# 8          TXN008 2024-01-17      Lisa Anderson                   The Holdovers      Senior                1          12.0                                                 0.00           Cash         12.00
# 9          TXN009        NaT       James Taylor                   The Holdovers      Senior                1          12.0                      Water,Pretzel              8.50     Debit Card         20.50
# 10         TXN010 2024-01-18        Mary Thomas                        Napoleon       Adult                3          15.5                Popcorn,Soda,Nachos             38.75    Credit Card         85.25
# 12         TXN011 2024-01-18  Christopher Moore                           Wonka       Child                4          10.0                 Candy,Popcorn,Soda             35.00           Cash         75.00
# 13         TXN012 2024-01-19     Amanda Jackson              Godzilla Minus One       Adult                2          15.5                       Hot Dog,Soda             16.50    Credit Card           NaN
# 14         TXN013 2024-01-19      Matthew White                The Color Purple     Student                2          13.0                Popcorn,Candy,Water             24.00     Debit Card         50.00
# 15         TXN014        NaT      Daniel Harris                         Ferrari       Adult                1          15.5                        Nachos,Soda             18.25           Cash         33.75
# 16         TXN015 2024-01-20     Jessica Martin                American Fiction       Adult                3          15.5                 Popcorn,Soda,Candy             32.00    Credit Card         78.50
# 17         TXN016 2024-01-20      Paul Thompson                      Mean Girls       Adult                2          15.5                      Pretzel,Water             14.75     Debit Card         45.75
# 18         TXN017 2024-01-20       Karen Garcia                      Mean Girls       Adult                2          15.5                      Pretzel,Water             14.75     Debit Card         45.75
# 19         TXN018 2024-01-21   Steven Rodriguez                   The Beekeeper      Senior                1          12.0                 Popcorn,Soda,Candy             21.50            NaN         33.50
# 20         TXN019 2024-01-22     Laura Martinez                       Migration       Child                3          10.0                 Candy,Popcorn,Soda             27.00           Cash         57.00
# 21         TXN020 2024-01-22          Kevin Lee    Aquaman And The Lost Kingdom     Student                2          13.0                Hot Dog,Nachos,Soda             25.50    Credit Card         51.50
# 22         TXN021 2024-01-22       Nancy Walker                   The Iron Claw       Adult                1          15.5                      Popcorn,Water             13.25           Cash           NaN
# 24         TXN022 2024-01-23         Brian Hall                  Anyone But You       Adult                2          15.5                 Soda,Candy,Popcorn             29.00     Debit Card         60.00
# 25         TXN023 2024-01-23      Rebecca Allen                  Anyone But You       Adult                2          15.5                 Soda,Candy,Popcorn             29.00     Debit Card         60.00
# 26         TXN024 2024-01-23       George Young                         Maestro      Senior                1          12.0                                                 0.00           Cash         12.00
# 27         TXN025 2024-01-24      Michelle King             Society Of The Snow       Adult                4          15.5        Popcorn,Soda,Hot Dog,Nachos             52.00    Credit Card        114.00
# 28         TXN026 2024-01-24     Charles Wright                      Night Swim       Child                3          10.0                      Candy,Popcorn             18.75           Cash         48.75
# 29         TXN027 2024-01-25    Elizabeth Lopez                      Night Swim       Child                3          10.0                      Candy,Popcorn             18.75           Cash         48.75
# 30         TXN028        NaT       William Hill                        Saltburn     Student                1          13.0                 Pretzel,Water,Soda             17.25     Debit Card         30.25
# 31         TXN029 2024-01-25      Barbara Scott            The Zone Of Interest       Adult                2          15.5                       Popcorn,Soda             19.50    Credit Card           NaN
# 32         TXN030 2024-01-26      Richard Green             All Of Us Strangers       Adult                1          15.5                     Hot Dog,Nachos             20.00           Cash         35.50
# 33         TXN031 2024-01-26       Thomas Baker    The Hunger Games: The Ballad       Adult                3          15.5          Popcorn,Soda,Candy,Nachos             42.00    Credit Card         88.50
# 34         TXN033 2024-01-27    Donald Campbell                            Wish       Child                4          10.0                 Candy,Popcorn,Soda             33.00     Debit Card         73.00
# 35         TXN034 2024-01-28  Patricia Mitchell                            Wish       Child                4          10.0                 Candy,Popcorn,Soda             33.00     Debit Card         73.00
# 36         TXN035 2024-01-28       Mark Roberts           The Boy And The Heron       Adult                2          15.5                Hot Dog,Nachos,Soda             28.75    Credit Card         59.75
# 37         TXN036 2024-01-28     Carol Phillips           The Boy And The Heron       Adult                2          15.5                Hot Dog,Nachos,Soda             28.75    Credit Card         59.75
# 38         TXN037        NaT       Betty Turner                           Wonka     Student                1          13.0                            Popcorn              5.50           Cash         18.50
# 39         TXN038 2024-01-29      Jeffrey Evans    Aquaman And The Lost Kingdom      Senior                1          12.0                         Candy,Soda             11.00           Cash         23.00
# 41         TXN039 2024-01-29    Dorothy Collins                       Freelance       Adult                2          15.5         Popcorn,Hot Dog,Soda,Candy             36.50     Debit Card           NaN
# 42         TXN040 2024-01-30      Jason Stewart  Renaissance: A Film By Beyoncé       Adult                3          15.5                  Nachos,Soda,Water             23.25    Credit Card         69.75
# 43         TXN041 2024-01-30       Helen Morris     Taylor Swift: The Eras Tour       Adult                4          15.5                 Popcorn,Candy,Soda             39.00    Credit Card        101.00
# 44         TXN042 2024-01-31        Gary Rogers     Taylor Swift: The Eras Tour       Adult                4          15.5                 Popcorn,Candy,Soda             39.00    Credit Card        101.00
# 45         TXN043 2024-01-31       Shirley Reed                            Nyad      Senior                1          12.0                      Water,Pretzel              8.25           Cash         20.25
# 46         TXN044 2024-01-31         Larry Cook                          Memory     Student                2          13.0               Hot Dog,Popcorn,Soda             24.50     Debit Card         50.50
# 47         TXN045        NaT     Deborah Bailey                          Memory     Student                2          13.0               Hot Dog,Popcorn,Soda             24.50     Debit Card         50.50
# 48         TXN046 2024-02-01     Gregory Cooper                             Leo       Child                3          10.0                 Candy,Popcorn,Soda             29.25           Cash           NaN
# 49         TXN047 2024-02-01    Ruth Richardson                             Leo       Child                3          10.0                 Candy,Popcorn,Soda             29.25           Cash         59.25
# 50         TXN048 2024-02-01          Frank Cox                     The Marvels       Adult                2          15.5                  Nachos,Soda,Candy             27.00    Credit Card         58.00
# 51         TXN049 2024-02-02       Maria Howard                     The Marvels       Adult                2          15.5                  Nachos,Soda,Candy             27.00    Credit Card         58.00
# 52         TXN050        NaT         Aaron Ward            Trolls Band Together       Child                5          10.0  Popcorn,Candy,Soda,Hot Dog,Nachos             48.00           Cash         98.00
# 53         TXN051 2024-02-02        Judy Torres            Trolls Band Together       Child                5          10.0  Popcorn,Candy,Soda,Hot Dog,Nachos             48.00           Cash         98.00
# 54         TXN052 2024-02-02     Henry Peterson                  Next Goal Wins       Adult                1          15.5                              Water              3.50     Debit Card         19.00
# 55         TXN053 2024-02-03        Pamela Gray                  Next Goal Wins       Adult                1          15.5                              Water              3.50     Debit Card           NaN
# 56         TXN054 2024-03-02     Walter Ramirez                       The Shift      Senior                2          12.0                 Pretzel,Soda,Candy             19.75           Cash         43.75
# 57         TXN055 2024-02-04     Virginia James                    Silent Night     Student                1          13.0                 Popcorn,Soda,Candy             18.00    Credit Card         31.00
# 58         TXN056 2024-02-04      Arthur Watson                    Silent Night     Student                1          13.0                 Popcorn,Soda,Candy             18.00    Credit Card         31.00
# 59         TXN057 2024-02-05      Teresa Brooks                             NaN       Adult                2          15.5                Hot Dog,Nachos,Soda             28.00     Debit Card         59.00
# 60         TXN058        NaT        Ralph Kelly                  Ricky Stanicky       Adult                3          15.5                      Popcorn,Candy             24.50           Cash         71.00
# 61         TXN059 2024-02-05    Frances Sanders                  Ricky Stanicky       Adult                3          15.5                      Popcorn,Candy             24.50           Cash           NaN
# 62         TXN060 2024-02-06          Roy Price                  The Bricklayer      Senior                1          12.0                      Water,Pretzel              8.00     Debit Card         20.00

# %% [markdown]
# ---
# ## STEP 8: Final Cleaned Data Summary
#
# **Explanation:** This is our final cleaned dataset with all issues resolved:
# - ✓ No duplicates
# - ✓ Standardized dates
# - ✓ Consistent text capitalization
# - ✓ Clean concession items
# - ✓ No missing numeric values
#
# This clean data is now ready for association rule mining!

# %%
df_cleaned = df_step7.copy()

print("COMPLETE FINAL CLEANED DATASET:")
print("="*100)
print(df_cleaned.to_string())
# Out:
# COMPLETE FINAL CLEANED DATASET:
# ====================================================================================================
#    transaction_id       date      customer_name                     movie_title ticket_type  ticket_quantity  ticket_price                   concession_items  concession_total payment_method  total_amount
# 0          TXN001 2024-01-15         John Smith                  Dune: Part Two       Adult                2          15.5                 Popcorn,Soda,Candy             28.50    Credit Card         59.50
# 1          TXN002 2024-01-15      Sarah Johnson                  Dune: Part Two       Adult                2          15.5                 Popcorn,Soda,Candy             28.50    Credit Card         59.50
# 2          TXN003        NaT      Michael Brown                      The Batman      Senior                1          12.0                       Popcorn,Soda             15.75           Cash         27.75
# 3          TXN004 2024-01-16        Emily Davis                     Oppenheimer     Student                3          13.0               Nachos,Pretzel,Water             22.00     Debit Card         61.00
# 5          TXN005 2024-01-16      Robert Wilson                          Barbie       Adult                4          15.5         Hot Dog,Popcorn,Soda,Candy             45.25    Credit Card        107.25
# 6          TXN006 2024-01-17       Jennifer Lee                     Poor Things       Adult                2          15.5                       Popcorn,Soda             18.00           Cash         49.00
# 7          TXN007        NaT     David Martinez      Killers Of The Flower Moon       Child                2          10.0                      Candy,Popcorn             12.50    Credit Card         32.50
# 8          TXN008 2024-01-17      Lisa Anderson                   The Holdovers      Senior                1          12.0                                                 0.00           Cash         12.00
# 9          TXN009        NaT       James Taylor                   The Holdovers      Senior                1          12.0                      Water,Pretzel              8.50     Debit Card         20.50
# 10         TXN010 2024-01-18        Mary Thomas                        Napoleon       Adult                3          15.5                Popcorn,Soda,Nachos             38.75    Credit Card         85.25
# 12         TXN011 2024-01-18  Christopher Moore                           Wonka       Child                4          10.0                 Candy,Popcorn,Soda             35.00           Cash         75.00
# 13         TXN012 2024-01-19     Amanda Jackson              Godzilla Minus One       Adult                2          15.5                       Hot Dog,Soda             16.50    Credit Card           NaN
# 14         TXN013 2024-01-19      Matthew White                The Color Purple     Student                2          13.0                Popcorn,Candy,Water             24.00     Debit Card         50.00
# 15         TXN014        NaT      Daniel Harris                         Ferrari       Adult                1          15.5                        Nachos,Soda             18.25           Cash         33.75
# 16         TXN015 2024-01-20     Jessica Martin                American Fiction       Adult                3          15.5                 Popcorn,Soda,Candy             32.00    Credit Card         78.50
# 17         TXN016 2024-01-20      Paul Thompson                      Mean Girls       Adult                2          15.5                      Pretzel,Water             14.75     Debit Card         45.75
# 18         TXN017 2024-01-20       Karen Garcia                      Mean Girls       Adult                2          15.5                      Pretzel,Water             14.75     Debit Card         45.75
# 19         TXN018 2024-01-21   Steven Rodriguez                   The Beekeeper      Senior                1          12.0                 Popcorn,Soda,Candy             21.50            NaN         33.50
# 20         TXN019 2024-01-22     Laura Martinez                       Migration       Child                3          10.0                 Candy,Popcorn,Soda             27.00           Cash         57.00
# 21         TXN020 2024-01-22          Kevin Lee    Aquaman And The Lost Kingdom     Student                2          13.0                Hot Dog,Nachos,Soda             25.50    Credit Card         51.50
# 22         TXN021 2024-01-22       Nancy Walker                   The Iron Claw       Adult                1          15.5                      Popcorn,Water             13.25           Cash           NaN
# 24         TXN022 2024-01-23         Brian Hall                  Anyone But You       Adult                2          15.5                 Soda,Candy,Popcorn             29.00     Debit Card         60.00
# 25         TXN023 2024-01-23      Rebecca Allen                  Anyone But You       Adult                2          15.5                 Soda,Candy,Popcorn             29.00     Debit Card         60.00
# 26         TXN024 2024-01-23       George Young                         Maestro      Senior                1          12.0                                                 0.00           Cash         12.00
# 27         TXN025 2024-01-24      Michelle King             Society Of The Snow       Adult                4          15.5        Popcorn,Soda,Hot Dog,Nachos             52.00    Credit Card        114.00
# 28         TXN026 2024-01-24     Charles Wright                      Night Swim       Child                3          10.0                      Candy,Popcorn             18.75           Cash         48.75
# 29         TXN027 2024-01-25    Elizabeth Lopez                      Night Swim       Child                3          10.0                      Candy,Popcorn             18.75           Cash         48.75
# 30         TXN028        NaT       William Hill                        Saltburn     Student                1          13.0                 Pretzel,Water,Soda             17.25     Debit Card         30.25
# 31         TXN029 2024-01-25      Barbara Scott            The Zone Of Interest       Adult                2          15.5                       Popcorn,Soda             19.50    Credit Card           NaN
# 32         TXN030 2024-01-26      Richard Green             All Of Us Strangers       Adult                1          15.5                     Hot Dog,Nachos             20.00           Cash         35.50
# 33         TXN031 2024-01-26       Thomas Baker    The Hunger Games: The Ballad       Adult                3          15.5          Popcorn,Soda,Candy,Nachos             42.00    Credit Card         88.50
# 34         TXN033 2024-01-27    Donald Campbell                            Wish       Child                4          10.0                 Candy,Popcorn,Soda             33.00     Debit Card         73.00
# 35         TXN034 2024-01-28  Patricia Mitchell                            Wish       Child                4          10.0                 Candy,Popcorn,Soda             33.00     Debit Card         73.00
# 36         TXN035 2024-01-28       Mark Roberts           The Boy And The Heron       Adult                2          15.5                Hot Dog,Nachos,Soda             28.75    Credit Card         59.75
# 37         TXN036 2024-01-28     Carol Phillips           The Boy And The Heron       Adult                2          15.5                Hot Dog,Nachos,Soda             28.75    Credit Card         59.75
# 38         TXN037        NaT       Betty Turner                           Wonka     Student                1          13.0                            Popcorn              5.50           Cash         18.50
# 39         TXN038 2024-01-29      Jeffrey Evans    Aquaman And The Lost Kingdom      Senior                1          12.0                         Candy,Soda             11.00           Cash         23.00
# 41         TXN039 2024-01-29    Dorothy Collins                       Freelance       Adult                2          15.5         Popcorn,Hot Dog,Soda,Candy             36.50     Debit Card           NaN
# 42         TXN040 2024-01-30      Jason Stewart  Renaissance: A Film By Beyoncé       Adult                3          15.5                  Nachos,Soda,Water             23.25    Credit Card         69.75
# 43         TXN041 2024-01-30       Helen Morris     Taylor Swift: The Eras Tour       Adult                4          15.5                 Popcorn,Candy,Soda             39.00    Credit Card        101.00
# 44         TXN042 2024-01-31        Gary Rogers     Taylor Swift: The Eras Tour       Adult                4          15.5                 Popcorn,Candy,Soda             39.00    Credit Card        101.00
# 45         TXN043 2024-01-31       Shirley Reed                            Nyad      Senior                1          12.0                      Water,Pretzel              8.25           Cash         20.25
# 46         TXN044 2024-01-31         Larry Cook                          Memory     Student                2          13.0               Hot Dog,Popcorn,Soda             24.50     Debit Card         50.50
# 47         TXN045        NaT     Deborah Bailey                          Memory     Student                2          13.0               Hot Dog,Popcorn,Soda             24.50     Debit Card         50.50
# 48         TXN046 2024-02-01     Gregory Cooper                             Leo       Child                3          10.0                 Candy,Popcorn,Soda             29.25           Cash           NaN
# 49         TXN047 2024-02-01    Ruth Richardson                             Leo       Child                3          10.0                 Candy,Popcorn,Soda             29.25           Cash         59.25
# 50         TXN048 2024-02-01          Frank Cox                     The Marvels       Adult                2          15.5                  Nachos,Soda,Candy             27.00    Credit Card         58.00
# 51         TXN049 2024-02-02       Maria Howard                     The Marvels       Adult                2          15.5                  Nachos,Soda,Candy             27.00    Credit Card         58.00
# 52         TXN050        NaT         Aaron Ward            Trolls Band Together       Child                5          10.0  Popcorn,Candy,Soda,Hot Dog,Nachos             48.00           Cash         98.00
# 53         TXN051 2024-02-02        Judy Torres            Trolls Band Together       Child                5          10.0  Popcorn,Candy,Soda,Hot Dog,Nachos             48.00           Cash         98.00
# 54         TXN052 2024-02-02     Henry Peterson                  Next Goal Wins       Adult                1          15.5                              Water              3.50     Debit Card         19.00
# 55         TXN053 2024-02-03        Pamela Gray                  Next Goal Wins       Adult                1          15.5                              Water              3.50     Debit Card           NaN
# 56         TXN054 2024-03-02     Walter Ramirez                       The Shift      Senior                2          12.0                 Pretzel,Soda,Candy             19.75           Cash         43.75
# 57         TXN055 2024-02-04     Virginia James                    Silent Night     Student                1          13.0                 Popcorn,Soda,Candy             18.00    Credit Card         31.00
# 58         TXN056 2024-02-04      Arthur Watson                    Silent Night     Student                1          13.0                 Popcorn,Soda,Candy             18.00    Credit Card         31.00
# 59         TXN057 2024-02-05      Teresa Brooks                             NaN       Adult                2          15.5                Hot Dog,Nachos,Soda             28.00     Debit Card         59.00
# 60         TXN058        NaT        Ralph Kelly                  Ricky Stanicky       Adult                3          15.5                      Popcorn,Candy             24.50           Cash         71.00
# 61         TXN059 2024-02-05    Frances Sanders                  Ricky Stanicky       Adult                3          15.5                      Popcorn,Candy             24.50           Cash           NaN
# 62         TXN060 2024-02-06          Roy Price                  The Bricklayer      Senior                1          12.0                      Water,Pretzel              8.00     Debit Card         20.00

# %%
# Summary statistics
print("CLEANING SUMMARY:")
print("="*100)
print(f"✓ Original rows: {len(df_raw)}")
print(f"✓ Final rows: {len(df_cleaned)}")
print(f"✓ Duplicates removed: {len(df_raw) - len(df_step3)}")
print(f"✓ Dates standardized: {df_cleaned['date'].notna().sum()}")
print(f"✓ Missing dates: {df_cleaned['date'].isna().sum()}")
print(f"✓ Text fields standardized: ticket_type, movie_title, payment_method")
print(f"✓ Concession items cleaned and standardized")
print(f"✓ Missing numeric values handled: 0 missing")

print("\nDATA QUALITY METRICS:")
print("="*100)
print(f"Unique transactions: {df_cleaned['transaction_id'].nunique()}")
print(f"Unique customers: {df_cleaned['customer_name'].nunique()}")
print(f"Unique movies: {df_cleaned['movie_title'].nunique()}")
print(f"Date range: {df_cleaned['date'].min()} to {df_cleaned['date'].max()}")
print(f"Total revenue: ${df_cleaned['total_amount'].sum():.2f}")

# Save cleaned data
output_file = 'cleaned_transactions.csv'
df_cleaned.to_csv(output_file, index=False)
print(f"\n✓ Cleaned data saved to: {output_file}")
# Out:
# CLEANING SUMMARY:
# ====================================================================================================
# ✓ Original rows: 64
# ✓ Final rows: 59
# ✓ Duplicates removed: 5
# ✓ Dates standardized: 50
# ✓ Missing dates: 9
# ✓ Text fields standardized: ticket_type, movie_title, payment_method
# ✓ Concession items cleaned and standardized
# ✓ Missing numeric values handled: 0 missing
#
# DATA QUALITY METRICS:
# ====================================================================================================
# Unique transactions: 59
# Unique customers: 59
# Unique movies: 41
# Date range: 2024-01-15 00:00:00 to 2024-03-02 00:00:00
# Total revenue: $2828.75
#
# ✓ Cleaned data saved to: cleaned_transactions.csv

# %%
# Check for remaining missing values
print("REMAINING MISSING VALUES ANALYSIS:")
print("="*100)

missing_mask = df_cleaned.isnull().any(axis=1)
rows_with_missing = df_cleaned[missing_mask]

print(f"Total rows with ANY missing values: {len(rows_with_missing)}")
print(f"\nMissing values by column:")
print(df_cleaned.isnull().sum())

if len(rows_with_missing) > 0:
    print("\n" + "="*100)
    print("DETAILED VIEW OF ROWS WITH MISSING VALUES:")
    print("="*100)
    print(rows_with_missing[['transaction_id', 'date', 'ticket_price', 'concession_total', 'total_amount']].to_string())
# Out:
# REMAINING MISSING VALUES ANALYSIS:
# ====================================================================================================
# Total rows with ANY missing values: 18
#
# Missing values by column:
# transaction_id      0
# date                9
# customer_name       0
# movie_title         1
# ticket_type         0
# ticket_quantity     0
# ticket_price        0
# concession_items    0
# concession_total    0
# payment_method      1
# total_amount        7
# dtype: int64
#
# ====================================================================================================
# DETAILED VIEW OF ROWS WITH MISSING VALUES:
# ====================================================================================================
#    transaction_id       date  ticket_price  concession_total  total_amount
# 2          TXN003        NaT          12.0             15.75         27.75
# 7          TXN007        NaT          10.0             12.50         32.50
# 9          TXN009        NaT          12.0              8.50         20.50
# 13         TXN012 2024-01-19          15.5             16.50           NaN
# 15         TXN014        NaT          15.5             18.25         33.75
# 19         TXN018 2024-01-21          12.0             21.50         33.50
# 22         TXN021 2024-01-22          15.5             13.25           NaN
# 30         TXN028        NaT          13.0             17.25         30.25
# 31         TXN029 2024-01-25          15.5             19.50           NaN
# 38         TXN037        NaT          13.0              5.50         18.50
# 41         TXN039 2024-01-29          15.5             36.50           NaN
# 47         TXN045        NaT          13.0             24.50         50.50
# 48         TXN046 2024-02-01          10.0             29.25           NaN
# 52         TXN050        NaT          10.0             48.00         98.00
# 55         TXN053 2024-02-03          15.5              3.50           NaN
# 59         TXN057 2024-02-05          15.5             28.00         59.00
# 60         TXN058        NaT          15.5             24.50         71.00
# 61         TXN059 2024-02-05          15.5             24.50           NaN

# %%
# Fix remaining missing values
print("HANDLING REMAINING MISSING VALUES:")
print("="*100)

df_cleaned_final = df_cleaned.copy()

# 1. Fill missing dates with median date
valid_dates = df_cleaned_final['date'].dropna()
if len(valid_dates) > 0:
    median_date = valid_dates.median()
    print(f"Using median date {median_date.date()} for {df_cleaned_final['date'].isna().sum()} missing dates")
    df_cleaned_final['date'].fillna(median_date, inplace=True)

# 2. Fix missing total_amount values - recalculate from components
for idx, row in df_cleaned_final.iterrows():
    if pd.isna(row['total_amount']):
        ticket_total = row['ticket_quantity'] * row['ticket_price']
        concession_total = row['concession_total'] if not pd.isna(row['concession_total']) else 0
        calculated_total = round(ticket_total + concession_total, 2)
        df_cleaned_final.at[idx, 'total_amount'] = calculated_total
        print(f"  TXN: {row['transaction_id']}, Calculated total_amount: ${calculated_total}")

# 3. Fill missing movie_title with "Unknown"
missing_movie_count = df_cleaned_final['movie_title'].isna().sum()
if missing_movie_count > 0:
    print(f"Filled {missing_movie_count} missing movie_title with 'Unknown'")
    df_cleaned_final['movie_title'].fillna('Unknown', inplace=True)

# 4. Fill missing payment_method with "Unknown"
missing_payment_count = df_cleaned_final['payment_method'].isna().sum()
if missing_payment_count > 0:
    print(f"Filled {missing_payment_count} missing payment_method with 'Unknown'")
    df_cleaned_final['payment_method'].fillna('Unknown', inplace=True)

# 5. Fill missing concession_total with 0
missing_concession_count = df_cleaned_final['concession_total'].isna().sum()
if missing_concession_count > 0:
    print(f"Filled {missing_concession_count} missing concession_total with 0")
    df_cleaned_final['concession_total'].fillna(0, inplace=True)

print("\n" + "="*100)
print("VERIFICATION - REMAINING MISSING VALUES:")
print("="*100)
print(df_cleaned_final.isnull().sum())
print(f"\n✓ Total missing values remaining: {df_cleaned_final.isnull().sum().sum()}")
# Out:
# HANDLING REMAINING MISSING VALUES:
# ====================================================================================================
# Using median date 2024-01-26 for 9 missing dates
#   TXN: TXN012, Calculated total_amount: $47.5
#   TXN: TXN021, Calculated total_amount: $28.75
#   TXN: TXN029, Calculated total_amount: $50.5
#   TXN: TXN039, Calculated total_amount: $67.5
#   TXN: TXN046, Calculated total_amount: $59.25
#   TXN: TXN053, Calculated total_amount: $19.0
#   TXN: TXN059, Calculated total_amount: $71.0
# Filled 1 missing movie_title with 'Unknown'
# Filled 1 missing payment_method with 'Unknown'
#
# ====================================================================================================
# VERIFICATION - REMAINING MISSING VALUES:
# ====================================================================================================
# transaction_id      0
# date                0
# customer_name       0
# movie_title         0
# ticket_type         0
# ticket_quantity     0
# ticket_price        0
# concession_items    0
# concession_total    0
# payment_method      0
# total_amount        0
# dtype: int64
#
# ✓ Total missing values remaining: 0

# %%
# Update df_cleaned and resave
df_cleaned = df_cleaned_final.copy()

# Save the completely cleaned data
output_file = 'cleaned_transactions.csv'
df_cleaned.to_csv(output_file, index=False)
print(f"✓ Completely cleaned data (0 missing values) saved to: {output_file}")

# Show final summary
print("\nFINAL DATA QUALITY METRICS:")
print("="*100)
print(f"Total rows: {len(df_cleaned)}")
print(f"Unique transactions: {df_cleaned['transaction_id'].nunique()}")
print(f"Unique customers: {df_cleaned['customer_name'].nunique()}")
print(f"Unique movies: {df_cleaned['movie_title'].nunique()}")
print(f"Date range: {df_cleaned['date'].min().date()} to {df_cleaned['date'].max().date()}")
print(f"Total revenue: ${df_cleaned['total_amount'].sum():.2f}")
print(f"\n✓ DATA IS NOW 100% CLEAN - READY FOR ANALYSIS")
# Out:
# ✓ Completely cleaned data (0 missing values) saved to: cleaned_transactions.csv
#
# FINAL DATA QUALITY METRICS:
# ====================================================================================================
# Total rows: 59
# Unique transactions: 59
# Unique customers: 59
# Unique movies: 42
# Date range: 2024-01-15 to 2024-03-02
# Total revenue: $3172.25
#
# ✓ DATA IS NOW 100% CLEAN - READY FOR ANALYSIS

# %%
# FINAL VERIFICATION - Show the completely cleaned dataset
print("COMPLETE FINAL CLEANED DATASET (100% Clean):")
print("="*100)
print(df_cleaned.to_string())
print("\n" + "="*100)
print(f"Total missing values in df_cleaned: {df_cleaned.isnull().sum().sum()}")
# Out:
# COMPLETE FINAL CLEANED DATASET (100% Clean):
# ====================================================================================================
#    transaction_id       date      customer_name                     movie_title ticket_type  ticket_quantity  ticket_price                   concession_items  concession_total payment_method  total_amount
# 0          TXN001 2024-01-15         John Smith                  Dune: Part Two       Adult                2          15.5                 Popcorn,Soda,Candy             28.50    Credit Card         59.50
# 1          TXN002 2024-01-15      Sarah Johnson                  Dune: Part Two       Adult                2          15.5                 Popcorn,Soda,Candy             28.50    Credit Card         59.50
# 2          TXN003 2024-01-26      Michael Brown                      The Batman      Senior                1          12.0                       Popcorn,Soda             15.75           Cash         27.75
# 3          TXN004 2024-01-16        Emily Davis                     Oppenheimer     Student                3          13.0               Nachos,Pretzel,Water             22.00     Debit Card         61.00
# 5          TXN005 2024-01-16      Robert Wilson                          Barbie       Adult                4          15.5         Hot Dog,Popcorn,Soda,Candy             45.25    Credit Card        107.25
# 6          TXN006 2024-01-17       Jennifer Lee                     Poor Things       Adult                2          15.5                       Popcorn,Soda             18.00           Cash         49.00
# 7          TXN007 2024-01-26     David Martinez      Killers Of The Flower Moon       Child                2          10.0                      Candy,Popcorn             12.50    Credit Card         32.50
# 8          TXN008 2024-01-17      Lisa Anderson                   The Holdovers      Senior                1          12.0                                                 0.00           Cash         12.00
# 9          TXN009 2024-01-26       James Taylor                   The Holdovers      Senior                1          12.0                      Water,Pretzel              8.50     Debit Card         20.50
# 10         TXN010 2024-01-18        Mary Thomas                        Napoleon       Adult                3          15.5                Popcorn,Soda,Nachos             38.75    Credit Card         85.25
# 12         TXN011 2024-01-18  Christopher Moore                           Wonka       Child                4          10.0                 Candy,Popcorn,Soda             35.00           Cash         75.00
# 13         TXN012 2024-01-19     Amanda Jackson              Godzilla Minus One       Adult                2          15.5                       Hot Dog,Soda             16.50    Credit Card         47.50
# 14         TXN013 2024-01-19      Matthew White                The Color Purple     Student                2          13.0                Popcorn,Candy,Water             24.00     Debit Card         50.00
# 15         TXN014 2024-01-26      Daniel Harris                         Ferrari       Adult                1          15.5                        Nachos,Soda             18.25           Cash         33.75
# 16         TXN015 2024-01-20     Jessica Martin                American Fiction       Adult                3          15.5                 Popcorn,Soda,Candy             32.00    Credit Card         78.50
# 17         TXN016 2024-01-20      Paul Thompson                      Mean Girls       Adult                2          15.5                      Pretzel,Water             14.75     Debit Card         45.75
# 18         TXN017 2024-01-20       Karen Garcia                      Mean Girls       Adult                2          15.5                      Pretzel,Water             14.75     Debit Card         45.75
# 19         TXN018 2024-01-21   Steven Rodriguez                   The Beekeeper      Senior                1          12.0                 Popcorn,Soda,Candy             21.50        Unknown         33.50
# 20         TXN019 2024-01-22     Laura Martinez                       Migration       Child                3          10.0                 Candy,Popcorn,Soda             27.00           Cash         57.00
# 21         TXN020 2024-01-22          Kevin Lee    Aquaman And The Lost Kingdom     Student                2          13.0                Hot Dog,Nachos,Soda             25.50    Credit Card         51.50
# 22         TXN021 2024-01-22       Nancy Walker                   The Iron Claw       Adult                1          15.5                      Popcorn,Water             13.25           Cash         28.75
# 24         TXN022 2024-01-23         Brian Hall                  Anyone But You       Adult                2          15.5                 Soda,Candy,Popcorn             29.00     Debit Card         60.00
# 25         TXN023 2024-01-23      Rebecca Allen                  Anyone But You       Adult                2          15.5                 Soda,Candy,Popcorn             29.00     Debit Card         60.00
# 26         TXN024 2024-01-23       George Young                         Maestro      Senior                1          12.0                                                 0.00           Cash         12.00
# 27         TXN025 2024-01-24      Michelle King             Society Of The Snow       Adult                4          15.5        Popcorn,Soda,Hot Dog,Nachos             52.00    Credit Card        114.00
# 28         TXN026 2024-01-24     Charles Wright                      Night Swim       Child                3          10.0                      Candy,Popcorn             18.75           Cash         48.75
# 29         TXN027 2024-01-25    Elizabeth Lopez                      Night Swim       Child                3          10.0                      Candy,Popcorn             18.75           Cash         48.75
# 30         TXN028 2024-01-26       William Hill                        Saltburn     Student                1          13.0                 Pretzel,Water,Soda             17.25     Debit Card         30.25
# 31         TXN029 2024-01-25      Barbara Scott            The Zone Of Interest       Adult                2          15.5                       Popcorn,Soda             19.50    Credit Card         50.50
# 32         TXN030 2024-01-26      Richard Green             All Of Us Strangers       Adult                1          15.5                     Hot Dog,Nachos             20.00           Cash         35.50
# 33         TXN031 2024-01-26       Thomas Baker    The Hunger Games: The Ballad       Adult                3          15.5          Popcorn,Soda,Candy,Nachos             42.00    Credit Card         88.50
# 34         TXN033 2024-01-27    Donald Campbell                            Wish       Child                4          10.0                 Candy,Popcorn,Soda             33.00     Debit Card         73.00
# 35         TXN034 2024-01-28  Patricia Mitchell                            Wish       Child                4          10.0                 Candy,Popcorn,Soda             33.00     Debit Card         73.00
# 36         TXN035 2024-01-28       Mark Roberts           The Boy And The Heron       Adult                2          15.5                Hot Dog,Nachos,Soda             28.75    Credit Card         59.75
# 37         TXN036 2024-01-28     Carol Phillips           The Boy And The Heron       Adult                2          15.5                Hot Dog,Nachos,Soda             28.75    Credit Card         59.75
# 38         TXN037 2024-01-26       Betty Turner                           Wonka     Student                1          13.0                            Popcorn              5.50           Cash         18.50
# 39         TXN038 2024-01-29      Jeffrey Evans    Aquaman And The Lost Kingdom      Senior                1          12.0                         Candy,Soda             11.00           Cash         23.00
# 41         TXN039 2024-01-29    Dorothy Collins                       Freelance       Adult                2          15.5         Popcorn,Hot Dog,Soda,Candy             36.50     Debit Card         67.50
# 42         TXN040 2024-01-30      Jason Stewart  Renaissance: A Film By Beyoncé       Adult                3          15.5                  Nachos,Soda,Water             23.25    Credit Card         69.75
# 43         TXN041 2024-01-30       Helen Morris     Taylor Swift: The Eras Tour       Adult                4          15.5                 Popcorn,Candy,Soda             39.00    Credit Card        101.00
# 44         TXN042 2024-01-31        Gary Rogers     Taylor Swift: The Eras Tour       Adult                4          15.5                 Popcorn,Candy,Soda             39.00    Credit Card        101.00
# 45         TXN043 2024-01-31       Shirley Reed                            Nyad      Senior                1          12.0                      Water,Pretzel              8.25           Cash         20.25
# 46         TXN044 2024-01-31         Larry Cook                          Memory     Student                2          13.0               Hot Dog,Popcorn,Soda             24.50     Debit Card         50.50
# 47         TXN045 2024-01-26     Deborah Bailey                          Memory     Student                2          13.0               Hot Dog,Popcorn,Soda             24.50     Debit Card         50.50
# 48         TXN046 2024-02-01     Gregory Cooper                             Leo       Child                3          10.0                 Candy,Popcorn,Soda             29.25           Cash         59.25
# 49         TXN047 2024-02-01    Ruth Richardson                             Leo       Child                3          10.0                 Candy,Popcorn,Soda             29.25           Cash         59.25
# 50         TXN048 2024-02-01          Frank Cox                     The Marvels       Adult                2          15.5                  Nachos,Soda,Candy             27.00    Credit Card         58.00
# 51         TXN049 2024-02-02       Maria Howard                     The Marvels       Adult                2          15.5                  Nachos,Soda,Candy             27.00    Credit Card         58.00
# 52         TXN050 2024-01-26         Aaron Ward            Trolls Band Together       Child                5          10.0  Popcorn,Candy,Soda,Hot Dog,Nachos             48.00           Cash         98.00
# 53         TXN051 2024-02-02        Judy Torres            Trolls Band Together       Child                5          10.0  Popcorn,Candy,Soda,Hot Dog,Nachos             48.00           Cash         98.00
# 54         TXN052 2024-02-02     Henry Peterson                  Next Goal Wins       Adult                1          15.5                              Water              3.50     Debit Card         19.00
# 55         TXN053 2024-02-03        Pamela Gray                  Next Goal Wins       Adult                1          15.5                              Water              3.50     Debit Card         19.00
# 56         TXN054 2024-03-02     Walter Ramirez                       The Shift      Senior                2          12.0                 Pretzel,Soda,Candy             19.75           Cash         43.75
# 57         TXN055 2024-02-04     Virginia James                    Silent Night     Student                1          13.0                 Popcorn,Soda,Candy             18.00    Credit Card         31.00
# 58         TXN056 2024-02-04      Arthur Watson                    Silent Night     Student                1          13.0                 Popcorn,Soda,Candy             18.00    Credit Card         31.00
# 59         TXN057 2024-02-05      Teresa Brooks                         Unknown       Adult                2          15.5                Hot Dog,Nachos,Soda             28.00     Debit Card         59.00
# 60         TXN058 2024-01-26        Ralph Kelly                  Ricky Stanicky       Adult                3          15.5                      Popcorn,Candy             24.50           Cash         71.00
# 61         TXN059 2024-02-05    Frances Sanders                  Ricky Stanicky       Adult                3          15.5                      Popcorn,Candy             24.50           Cash         71.00
# 62         TXN060 2024-02-06          Roy Price                  The Bricklayer      Senior                1          12.0                      Water,Pretzel              8.00     Debit Card         20.00
#
# ====================================================================================================
# Total missing values in df_cleaned: 0

# %% [markdown]
# ---
# # ASSOCIATION RULE MINING
#
# ## What is Association Rule Mining?
#
# Association rule mining discovers **relationships between items** that are frequently purchased together.
#
# **Example Rule:** `{Popcorn} → {Soda}`
# - **Meaning:** "If a customer buys Popcorn, they are likely to also buy Soda"
#
# **Key Metrics:**
# 1. **Support:** How frequently the itemset appears
# 2. **Confidence:** How often the rule is true
# 3. **Lift:** How much more likely items appear together vs. independently
#
# ---

# %% [markdown]
# ## STEP 9: Prepare Data for Association Rule Mining
#
# **Explanation:** Association rule mining requires a specific data format:
# - Each row = one transaction
# - Each column = one item (binary: bought/not bought)
# - This is called a **transaction-item matrix** or **one-hot encoding**
#
# **What we'll include as "items":**
# - Movie titles (prefixed with "Movie:")
# - Ticket types (prefixed with "Ticket:")
# - Concession items (prefixed with "Concession:")
# - Payment methods (prefixed with "Payment:")

# %%
# Create list of transactions
transactions = []
transaction_ids = []

for idx, row in df_cleaned.iterrows():
    items = []
    
    # Add movie title as an item
    if pd.notna(row['movie_title']) and row['movie_title']:
        items.append(f"Movie:{row['movie_title']}")
    
    # Add ticket type as an item
    if pd.notna(row['ticket_type']) and row['ticket_type']:
        items.append(f"Ticket:{row['ticket_type']}")
    
    # Add concession items
    if pd.notna(row['concession_items']) and row['concession_items']:
        concession_list = row['concession_items'].split(',')
        for item in concession_list:
            item = item.strip()
            if item:
                items.append(f"Concession:{item}")
    
    # Add payment method
    if pd.notna(row['payment_method']) and row['payment_method']:
        items.append(f"Payment:{row['payment_method']}")
    
    if items:  # Only add non-empty transactions
        transactions.append(items)
        transaction_ids.append(row['transaction_id'])

print(f"TRANSACTION LIST CREATED:")
print("="*100)
print(f"✓ Created {len(transactions)} transaction records for analysis")
print("\nSample Transactions (First 10):")
for i in range(min(10, len(transactions))):
    print(f"{transaction_ids[i]}: {transactions[i]}")
# Out:
# TRANSACTION LIST CREATED:
# ====================================================================================================
# ✓ Created 59 transaction records for analysis
#
# Sample Transactions (First 10):
# TXN001: ['Movie:Dune: Part Two', 'Ticket:Adult', 'Concession:Popcorn', 'Concession:Soda', 'Concession:Candy', 'Payment:Credit Card']
# TXN002: ['Movie:Dune: Part Two', 'Ticket:Adult', 'Concession:Popcorn', 'Concession:Soda', 'Concession:Candy', 'Payment:Credit Card']
# TXN003: ['Movie:The Batman', 'Ticket:Senior', 'Concession:Popcorn', 'Concession:Soda', 'Payment:Cash']
# TXN004: ['Movie:Oppenheimer', 'Ticket:Student', 'Concession:Nachos', 'Concession:Pretzel', 'Concession:Water', 'Payment:Debit Card']
# TXN005: ['Movie:Barbie', 'Ticket:Adult', 'Concession:Hot Dog', 'Concession:Popcorn', 'Concession:Soda', 'Concession:Candy', 'Payment:Credit Card']
# TXN006: ['Movie:Poor Things', 'Ticket:Adult', 'Concession:Popcorn', 'Concession:Soda', 'Payment:Cash']
# TXN007: ['Movie:Killers Of The Flower Moon', 'Ticket:Child', 'Concession:Candy', 'Concession:Popcorn', 'Payment:Credit Card']
# TXN008: ['Movie:The Holdovers', 'Ticket:Senior', 'Payment:Cash']
# TXN009: ['Movie:The Holdovers', 'Ticket:Senior', 'Concession:Water', 'Concession:Pretzel', 'Payment:Debit Card']
# TXN010: ['Movie:Napoleon', 'Ticket:Adult', 'Concession:Popcorn', 'Concession:Soda', 'Concession:Nachos', 'Payment:Credit Card']

# %%
# Convert to one-hot encoded DataFrame
te = TransactionEncoder()
te_array = te.fit(transactions).transform(transactions)
df_encoded = pd.DataFrame(te_array, columns=te.columns_)

print("ONE-HOT ENCODED TRANSACTION MATRIX:")
print("="*100)
print(f"Matrix shape: {df_encoded.shape[0]} transactions × {df_encoded.shape[1]} items")
print("\nFirst 10 transactions, First 15 items:")
print(df_encoded.iloc[:10, :15].to_string())
# Out:
# ONE-HOT ENCODED TRANSACTION MATRIX:
# ====================================================================================================
# Matrix shape: 59 transactions × 57 items
#
# First 10 transactions, First 15 items:
#    Concession:Candy  Concession:Hot Dog  Concession:Nachos  Concession:Popcorn  Concession:Pretzel  Concession:Soda  Concession:Water  Movie:All Of Us Strangers  Movie:American Fiction  Movie:Anyone But You  Movie:Aquaman And The Lost Kingdom  Movie:Barbie  Movie:Dune: Part Two  Movie:Ferrari  Movie:Freelance
# 0              True               False              False                True               False             True             False                      False                   False                 False                               False         False                  True          False            False
# 1              True               False              False                True               False             True             False                      False                   False                 False                               False         False                  True          False            False
# 2             False               False              False                True               False             True             False                      False                   False                 False                               False         False                 False          False            False
# 3             False               False               True               False                True            False              True                      False                   False                 False                               False         False                 False          False            False
# 4              True                True              False                True               False             True             False                      False                   False                 False                               False          True                 False          False            False
# 5             False               False              False                True               False             True             False                      False                   False                 False                               False         False                 False          False            False
# 6              True               False              False                True               False            False             False                      False                   False                 False                               False         False                 False          False            False
# 7             False               False              False               False               False            False             False                      False                   False                 False                               False         False                 False          False            False
# 8             False               False              False               False                True            False              True                      False                   False                 False                               False         False                 False          False            False
# 9             False               False               True                True               False             True             False                      False                   False                 False                               False         False                 False          False            False

# %%
# Show complete encoded matrix
print("COMPLETE ONE-HOT ENCODED MATRIX:")
print("="*100)
print(df_encoded.to_string())
# Out:
# COMPLETE ONE-HOT ENCODED MATRIX:
# ====================================================================================================
#     Concession:Candy  Concession:Hot Dog  Concession:Nachos  Concession:Popcorn  Concession:Pretzel  Concession:Soda  Concession:Water  Movie:All Of Us Strangers  Movie:American Fiction  Movie:Anyone But You  Movie:Aquaman And The Lost Kingdom  Movie:Barbie  Movie:Dune: Part Two  Movie:Ferrari  Movie:Freelance  Movie:Godzilla Minus One  Movie:Killers Of The Flower Moon  Movie:Leo  Movie:Maestro  Movie:Mean Girls  Movie:Memory  Movie:Migration  Movie:Napoleon  Movie:Next Goal Wins  Movie:Night Swim  Movie:Nyad  Movie:Oppenheimer  Movie:Poor Things  Movie:Renaissance: A Film By Beyoncé  Movie:Ricky Stanicky  Movie:Saltburn  Movie:Silent Night  Movie:Society Of The Snow  Movie:Taylor Swift: The Eras Tour  Movie:The Batman  Movie:The Beekeeper  Movie:The Boy And The Heron  Movie:The Bricklayer  Movie:The Color Purple  Movie:The Holdovers  Movie:The Hunger Games: The Ballad  Movie:The Iron Claw  Movie:The Marvels  Movie:The Shift  Movie:The Zone Of Interest  Movie:Trolls Band Together  Movie:Unknown  Movie:Wish  Movie:Wonka  Payment:Cash  Payment:Credit Card  Payment:Debit Card  Payment:Unknown  Ticket:Adult  Ticket:Child  Ticket:Senior  Ticket:Student
# 0               True               False              False                True               False             True             False                      False                   False                 False                               False         False                  True          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False        False         False                 True               False            False          True         False          False           False
# 1               True               False              False                True               False             True             False                      False                   False                 False                               False         False                  True          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False        False         False                 True               False            False          True         False          False           False
# 2              False               False              False                True               False             True             False                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False              True                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False        False          True                False               False            False         False         False           True           False
# 3              False               False               True               False                True            False              True                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False               True              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False        False         False                False                True            False         False         False          False            True
# 4               True                True              False                True               False             True             False                      False                   False                 False                               False          True                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False        False         False                 True               False            False          True         False          False           False
# 5              False               False              False                True               False             True             False                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False               True                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False        False          True                False               False            False          True         False          False           False
# 6               True               False              False                True               False            False             False                      False                   False                 False                               False         False                 False          False            False                     False                              True      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False        False         False                 True               False            False         False          True          False           False
# 7              False               False              False               False               False            False             False                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                 True                               False                False              False            False                       False                       False          False       False        False          True                False               False            False         False         False           True           False
# 8              False               False              False               False                True            False              True                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                 True                               False                False              False            False                       False                       False          False       False        False         False                False                True            False         False         False           True           False
# 9              False               False               True                True               False             True             False                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False            True                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False        False         False                 True               False            False          True         False          False           False
# 10              True               False              False                True               False             True             False                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False         True          True                False               False            False         False          True          False           False
# 11             False                True              False               False               False             True             False                      False                   False                 False                               False         False                 False          False            False                      True                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False        False         False                 True               False            False          True         False          False           False
# 12              True               False              False                True               False            False              True                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                    True                False                               False                False              False            False                       False                       False          False       False        False         False                False                True            False         False         False          False            True
# 13             False               False               True               False               False             True             False                      False                   False                 False                               False         False                 False           True            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False        False          True                False               False            False          True         False          False           False
# 14              True               False              False                True               False             True             False                      False                    True                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False        False         False                 True               False            False          True         False          False           False
# 15             False               False              False               False                True            False              True                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False              True         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False        False         False                False                True            False          True         False          False           False
# 16             False               False              False               False                True            False              True                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False              True         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False        False         False                False                True            False          True         False          False           False
# 17              True               False              False                True               False             True             False                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                 True                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False        False         False                False               False             True         False         False           True           False
# 18              True               False              False                True               False             True             False                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False             True           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False        False          True                False               False            False         False          True          False           False
# 19             False                True               True               False               False             True             False                      False                   False                 False                                True         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False        False         False                 True               False            False         False         False          False            True
# 20             False               False              False                True               False            False              True                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                 True              False            False                       False                       False          False       False        False          True                False               False            False          True         False          False           False
# 21              True               False              False                True               False             True             False                      False                   False                  True                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False        False         False                False                True            False          True         False          False           False
# 22              True               False              False                True               False             True             False                      False                   False                  True                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False        False         False                False                True            False          True         False          False           False
# 23             False               False              False               False               False            False             False                      False                   False                 False                               False         False                 False          False            False                     False                             False      False           True             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False        False          True                False               False            False         False         False           True           False
# 24             False                True               True                True               False             True             False                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                       True                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False        False         False                 True               False            False          True         False          False           False
# 25              True               False              False                True               False            False             False                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False              True       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False        False          True                False               False            False         False          True          False           False
# 26              True               False              False                True               False            False             False                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False              True       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False        False          True                False               False            False         False          True          False           False
# 27             False               False              False               False                True             True              True                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False            True               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False        False         False                False                True            False         False         False          False            True
# 28             False               False              False                True               False             True             False                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                        True                       False          False       False        False         False                 True               False            False          True         False          False           False
# 29             False                True               True               False               False            False             False                       True                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False        False          True                False               False            False          True         False          False           False
# 30              True               False               True                True               False             True             False                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                                True                False              False            False                       False                       False          False       False        False         False                 True               False            False          True         False          False           False
# 31              True               False              False                True               False             True             False                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False        True        False         False                False                True            False         False          True          False           False
# 32              True               False              False                True               False             True             False                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False        True        False         False                False                True            False         False          True          False           False
# 33             False                True               True               False               False             True             False                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                         True                 False                   False                False                               False                False              False            False                       False                       False          False       False        False         False                 True               False            False          True         False          False           False
# 34             False                True               True               False               False             True             False                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                         True                 False                   False                False                               False                False              False            False                       False                       False          False       False        False         False                 True               False            False          True         False          False           False
# 35             False               False              False                True               False            False             False                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False         True          True                False               False            False         False         False          False            True
# 36              True               False              False               False               False             True             False                      False                   False                 False                                True         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False        False          True                False               False            False         False         False           True           False
# 37              True                True              False                True               False             True             False                      False                   False                 False                               False         False                 False          False             True                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False        False         False                False                True            False          True         False          False           False
# 38             False               False               True               False               False             True              True                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                  True                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False        False         False                 True               False            False          True         False          False           False
# 39              True               False              False                True               False             True             False                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                               True             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False        False         False                 True               False            False          True         False          False           False
# ...
# 46              True               False               True               False               False             True             False                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False               True            False                       False                       False          False       False        False         False                 True               False            False          True         False          False           False
# 47              True               False               True               False               False             True             False                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False               True            False                       False                       False          False       False        False         False                 True               False            False          True         False          False           False
# 48              True                True               True                True               False             True             False                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                        True          False       False        False          True                False               False            False         False          True          False           False
# 49              True                True               True                True               False             True             False                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                        True          False       False        False          True                False               False            False         False          True          False           False
# 50             False               False              False               False               False            False              True                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                  True             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False        False         False                False                True            False          True         False          False           False
# 51             False               False              False               False               False            False              True                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                  True             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False        False         False                False                True            False          True         False          False           False
# 52              True               False              False               False                True             True             False                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False             True                       False                       False          False       False        False          True                False               False            False         False         False           True           False
# 53              True               False              False                True               False             True             False                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False                True                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False        False         False                 True               False            False         False         False          False            True
# 54              True               False              False                True               False             True             False                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False                True                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False        False         False                 True               False            False         False         False          False            True
# 55             False                True               True               False               False             True             False                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False           True       False        False         False                False                True            False          True         False          False           False
# 56              True               False              False                True               False            False             False                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                  True           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False        False          True                False               False            False          True         False          False           False
# 57              True               False              False                True               False            False             False                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                  True           False               False                      False                              False             False                False                        False                 False                   False                False                               False                False              False            False                       False                       False          False       False        False          True                False               False            False          True         False          False           False
# 58             False               False              False               False                True            False              True                      False                   False                 False                               False         False                 False          False            False                     False                             False      False          False             False         False            False           False                 False             False       False              False              False                                 False                 False           False               False                      False                              False             False                False                        False                  True                   False                False                               False                False              False            False                       False                       False          False       False        False         False                False                True            False         False         False           True           False

# %%
# Item frequency analysis
item_counts = df_encoded.sum().sort_values(ascending=False)

print("ITEM FREQUENCY ANALYSIS:")
print("="*100)
print("How many times each item appears in transactions:\n")
print(item_counts.to_string())
print(f"\n✓ Data prepared for association rule mining")
# Out:
# ITEM FREQUENCY ANALYSIS:
# ====================================================================================================
# How many times each item appears in transactions:
#
# Concession:Soda                         40
# Concession:Popcorn                      36
# Concession:Candy                        31
# Ticket:Adult                            30
# Payment:Cash                            21
# Payment:Credit Card                     20
# Payment:Debit Card                      17
# Concession:Nachos                       15
# Concession:Hot Dog                      13
# Concession:Water                        12
# Ticket:Child                            11
# Ticket:Senior                            9
# Ticket:Student                           9
# Concession:Pretzel                       8
# Movie:The Holdovers                      2
# Movie:Taylor Swift: The Eras Tour        2
# Movie:Silent Night                       2
# Movie:Wish                               2
# Movie:Ricky Stanicky                     2
# Movie:Dune: Part Two                     2
# Movie:Wonka                              2
# Movie:Aquaman And The Lost Kingdom       2
# Movie:Night Swim                         2
# Movie:Next Goal Wins                     2
# Movie:Anyone But You                     2
# Movie:The Boy And The Heron              2
# Movie:Memory                             2
# Movie:Mean Girls                         2
# Movie:Leo                                2
# Movie:The Marvels                        2
# Movie:Trolls Band Together               2
# Movie:The Zone Of Interest               1
# Movie:The Shift                          1
# Movie:Ferrari                            1
# Movie:Unknown                            1
# Movie:The Iron Claw                      1
# Payment:Unknown                          1
# Movie:American Fiction                   1
# Movie:All Of Us Strangers                1
# Movie:Barbie                             1
# Movie:The Beekeeper                      1
# Movie:The Hunger Games: The Ballad       1
# Movie:The Color Purple                   1
# Movie:The Bricklayer                     1
# Movie:Freelance                          1
# Movie:The Batman                         1
# Movie:Society Of The Snow                1
# Movie:Saltburn                           1
# Movie:Poor Things                        1
# Movie:Oppenheimer                        1
# Movie:Nyad                               1
# Movie:Napoleon                           1
# Movie:Migration                          1
# Movie:Maestro                            1
# Movie:Killers Of The Flower Moon         1
# Movie:Godzilla Minus One                 1
# Movie:Renaissance: A Film By Beyoncé     1
#
# ✓ Data prepared for association rule mining

# %% [markdown]
# ---
# ## STEP 10: Apply Apriori Algorithm (Find Frequent Itemsets)
#
# **Explanation:** The Apriori algorithm identifies **itemsets** (combinations of items) that appear frequently together.
#
# **Support Metric:**
# - **Definition:** The proportion of transactions containing the itemset
# - **Formula:** `Support(A) = (# of transactions containing A) / (total # of transactions)`
# - **Example:** If Popcorn appears in 30 out of 50 transactions:
#   - Support = 30/50 = 0.6 (60%)
#
# **Minimum Support Threshold:**
# - We set a threshold (e.g., 0.1 = 10%)
# - Only itemsets appearing in ≥10% of transactions are kept
# - This filters out rare, insignificant patterns

# %%
# Apply Apriori algorithm
min_support = 0.1  # Items must appear in at least 10% of transactions

print("APPLYING APRIORI ALGORITHM:")
print("="*100)
print(f"Minimum support threshold: {min_support} ({min_support*100}%)")
print("This means itemsets must appear in at least 10% of transactions\n")

frequent_itemsets = apriori(df_encoded, min_support=min_support, use_colnames=True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))

print(f"✓ Found {len(frequent_itemsets)} frequent itemsets")
# Out:
# APPLYING APRIORI ALGORITHM:
# ====================================================================================================
# Minimum support threshold: 0.1 (10.0%)
# This means itemsets must appear in at least 10% of transactions
#
# ✓ Found 93 frequent itemsets

# %%
# Itemset size distribution
print("FREQUENT ITEMSETS BY SIZE:")
print("="*100)
print(frequent_itemsets.groupby('length').size())
# Out:
# FREQUENT ITEMSETS BY SIZE:
# ====================================================================================================
# length
# 1    14
# 2    37
# 3    29
# 4    11
# 5     2
# dtype: int64

# %%
# Show all frequent itemsets sorted by support
print("ALL FREQUENT ITEMSETS (Sorted by Support):")
print("="*100)
frequent_itemsets_sorted = frequent_itemsets.sort_values('support', ascending=False)
print(frequent_itemsets_sorted.to_string())
# Out:
# ALL FREQUENT ITEMSETS (Sorted by Support):
# ====================================================================================================
#      support                                                                                    itemsets  length
# 5   0.677966                                                                           (Concession:Soda)       1
# 3   0.610169                                                                        (Concession:Popcorn)       1
# 0   0.525424                                                                          (Concession:Candy)       1
# 10  0.508475                                                                              (Ticket:Adult)       1
# 29  0.474576                                                       (Concession:Popcorn, Concession:Soda)       2
# 14  0.457627                                                      (Concession:Popcorn, Concession:Candy)       2
# 15  0.423729                                                         (Concession:Candy, Concession:Soda)       2
# 41  0.372881                                                             (Ticket:Adult, Concession:Soda)       2
# 7   0.355932                                                                              (Payment:Cash)       1
# 51  0.355932                                     (Concession:Popcorn, Concession:Candy, Concession:Soda)       3
# 8   0.338983                                                                       (Payment:Credit Card)       1
# 39  0.322034                                                      (Payment:Credit Card, Concession:Soda)       2
# 9   0.288136                                                                        (Payment:Debit Card)       1
# 33  0.288136                                                          (Concession:Popcorn, Ticket:Adult)       2
# 79  0.271186                                        (Payment:Credit Card, Ticket:Adult, Concession:Soda)       3
# 49  0.271186                                                         (Payment:Credit Card, Ticket:Adult)       2
# 2   0.254237                                                                         (Concession:Nachos)       1
# 19  0.237288                                                            (Concession:Candy, Ticket:Adult)       2
# 30  0.237288                                                          (Payment:Cash, Concession:Popcorn)       2
# 73  0.237288                                         (Concession:Popcorn, Ticket:Adult, Concession:Soda)       3
# 26  0.220339                                                        (Concession:Soda, Concession:Nachos)       2
# 31  0.220339                                                   (Payment:Credit Card, Concession:Popcorn)       2
# 1   0.220339                                                                        (Concession:Hot Dog)       1
# 23  0.203390                                                       (Concession:Soda, Concession:Hot Dog)       2
# 17  0.203390                                                     (Payment:Credit Card, Concession:Candy)       2
# 59  0.203390                                           (Concession:Candy, Concession:Soda, Ticket:Adult)       3
# 71  0.203390                                  (Payment:Credit Card, Concession:Popcorn, Concession:Soda)       3
# 6   0.203390                                                                          (Concession:Water)       1
# 55  0.203390                                        (Concession:Popcorn, Concession:Candy, Ticket:Adult)       3
# 16  0.203390                                                            (Payment:Cash, Concession:Candy)       2
# 38  0.186441                                                             (Payment:Cash, Concession:Soda)       2
# 34  0.186441                                                          (Concession:Popcorn, Ticket:Child)       2
# 28  0.186441                                                           (Ticket:Adult, Concession:Nachos)       2
# 56  0.186441                                        (Concession:Popcorn, Concession:Candy, Ticket:Child)       3
# 58  0.186441                                    (Payment:Credit Card, Concession:Candy, Concession:Soda)       3
# 11  0.186441                                                                              (Ticket:Child)       1
# 20  0.186441                                                            (Concession:Candy, Ticket:Child)       2
# 76  0.169492                                     (Payment:Credit Card, Concession:Popcorn, Ticket:Adult)       3
# 53  0.169492                                 (Payment:Credit Card, Concession:Popcorn, Concession:Candy)       3
# 52  0.169492                                        (Payment:Cash, Concession:Popcorn, Concession:Candy)       3
# 68  0.169492                                          (Ticket:Adult, Concession:Soda, Concession:Nachos)       3
# 90  0.169492                    (Payment:Credit Card, Concession:Popcorn, Ticket:Adult, Concession:Soda)       4
# 82  0.169492                       (Concession:Popcorn, Concession:Candy, Concession:Soda, Ticket:Adult)       4
# 12  0.152542                                                                             (Ticket:Senior)       1
# 13  0.152542                                                                            (Ticket:Student)       1
# 81  0.152542                (Payment:Credit Card, Concession:Popcorn, Concession:Candy, Concession:Soda)       4
# 44  0.152542                                                      (Concession:Water, Payment:Debit Card)       2
# 40  0.152542                                                       (Payment:Debit Card, Concession:Soda)       2
# 67  0.152542                                   (Payment:Credit Card, Concession:Soda, Concession:Nachos)       3
# 87  0.152542                      (Payment:Credit Card, Concession:Candy, Concession:Soda, Ticket:Adult)       4
# 62  0.152542                                       (Payment:Credit Card, Concession:Candy, Ticket:Adult)       3
# 27  0.152542                                                    (Payment:Credit Card, Concession:Nachos)       2
# 60  0.135593                                           (Concession:Candy, Concession:Soda, Ticket:Child)       3
# 61  0.135593                                              (Payment:Cash, Concession:Candy, Ticket:Child)       3
# 75  0.135593                                            (Payment:Cash, Concession:Popcorn, Ticket:Child)       3
# 69  0.135593                                      (Payment:Credit Card, Ticket:Adult, Concession:Nachos)       3
# 74  0.135593                                         (Concession:Popcorn, Concession:Soda, Ticket:Child)       3
# 70  0.135593                                         (Payment:Cash, Concession:Popcorn, Concession:Soda)       3
# 57  0.135593                                           (Payment:Cash, Concession:Candy, Concession:Soda)       3
# 50  0.135593                                                          (Payment:Debit Card, Ticket:Adult)       2
# 47  0.135593                                                                (Payment:Cash, Ticket:Child)       2
# 42  0.135593                                                             (Concession:Soda, Ticket:Child)       2
# 83  0.135593                       (Concession:Popcorn, Concession:Candy, Concession:Soda, Ticket:Child)       4
# 84  0.135593                          (Payment:Cash, Concession:Popcorn, Concession:Candy, Ticket:Child)       4
# 32  0.135593                                                    (Concession:Popcorn, Payment:Debit Card)       2
# 25  0.135593                                                          (Ticket:Adult, Concession:Hot Dog)       2
# 88  0.135593                     (Payment:Credit Card, Ticket:Adult, Concession:Soda, Concession:Nachos)       4
# 21  0.135593                                                     (Concession:Hot Dog, Concession:Nachos)       2
# 4   0.135593                                                                        (Concession:Pretzel)       1
# 72  0.118644                                   (Concession:Popcorn, Payment:Debit Card, Concession:Soda)       3
# 85  0.118644                   (Payment:Credit Card, Concession:Popcorn, Concession:Candy, Ticket:Adult)       4
# 92  0.118644  (Payment:Credit Card, Concession:Candy, Concession:Soda, Concession:Popcorn, Ticket:Adult)       5
# 66  0.118644                                         (Ticket:Adult, Concession:Soda, Concession:Hot Dog)       3
# 36  0.118644                                                      (Concession:Pretzel, Concession:Water)       2
# 64  0.118644                                   (Concession:Popcorn, Concession:Soda, Concession:Hot Dog)       3
# 63  0.118644                                    (Concession:Soda, Concession:Hot Dog, Concession:Nachos)       3
# 22  0.118644                                                    (Concession:Popcorn, Concession:Hot Dog)       2
# 91  0.101695         (Payment:Cash, Concession:Candy, Concession:Soda, Concession:Popcorn, Ticket:Child)       5
# 18  0.101695                                                      (Payment:Debit Card, Concession:Candy)       2
# 89  0.101695                           (Payment:Cash, Concession:Popcorn, Concession:Soda, Ticket:Child)       4
# 24  0.101695                                                   (Payment:Credit Card, Concession:Hot Dog)       2
# 86  0.101695                             (Payment:Cash, Concession:Candy, Concession:Soda, Ticket:Child)       4
# 35  0.101695                                                        (Concession:Popcorn, Ticket:Student)       2
# 43  0.101695                                                           (Concession:Soda, Ticket:Student)       2
# 37  0.101695                                                    (Concession:Pretzel, Payment:Debit Card)       2
# 65  0.101695                                  (Payment:Credit Card, Concession:Soda, Concession:Hot Dog)       3
# 45  0.101695                                                            (Concession:Water, Ticket:Adult)       2
# 80  0.101695                       (Payment:Cash, Concession:Popcorn, Concession:Candy, Concession:Soda)       4
# 48  0.101695                                                               (Payment:Cash, Ticket:Senior)       2
# 78  0.101695                                               (Payment:Cash, Concession:Soda, Ticket:Child)       3
# 77  0.101695                                  (Concession:Pretzel, Concession:Water, Payment:Debit Card)       3
# 54  0.101695                                  (Concession:Popcorn, Payment:Debit Card, Concession:Candy)       3
# 46  0.101695                                                                (Payment:Cash, Ticket:Adult)       2

# %%
# Single items analysis
print("SINGLE ITEMS (Length=1):")
print("="*100)
single_items = frequent_itemsets[frequent_itemsets['length'] == 1].sort_values('support', ascending=False)
print(single_items.to_string())
print(f"\nThese are the most popular individual items")
# Out:
# SINGLE ITEMS (Length=1):
# ====================================================================================================
#      support               itemsets  length
# 5   0.677966      (Concession:Soda)       1
# 3   0.610169   (Concession:Popcorn)       1
# 0   0.525424     (Concession:Candy)       1
# 10  0.508475         (Ticket:Adult)       1
# 7   0.355932         (Payment:Cash)       1
# 8   0.338983  (Payment:Credit Card)       1
# 9   0.288136   (Payment:Debit Card)       1
# 2   0.254237    (Concession:Nachos)       1
# 1   0.220339   (Concession:Hot Dog)       1
# 6   0.203390     (Concession:Water)       1
# 11  0.186441         (Ticket:Child)       1
# 12  0.152542        (Ticket:Senior)       1
# 13  0.152542       (Ticket:Student)       1
# 4   0.135593   (Concession:Pretzel)       1
#
# These are the most popular individual items

# %%
# Item pairs analysis
print("ITEM PAIRS (Length=2):")
print("="*100)
pairs = frequent_itemsets[frequent_itemsets['length'] == 2].sort_values('support', ascending=False)
print(pairs.to_string())
print(f"\nThese pairs of items are frequently purchased together")
# Out:
# ITEM PAIRS (Length=2):
# ====================================================================================================
#      support                                   itemsets  length
# 29  0.474576      (Concession:Popcorn, Concession:Soda)       2
# 14  0.457627     (Concession:Popcorn, Concession:Candy)       2
# 15  0.423729        (Concession:Candy, Concession:Soda)       2
# 41  0.372881            (Ticket:Adult, Concession:Soda)       2
# 39  0.322034     (Payment:Credit Card, Concession:Soda)       2
# 33  0.288136         (Concession:Popcorn, Ticket:Adult)       2
# 49  0.271186        (Payment:Credit Card, Ticket:Adult)       2
# 19  0.237288           (Concession:Candy, Ticket:Adult)       2
# 30  0.237288         (Payment:Cash, Concession:Popcorn)       2
# 26  0.220339       (Concession:Soda, Concession:Nachos)       2
# 31  0.220339  (Payment:Credit Card, Concession:Popcorn)       2
# 23  0.203390      (Concession:Soda, Concession:Hot Dog)       2
# 17  0.203390    (Payment:Credit Card, Concession:Candy)       2
# 16  0.203390           (Payment:Cash, Concession:Candy)       2
# 38  0.186441            (Payment:Cash, Concession:Soda)       2
# 28  0.186441          (Ticket:Adult, Concession:Nachos)       2
# 20  0.186441           (Concession:Candy, Ticket:Child)       2
# 34  0.186441         (Concession:Popcorn, Ticket:Child)       2
# 44  0.152542     (Concession:Water, Payment:Debit Card)       2
# 40  0.152542      (Payment:Debit Card, Concession:Soda)       2
# 27  0.152542   (Payment:Credit Card, Concession:Nachos)       2
# 47  0.135593               (Payment:Cash, Ticket:Child)       2
# 42  0.135593            (Concession:Soda, Ticket:Child)       2
# 32  0.135593   (Concession:Popcorn, Payment:Debit Card)       2
# 25  0.135593         (Ticket:Adult, Concession:Hot Dog)       2
# 21  0.135593    (Concession:Hot Dog, Concession:Nachos)       2
# 50  0.135593         (Payment:Debit Card, Ticket:Adult)       2
# 36  0.118644     (Concession:Pretzel, Concession:Water)       2
# 22  0.118644   (Concession:Popcorn, Concession:Hot Dog)       2
# 37  0.101695   (Concession:Pretzel, Payment:Debit Card)       2
# 35  0.101695       (Concession:Popcorn, Ticket:Student)       2
# 24  0.101695  (Payment:Credit Card, Concession:Hot Dog)       2
# 43  0.101695          (Concession:Soda, Ticket:Student)       2
# 45  0.101695           (Concession:Water, Ticket:Adult)       2
# 46  0.101695               (Payment:Cash, Ticket:Adult)       2
# 48  0.101695              (Payment:Cash, Ticket:Senior)       2
# 18  0.101695     (Payment:Debit Card, Concession:Candy)       2
#
# These pairs of items are frequently purchased together

# %%
# Item triplets analysis
print("ITEM TRIPLETS (Length=3):")
print("="*100)
triplets = frequent_itemsets[frequent_itemsets['length'] == 3].sort_values('support', ascending=False)
if len(triplets) > 0:
    print(triplets.to_string())
    print(f"\nThese triplets of items are frequently purchased together")
else:
    print("No triplets found with minimum support threshold")
    print("This is normal - larger itemsets are less frequent")
# Out:
# ITEM TRIPLETS (Length=3):
# ====================================================================================================
#      support                                                     itemsets  length
# 51  0.355932      (Concession:Popcorn, Concession:Candy, Concession:Soda)       3
# 79  0.271186         (Payment:Credit Card, Ticket:Adult, Concession:Soda)       3
# 73  0.237288          (Concession:Popcorn, Ticket:Adult, Concession:Soda)       3
# 71  0.203390   (Payment:Credit Card, Concession:Popcorn, Concession:Soda)       3
# 55  0.203390         (Concession:Popcorn, Concession:Candy, Ticket:Adult)       3
# 59  0.203390            (Concession:Candy, Concession:Soda, Ticket:Adult)       3
# 56  0.186441         (Concession:Popcorn, Concession:Candy, Ticket:Child)       3
# 58  0.186441     (Payment:Credit Card, Concession:Candy, Concession:Soda)       3
# 68  0.169492           (Ticket:Adult, Concession:Soda, Concession:Nachos)       3
# 52  0.169492         (Payment:Cash, Concession:Popcorn, Concession:Candy)       3
# 76  0.169492      (Payment:Credit Card, Concession:Popcorn, Ticket:Adult)       3
# 53  0.169492  (Payment:Credit Card, Concession:Popcorn, Concession:Candy)       3
# 67  0.152542    (Payment:Credit Card, Concession:Soda, Concession:Nachos)       3
# 62  0.152542        (Payment:Credit Card, Concession:Candy, Ticket:Adult)       3
# 61  0.135593               (Payment:Cash, Concession:Candy, Ticket:Child)       3
# 75  0.135593             (Payment:Cash, Concession:Popcorn, Ticket:Child)       3
# 60  0.135593            (Concession:Candy, Concession:Soda, Ticket:Child)       3
# 74  0.135593          (Concession:Popcorn, Concession:Soda, Ticket:Child)       3
# 57  0.135593            (Payment:Cash, Concession:Candy, Concession:Soda)       3
# 69  0.135593       (Payment:Credit Card, Ticket:Adult, Concession:Nachos)       3
# 70  0.135593          (Payment:Cash, Concession:Popcorn, Concession:Soda)       3
# 66  0.118644          (Ticket:Adult, Concession:Soda, Concession:Hot Dog)       3
# 72  0.118644    (Concession:Popcorn, Payment:Debit Card, Concession:Soda)       3
# 64  0.118644    (Concession:Popcorn, Concession:Soda, Concession:Hot Dog)       3
# 63  0.118644     (Concession:Soda, Concession:Hot Dog, Concession:Nachos)       3
# 54  0.101695   (Concession:Popcorn, Payment:Debit Card, Concession:Candy)       3
# 77  0.101695   (Concession:Pretzel, Concession:Water, Payment:Debit Card)       3
# 78  0.101695                (Payment:Cash, Concession:Soda, Ticket:Child)       3
# 65  0.101695   (Payment:Credit Card, Concession:Soda, Concession:Hot Dog)       3
#
# These triplets of items are frequently purchased together

# %% [markdown]
# ---
# ## STEP 11: Generate Association Rules
#
# **Explanation:** Association rules show **directional relationships**: "If A, then B"
#
# **Rule Format:** `{Antecedent} → {Consequent}`
# - **Antecedent:** The "if" part (what customer already has)
# - **Consequent:** The "then" part (what they're likely to buy)
#
# **Three Key Metrics:**
#
# 1. **SUPPORT:** Frequency of the complete itemset
#    - `Support(A,B) = # of transactions with both A and B / total transactions`
#    - Higher support = more common combination
#    - Range: 0 to 1
#
# 2. **CONFIDENCE:** Probability of consequent given antecedent
#    - `Confidence(A→B) = Support(A,B) / Support(A)`
#    - Example: If 80% of Popcorn buyers also buy Soda, Confidence = 0.8
#    - Range: 0 to 1
#
# 3. **LIFT:** How much more likely the consequent is when antecedent is present
#    - `Lift(A→B) = Confidence(A→B) / Support(B)`
#    - **Lift > 1:** Positive correlation (A and B go together)
#    - **Lift = 1:** No correlation (independent)
#    - **Lift < 1:** Negative correlation (A and B don't go together)

# %%
# Generate association rules
min_threshold = 0.3  # Minimum confidence threshold

print("GENERATING ASSOCIATION RULES:")
print("="*100)
print(f"Minimum confidence threshold: {min_threshold} ({min_threshold*100}%)")
print("Rules must have at least 30% confidence to be included\n")

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=min_threshold)

if len(rules) > 0:
    # Add readable columns
    rules['antecedents_str'] = rules['antecedents'].apply(lambda x: ', '.join(list(x)))
    rules['consequents_str'] = rules['consequents'].apply(lambda x: ', '.join(list(x)))
    rules['rule'] = rules['antecedents_str'] + ' → ' + rules['consequents_str']
    
    print(f"✓ Generated {len(rules)} association rules\n")
else:
    print("No rules found with the minimum confidence threshold.")
    print("Try lowering the min_threshold value.")
# Out:
# GENERATING ASSOCIATION RULES:
# ====================================================================================================
# Minimum confidence threshold: 0.3 (30.0%)
# Rules must have at least 30% confidence to be included
#
# ✓ Generated 359 association rules

# %%
# Display all rules sorted by LIFT
if len(rules) > 0:
    print("ALL ASSOCIATION RULES - SORTED BY LIFT:")
    print("="*100)
    print("Lift shows how much more likely items are purchased together vs independently")
    print("Higher lift = stronger association\n")
    rules_by_lift = rules.sort_values('lift', ascending=False)
    print(rules_by_lift[['rule', 'support', 'confidence', 'lift']].to_string())
# Out:
# ALL ASSOCIATION RULES - SORTED BY LIFT:
# ====================================================================================================
# Lift shows how much more likely items are purchased together vs independently
# Higher lift = stronger association
#
#                                                                                           rule   support  confidence      lift
# 335         Ticket:Child → Payment:Cash, Concession:Popcorn, Concession:Candy, Concession:Soda  0.101695    0.545455  5.363636
# 314         Payment:Cash, Concession:Popcorn, Concession:Candy, Concession:Soda → Ticket:Child  0.101695    1.000000  5.363636
# 186                                  Concession:Pretzel → Concession:Water, Payment:Debit Card  0.101695    0.750000  4.916667
# 187                                  Concession:Water → Concession:Pretzel, Payment:Debit Card  0.101695    0.500000  4.916667
# 184                                  Concession:Pretzel, Payment:Debit Card → Concession:Water  0.101695    1.000000  4.916667
# 185                                  Concession:Water, Payment:Debit Card → Concession:Pretzel  0.101695    0.666667  4.916667
# 320         Payment:Cash, Concession:Popcorn, Concession:Candy → Concession:Soda, Ticket:Child  0.101695    0.600000  4.425000
# 333         Concession:Soda, Ticket:Child → Payment:Cash, Concession:Popcorn, Concession:Candy  0.101695    0.750000  4.425000
# 40                                                       Concession:Water → Concession:Pretzel  0.118644    0.583333  4.302083
# 39                                                       Concession:Pretzel → Concession:Water  0.118644    0.875000  4.302083
# 237                          Payment:Cash, Concession:Popcorn, Concession:Candy → Ticket:Child  0.135593    0.800000  4.290909
# 247                          Ticket:Child → Payment:Cash, Concession:Popcorn, Concession:Candy  0.135593    0.727273  4.290909
# 334         Concession:Popcorn, Ticket:Child → Payment:Cash, Concession:Candy, Concession:Soda  0.101695    0.545455  4.022727
# 301                           Ticket:Child → Payment:Cash, Concession:Popcorn, Concession:Soda  0.101695    0.545455  4.022727
# 332         Concession:Candy, Ticket:Child → Payment:Cash, Concession:Popcorn, Concession:Soda  0.101695    0.545455  4.022727
# 267                             Ticket:Child → Payment:Cash, Concession:Candy, Concession:Soda  0.101695    0.545455  4.022727
# 292                           Payment:Cash, Concession:Popcorn, Concession:Soda → Ticket:Child  0.101695    0.750000  4.022727
# 319         Payment:Cash, Concession:Candy, Concession:Soda → Concession:Popcorn, Ticket:Child  0.101695    0.750000  4.022727
# 322         Payment:Cash, Concession:Popcorn, Concession:Soda → Concession:Candy, Ticket:Child  0.101695    0.750000  4.022727
# 258                             Payment:Cash, Concession:Candy, Concession:Soda → Ticket:Child  0.101695    0.750000  4.022727
# 262                             Payment:Cash, Concession:Candy → Concession:Soda, Ticket:Child  0.101695    0.500000  3.687500
# 328         Payment:Cash, Concession:Candy → Concession:Popcorn, Concession:Soda, Ticket:Child  0.101695    0.500000  3.687500
# 327         Concession:Popcorn, Concession:Soda, Ticket:Child → Payment:Cash, Concession:Candy  0.101695    0.750000  3.687500
# 266                             Concession:Soda, Ticket:Child → Payment:Cash, Concession:Candy  0.101695    0.750000  3.687500
# 110                                              Payment:Cash, Concession:Candy → Ticket:Child  0.135593    0.666667  3.575758
# 244                          Concession:Popcorn, Ticket:Child → Payment:Cash, Concession:Candy  0.135593    0.727273  3.575758
# 114                                              Ticket:Child → Payment:Cash, Concession:Candy  0.135593    0.727273  3.575758
# 242                          Payment:Cash, Concession:Candy → Concession:Popcorn, Ticket:Child  0.135593    0.666667  3.575758
# 330         Payment:Cash, Concession:Popcorn → Concession:Candy, Concession:Soda, Ticket:Child  0.101695    0.428571  3.160714
# 296                           Payment:Cash, Concession:Popcorn → Concession:Soda, Ticket:Child  0.101695    0.428571  3.160714
# 325         Concession:Candy, Concession:Soda, Ticket:Child → Payment:Cash, Concession:Popcorn  0.101695    0.750000  3.160714
# 300                           Concession:Soda, Ticket:Child → Payment:Cash, Concession:Popcorn  0.101695    0.750000  3.160714
# 245                          Concession:Candy, Ticket:Child → Payment:Cash, Concession:Popcorn  0.135593    0.727273  3.064935
# 177                                            Ticket:Child → Payment:Cash, Concession:Popcorn  0.135593    0.727273  3.064935
# 173                                            Payment:Cash, Concession:Popcorn → Ticket:Child  0.135593    0.571429  3.064935
# 241                          Payment:Cash, Concession:Popcorn → Concession:Candy, Ticket:Child  0.135593    0.571429  3.064935
# 188                                  Payment:Debit Card → Concession:Pretzel, Concession:Water  0.101695    0.352941  2.974790
# 183                                  Concession:Pretzel, Concession:Water → Payment:Debit Card  0.101695    0.857143  2.974790
# 326         Concession:Popcorn, Concession:Candy, Ticket:Child → Payment:Cash, Concession:Soda  0.101695    0.545455  2.925620
# 265                             Concession:Candy, Ticket:Child → Payment:Cash, Concession:Soda  0.101695    0.545455  2.925620
# 189                                               Payment:Cash, Concession:Soda → Ticket:Child  0.101695    0.545455  2.925620
# 299                           Concession:Popcorn, Ticket:Child → Payment:Cash, Concession:Soda  0.101695    0.545455  2.925620
# 263                             Payment:Cash, Concession:Soda → Concession:Candy, Ticket:Child  0.101695    0.545455  2.925620
# 192                                               Ticket:Child → Payment:Cash, Concession:Soda  0.101695    0.545455  2.925620
# 297                           Payment:Cash, Concession:Soda → Concession:Popcorn, Ticket:Child  0.101695    0.545455  2.925620
# 329         Payment:Cash, Concession:Soda → Concession:Popcorn, Concession:Candy, Ticket:Child  0.101695    0.545455  2.925620
# 353  Payment:Credit Card, Concession:Popcorn → Concession:Candy, Concession:Soda, Ticket:Adult  0.118644    0.538462  2.647436
# 348  Concession:Candy, Concession:Soda, Ticket:Adult → Payment:Credit Card, Concession:Popcorn  0.118644    0.583333  2.647436
# 52                                                       Payment:Debit Card → Concession:Water  0.152542    0.529412  2.602941
# 41                                                     Concession:Pretzel → Payment:Debit Card  0.101695    0.750000  2.602941
# 42                                                     Payment:Debit Card → Concession:Pretzel  0.101695    0.352941  2.602941
# 51                                                       Concession:Water → Payment:Debit Card  0.152542    0.750000  2.602941
# 350  Concession:Popcorn, Concession:Soda, Ticket:Adult → Payment:Credit Card, Concession:Candy  0.118644    0.500000  2.458333
# 351  Payment:Credit Card, Concession:Candy → Concession:Popcorn, Concession:Soda, Ticket:Adult  0.118644    0.583333  2.458333
# 355  Concession:Candy, Ticket:Adult → Payment:Credit Card, Concession:Popcorn, Concession:Soda  0.118644    0.500000  2.458333
# 344  Payment:Credit Card, Concession:Popcorn, Concession:Soda → Concession:Candy, Ticket:Adult  0.118644    0.583333  2.458333
# 121                                    Concession:Soda, Concession:Nachos → Concession:Hot Dog  0.118644    0.538462  2.443787
# 123                                    Concession:Hot Dog → Concession:Soda, Concession:Nachos  0.118644    0.538462  2.443787
# 13                                                      Concession:Hot Dog → Concession:Nachos  0.135593    0.615385  2.420513
# 14                                                      Concession:Nachos → Concession:Hot Dog  0.135593    0.533333  2.420513
# 287                     Ticket:Adult, Concession:Soda → Payment:Credit Card, Concession:Nachos  0.135593    0.363636  2.383838
# 286                     Payment:Credit Card, Concession:Nachos → Ticket:Adult, Concession:Soda  0.135593    0.888889  2.383838
# 290                     Payment:Credit Card → Ticket:Adult, Concession:Soda, Concession:Nachos  0.135593    0.400000  2.360000
# 283                     Ticket:Adult, Concession:Soda, Concession:Nachos → Payment:Credit Card  0.135593    0.800000  2.360000
# 124                                    Concession:Nachos → Concession:Soda, Concession:Hot Dog  0.118644    0.466667  2.294444
# 120                                    Concession:Soda, Concession:Hot Dog → Concession:Nachos  0.118644    0.583333  2.294444
# 252                   Payment:Credit Card, Concession:Popcorn → Concession:Candy, Ticket:Adult  0.118644    0.538462  2.269231
# 289                     Concession:Soda, Concession:Nachos → Payment:Credit Card, Ticket:Adult  0.135593    0.615385  2.269231
# 256                   Concession:Candy, Ticket:Adult → Payment:Credit Card, Concession:Popcorn  0.118644    0.500000  2.269231
# 284                     Payment:Credit Card, Ticket:Adult → Concession:Soda, Concession:Nachos  0.135593    0.500000  2.269231
# 285                     Payment:Credit Card, Concession:Soda → Ticket:Adult, Concession:Nachos  0.135593    0.421053  2.258373
# 288                     Ticket:Adult, Concession:Nachos → Payment:Credit Card, Concession:Soda  0.135593    0.727273  2.258373
# 278                      Payment:Credit Card → Concession:Candy, Concession:Soda, Ticket:Adult  0.152542    0.450000  2.212500
# 271                      Concession:Candy, Concession:Soda, Ticket:Adult → Payment:Credit Card  0.152542    0.750000  2.212500
# 357  Concession:Popcorn, Ticket:Adult → Payment:Credit Card, Concession:Candy, Concession:Soda  0.118644    0.411765  2.208556
# 341  Payment:Credit Card, Concession:Candy, Concession:Soda → Concession:Popcorn, Ticket:Adult  0.118644    0.636364  2.208556
# 85                                         Concession:Popcorn, Concession:Candy → Ticket:Child  0.186441    0.407407  2.185185
# 90                                         Ticket:Child → Concession:Popcorn, Concession:Candy  0.186441    1.000000  2.185185
# 243                          Payment:Cash, Ticket:Child → Concession:Popcorn, Concession:Candy  0.135593    1.000000  2.185185
# 323         Payment:Cash, Concession:Soda, Ticket:Child → Concession:Popcorn, Concession:Candy  0.101695    1.000000  2.185185
# 235                       Concession:Soda, Ticket:Child → Concession:Popcorn, Concession:Candy  0.135593    1.000000  2.185185
# 196                                        Payment:Credit Card → Ticket:Adult, Concession:Soda  0.271186    0.800000  2.145455
# 150                                      Payment:Credit Card → Ticket:Adult, Concession:Nachos  0.135593    0.400000  2.145455
# 149                                      Ticket:Adult, Concession:Nachos → Payment:Credit Card  0.135593    0.727273  2.145455
# 195                                        Ticket:Adult, Concession:Soda → Payment:Credit Card  0.271186    0.727273  2.145455
# 261                             Concession:Candy, Concession:Soda, Ticket:Child → Payment:Cash  0.101695    0.750000  2.107143
# 331         Payment:Cash, Ticket:Child → Concession:Popcorn, Concession:Candy, Concession:Soda  0.101695    0.750000  2.107143
# 295                           Concession:Popcorn, Concession:Soda, Ticket:Child → Payment:Cash  0.101695    0.750000  2.107143
# 318         Concession:Popcorn, Concession:Candy, Concession:Soda, Ticket:Child → Payment:Cash  0.101695    0.750000  2.107143
# 191                                               Concession:Soda, Ticket:Child → Payment:Cash  0.101695    0.750000  2.107143
# 312                    Payment:Credit Card → Concession:Popcorn, Ticket:Adult, Concession:Soda  0.169492    0.500000  2.107143
# 305                    Concession:Popcorn, Ticket:Adult, Concession:Soda → Payment:Credit Card  0.169492    0.714286  2.107143
# 358  Payment:Credit Card → Concession:Popcorn, Concession:Candy, Concession:Soda, Ticket:Adult  0.118644    0.350000  2.065000
# 340  Concession:Popcorn, Concession:Candy, Concession:Soda, Ticket:Adult → Payment:Credit Card  0.118644    0.700000  2.065000
# 306                    Payment:Credit Card, Concession:Popcorn → Ticket:Adult, Concession:Soda  0.169492    0.769231  2.062937
# 311                    Ticket:Adult, Concession:Soda → Payment:Credit Card, Concession:Popcorn  0.169492    0.454545  2.062937
# 236                       Ticket:Child → Concession:Popcorn, Concession:Candy, Concession:Soda  0.135593    0.727273  2.043290
# 55                                                                 Ticket:Child → Payment:Cash  0.135593    0.727273  2.043290
# 175                                            Concession:Popcorn, Ticket:Child → Payment:Cash  0.135593    0.727273  2.043290
# 240                          Concession:Popcorn, Concession:Candy, Ticket:Child → Payment:Cash  0.135593    0.727273  2.043290
# 112                                              Concession:Candy, Ticket:Child → Payment:Cash  0.135593    0.727273  2.043290
# 228                       Concession:Popcorn, Concession:Candy, Concession:Soda → Ticket:Child  0.135593    0.380952  2.043290
# 54                                                                 Payment:Cash → Ticket:Child  0.135593    0.380952  2.043290
# 113                                              Payment:Cash → Concession:Candy, Ticket:Child  0.135593    0.380952  2.043290
# 246                          Payment:Cash → Concession:Popcorn, Concession:Candy, Ticket:Child  0.135593    0.380952  2.043290
# 176                                            Payment:Cash → Concession:Popcorn, Ticket:Child  0.135593    0.380952  2.043290
# 139                                   Concession:Soda, Concession:Nachos → Payment:Credit Card  0.152542    0.692308  2.042308
# 140                                   Payment:Credit Card → Concession:Soda, Concession:Nachos  0.152542    0.450000  2.042308
# 255                   Concession:Popcorn, Ticket:Adult → Payment:Credit Card, Concession:Candy  0.118644    0.411765  2.024510
# 253                   Payment:Credit Card, Concession:Candy → Concession:Popcorn, Ticket:Adult  0.118644    0.583333  2.024510
# 272                      Payment:Credit Card, Concession:Candy → Concession:Soda, Ticket:Adult  0.152542    0.750000  2.011364
# 277                      Concession:Soda, Ticket:Adult → Payment:Credit Card, Concession:Candy  0.152542    0.409091  2.011364
# 273                      Payment:Credit Card, Concession:Soda → Concession:Candy, Ticket:Adult  0.152542    0.473684  1.996241
# 276                      Concession:Candy, Ticket:Adult → Payment:Credit Card, Concession:Soda  0.152542    0.642857  1.996241
# 280                     Payment:Credit Card, Ticket:Adult, Concession:Soda → Concession:Nachos  0.135593    0.500000  1.966667
# 147                                      Payment:Credit Card, Ticket:Adult → Concession:Nachos  0.135593    0.500000  1.966667
# 151                                      Concession:Nachos → Payment:Credit Card, Ticket:Adult  0.135593    0.533333  1.966667
# 291                     Concession:Nachos → Payment:Credit Card, Ticket:Adult, Concession:Soda  0.135593    0.533333  1.966667
# 260                             Payment:Cash, Concession:Soda, Ticket:Child → Concession:Candy  0.101695    1.000000  1.903226
# 11                                                             Concession:Candy → Ticket:Child  0.186441    0.354839  1.903226
# 12                                                             Ticket:Child → Concession:Candy  0.186441    1.000000  1.903226
# 230                       Concession:Popcorn, Concession:Soda, Ticket:Child → Concession:Candy  0.135593    1.000000  1.903226
# 111                                              Payment:Cash, Ticket:Child → Concession:Candy  0.135593    1.000000  1.903226
# 317         Payment:Cash, Concession:Popcorn, Concession:Soda, Ticket:Child → Concession:Candy  0.101695    1.000000  1.903226
# 238                          Payment:Cash, Concession:Popcorn, Ticket:Child → Concession:Candy  0.135593    1.000000  1.903226
# 108                                           Concession:Soda, Ticket:Child → Concession:Candy  0.135593    1.000000  1.903226
# 86                                         Concession:Popcorn, Ticket:Child → Concession:Candy  0.186441    1.000000  1.903226
# 89                                         Concession:Candy → Concession:Popcorn, Ticket:Child  0.186441    0.354839  1.903226
# 118                                       Payment:Credit Card → Concession:Candy, Ticket:Adult  0.152542    0.450000  1.896429
# 117                                       Concession:Candy, Ticket:Adult → Payment:Credit Card  0.152542    0.642857  1.896429
# 342  Payment:Credit Card, Concession:Popcorn, Concession:Candy → Concession:Soda, Ticket:Adult  0.118644    0.700000  1.877273
# 356  Concession:Soda, Ticket:Adult → Payment:Credit Card, Concession:Popcorn, Concession:Candy  0.118644    0.318182  1.877273
# 56                                                                Ticket:Senior → Payment:Cash  0.101695    0.666667  1.873016
# 137                                   Payment:Credit Card, Concession:Soda → Concession:Nachos  0.152542    0.473684  1.863158
# 141                                   Concession:Nachos → Payment:Credit Card, Concession:Soda  0.152542    0.600000  1.863158
# 309                    Concession:Popcorn, Ticket:Adult → Payment:Credit Card, Concession:Soda  0.169492    0.588235  1.826625
# 308                    Payment:Credit Card, Concession:Soda → Concession:Popcorn, Ticket:Adult  0.169492    0.526316  1.826625
# 349  Concession:Popcorn, Concession:Candy, Ticket:Adult → Payment:Credit Card, Concession:Soda  0.118644    0.583333  1.811404
# 352  Payment:Credit Card, Concession:Soda → Concession:Popcorn, Concession:Candy, Ticket:Adult  0.118644    0.368421  1.811404
# 146                                          Concession:Nachos → Ticket:Adult, Concession:Soda  0.169492    0.666667  1.787879
# 142                                          Ticket:Adult, Concession:Soda → Concession:Nachos  0.169492    0.454545  1.787879
# 23                                                     Payment:Credit Card → Concession:Nachos  0.152542    0.450000  1.770000
# 24                                                     Concession:Nachos → Payment:Credit Card  0.152542    0.600000  1.770000
# 324         Payment:Cash, Concession:Popcorn, Ticket:Child → Concession:Candy, Concession:Soda  0.101695    0.750000  1.770000
# 264                             Payment:Cash, Ticket:Child → Concession:Candy, Concession:Soda  0.101695    0.750000  1.770000
# 148                                      Payment:Credit Card, Concession:Nachos → Ticket:Adult  0.135593    0.888889  1.748148
# 282                     Payment:Credit Card, Concession:Soda, Concession:Nachos → Ticket:Adult  0.135593    0.888889  1.748148
# 181                                     Payment:Credit Card → Concession:Popcorn, Ticket:Adult  0.169492    0.500000  1.735294
# 180                                     Concession:Popcorn, Ticket:Adult → Payment:Credit Card  0.169492    0.588235  1.735294
# 257                   Payment:Credit Card → Concession:Popcorn, Concession:Candy, Ticket:Adult  0.118644    0.350000  1.720833
# 251                   Concession:Popcorn, Concession:Candy, Ticket:Adult → Payment:Credit Card  0.118644    0.583333  1.720833
# 232                       Concession:Popcorn, Ticket:Child → Concession:Candy, Concession:Soda  0.135593    0.727273  1.716364
# 109                                           Ticket:Child → Concession:Candy, Concession:Soda  0.135593    0.727273  1.716364
# 233                       Concession:Candy, Concession:Soda → Concession:Popcorn, Ticket:Child  0.135593    0.320000  1.716364
# 106                                           Concession:Candy, Concession:Soda → Ticket:Child  0.135593    0.320000  1.716364
# 194                                        Payment:Credit Card, Concession:Soda → Ticket:Adult  0.271186    0.842105  1.656140
# 197                                        Ticket:Adult → Payment:Credit Card, Concession:Soda  0.271186    0.533333  1.656140
# 346  Payment:Credit Card, Concession:Popcorn, Ticket:Adult → Concession:Candy, Concession:Soda  0.118644    0.700000  1.652000
# 239                          Payment:Cash, Concession:Candy, Ticket:Child → Concession:Popcorn  0.135593    1.000000  1.638889
# 174                                            Payment:Cash, Ticket:Child → Concession:Popcorn  0.135593    1.000000  1.638889
# 303                    Payment:Credit Card, Concession:Popcorn, Concession:Soda → Ticket:Adult  0.169492    0.833333  1.638889
# 37                                                           Ticket:Child → Concession:Popcorn  0.186441    1.000000  1.638889
# 87                                         Concession:Candy, Ticket:Child → Concession:Popcorn  0.186441    1.000000  1.638889
# 294                           Payment:Cash, Concession:Soda, Ticket:Child → Concession:Popcorn  0.101695    1.000000  1.638889
# 77                                   Payment:Debit Card, Concession:Candy → Concession:Popcorn  0.101695    1.000000  1.638889
# 231                       Concession:Candy, Concession:Soda, Ticket:Child → Concession:Popcorn  0.135593    1.000000  1.638889
# 343  Payment:Credit Card, Concession:Candy, Ticket:Adult → Concession:Popcorn, Concession:Soda  0.118644    0.777778  1.638889
# 315         Payment:Cash, Concession:Candy, Concession:Soda, Ticket:Child → Concession:Popcorn  0.101695    1.000000  1.638889
# 171                                         Concession:Soda, Ticket:Child → Concession:Popcorn  0.135593    1.000000  1.638889
# 36                                                           Concession:Popcorn → Ticket:Child  0.186441    0.305556  1.638889
# 88                                         Concession:Popcorn → Concession:Candy, Ticket:Child  0.186441    0.305556  1.638889
# 313                    Ticket:Adult → Payment:Credit Card, Concession:Popcorn, Concession:Soda  0.169492    0.333333  1.638889
# 214                Concession:Candy, Concession:Soda → Payment:Credit Card, Concession:Popcorn  0.152542    0.360000  1.633846
# 209                Payment:Credit Card, Concession:Popcorn → Concession:Candy, Concession:Soda  0.152542    0.692308  1.633846
# 279                      Ticket:Adult → Payment:Credit Card, Concession:Candy, Concession:Soda  0.152542    0.300000  1.609091
# 268                      Payment:Credit Card, Concession:Candy, Concession:Soda → Ticket:Adult  0.152542    0.818182  1.609091
# 213                Concession:Popcorn, Concession:Soda → Payment:Credit Card, Concession:Candy  0.152542    0.321429  1.580357
# 321         Payment:Cash, Concession:Candy, Ticket:Child → Concession:Popcorn, Concession:Soda  0.101695    0.750000  1.580357
# 210                Payment:Credit Card, Concession:Candy → Concession:Popcorn, Concession:Soda  0.152542    0.750000  1.580357
# 298                           Payment:Cash, Ticket:Child → Concession:Popcorn, Concession:Soda  0.101695    0.750000  1.580357
# 57                                                          Payment:Credit Card → Ticket:Adult  0.271186    0.800000  1.573333
# 58                                                          Ticket:Adult → Payment:Credit Card  0.271186    0.533333  1.573333
# 172                                         Ticket:Child → Concession:Popcorn, Concession:Soda  0.135593    0.727273  1.532468
# 234                       Concession:Candy, Ticket:Child → Concession:Popcorn, Concession:Soda  0.135593    0.727273  1.532468
# 336  Payment:Credit Card, Concession:Popcorn, Concession:Candy, Concession:Soda → Ticket:Adult  0.118644    0.777778  1.529630
# 145                                          Ticket:Adult → Concession:Soda, Concession:Nachos  0.169492    0.333333  1.512821
# 144                                          Concession:Soda, Concession:Nachos → Ticket:Adult  0.169492    0.769231  1.512821
# 182                                     Ticket:Adult → Payment:Credit Card, Concession:Popcorn  0.169492    0.333333  1.512821
# 178                                     Payment:Credit Card, Concession:Popcorn → Ticket:Adult  0.169492    0.769231  1.512821
# 224                       Concession:Candy, Ticket:Adult → Concession:Popcorn, Concession:Soda  0.169492    0.714286  1.505102
# 221                       Concession:Popcorn, Concession:Soda → Concession:Candy, Ticket:Adult  0.169492    0.357143  1.505102
# 302                    Payment:Credit Card, Concession:Popcorn, Ticket:Adult → Concession:Soda  0.169492    1.000000  1.475000
# 138                                   Payment:Credit Card, Concession:Nachos → Concession:Soda  0.152542    1.000000  1.475000
# 130                                  Concession:Soda, Concession:Hot Dog → Payment:Credit Card  0.101695    0.500000  1.475000
# 129                                  Payment:Credit Card, Concession:Hot Dog → Concession:Soda  0.101695    1.000000  1.475000
# 198                                        Concession:Soda → Payment:Credit Card, Ticket:Adult  0.271186    0.400000  1.475000
# 119                                       Ticket:Adult → Payment:Credit Card, Concession:Candy  0.152542    0.300000  1.475000
# 125                                   Concession:Popcorn, Concession:Hot Dog → Concession:Soda  0.118644    1.000000  1.475000
# 131                                  Payment:Credit Card → Concession:Soda, Concession:Hot Dog  0.101695    0.300000  1.475000
# 269                      Payment:Credit Card, Concession:Candy, Ticket:Adult → Concession:Soda  0.152542    1.000000  1.475000
# 193                                        Payment:Credit Card, Ticket:Adult → Concession:Soda  0.271186    1.000000  1.475000
# 115                                       Payment:Credit Card, Concession:Candy → Ticket:Adult  0.152542    0.750000  1.475000
# 281                     Payment:Credit Card, Ticket:Adult, Concession:Nachos → Concession:Soda  0.135593    1.000000  1.475000
# 338  Payment:Credit Card, Concession:Popcorn, Concession:Candy, Ticket:Adult → Concession:Soda  0.118644    1.000000  1.475000
# 75                                  Concession:Candy → Payment:Credit Card, Concession:Popcorn  0.169492    0.322581  1.464020
# 71                                  Payment:Credit Card, Concession:Popcorn → Concession:Candy  0.169492    0.769231  1.464020
# 133                                         Ticket:Adult, Concession:Soda → Concession:Hot Dog  0.118644    0.318182  1.444056
# 136                                         Concession:Hot Dog → Ticket:Adult, Concession:Soda  0.118644    0.538462  1.444056
# 25                                                            Ticket:Adult → Concession:Nachos  0.186441    0.366667  1.442222
# 26                                                            Concession:Nachos → Ticket:Adult  0.186441    0.733333  1.442222
# 132                                  Concession:Hot Dog → Payment:Credit Card, Concession:Soda  0.101695    0.461538  1.433198
# 128                                  Payment:Credit Card, Concession:Soda → Concession:Hot Dog  0.101695    0.315789  1.433198
# 0                                                        Concession:Popcorn → Concession:Candy  0.457627    0.750000  1.427419
# 200                       Payment:Cash, Concession:Popcorn, Concession:Soda → Concession:Candy  0.101695    0.750000  1.427419
# 206                Payment:Credit Card, Concession:Popcorn, Concession:Soda → Concession:Candy  0.152542    0.750000  1.427419
# 61                                      Concession:Popcorn, Concession:Soda → Concession:Candy  0.355932    0.750000  1.427419
# 1                                                        Concession:Candy → Concession:Popcorn  0.457627    0.870968  1.427419
# 76                                   Concession:Popcorn, Payment:Debit Card → Concession:Candy  0.101695    0.750000  1.427419
# 64                                      Concession:Candy → Concession:Popcorn, Concession:Soda  0.355932    0.677419  1.427419
# 81                                         Concession:Candy, Ticket:Adult → Concession:Popcorn  0.203390    0.857143  1.404762
# 82                                         Concession:Popcorn → Concession:Candy, Ticket:Adult  0.203390    0.333333  1.404762
# 45                                                       Concession:Soda → Payment:Credit Card  0.322034    0.475000  1.401250
# 44                                                       Payment:Credit Card → Concession:Soda  0.322034    0.950000  1.401250
# 223                       Concession:Candy, Concession:Soda → Concession:Popcorn, Ticket:Adult  0.169492    0.400000  1.388235
# 222                       Concession:Popcorn, Ticket:Adult → Concession:Candy, Concession:Soda  0.169492    0.588235  1.388235
# 92                                            Payment:Cash, Concession:Soda → Concession:Candy  0.135593    0.727273  1.384164
# 248                   Payment:Credit Card, Concession:Popcorn, Concession:Candy → Ticket:Adult  0.118644    0.700000  1.376667
# 62                                      Concession:Candy, Concession:Soda → Concession:Popcorn  0.355932    0.840000  1.376667
# 63                                      Concession:Popcorn → Concession:Candy, Concession:Soda  0.355932    0.583333  1.376667
# 67                                         Payment:Cash, Concession:Candy → Concession:Popcorn  0.169492    0.833333  1.365741
# 72                                  Payment:Credit Card, Concession:Candy → Concession:Popcorn  0.169492    0.833333  1.365741
# 219                       Concession:Candy, Concession:Soda, Ticket:Adult → Concession:Popcorn  0.169492    0.833333  1.365741
# 18                                                    Payment:Credit Card → Concession:Hot Dog  0.101695    0.300000  1.361538
# 160                                  Concession:Soda → Payment:Credit Card, Concession:Popcorn  0.203390    0.300000  1.361538
# 16                                                        Concession:Soda → Concession:Hot Dog  0.203390    0.300000  1.361538
# 19                                                    Concession:Hot Dog → Payment:Credit Card  0.101695    0.461538  1.361538
# 17                                                        Concession:Hot Dog → Concession:Soda  0.203390    0.923077  1.361538
# 155                                  Payment:Credit Card, Concession:Popcorn → Concession:Soda  0.203390    0.923077  1.361538
# 66                                         Payment:Cash, Concession:Popcorn → Concession:Candy  0.169492    0.714286  1.359447
# 226                       Concession:Candy → Concession:Popcorn, Concession:Soda, Ticket:Adult  0.169492    0.322581  1.359447
# 218                       Concession:Popcorn, Concession:Soda, Ticket:Adult → Concession:Candy  0.169492    0.714286  1.359447
# 70                                         Concession:Candy → Payment:Cash, Concession:Popcorn  0.169492    0.322581  1.359447
# 95                                     Payment:Credit Card, Concession:Candy → Concession:Soda  0.186441    0.916667  1.352083
# 80                                         Concession:Popcorn, Ticket:Adult → Concession:Candy  0.203390    0.705882  1.343454
# 83                                         Concession:Candy → Concession:Popcorn, Ticket:Adult  0.203390    0.387097  1.343454
# 143                                          Ticket:Adult, Concession:Nachos → Concession:Soda  0.169492    0.909091  1.340909
# 207                Payment:Credit Card, Concession:Candy, Concession:Soda → Concession:Popcorn  0.152542    0.818182  1.340909
# 339  Payment:Credit Card, Concession:Popcorn, Concession:Soda, Ticket:Adult → Concession:Candy  0.118644    0.700000  1.332258
# 249                   Payment:Credit Card, Concession:Popcorn, Ticket:Adult → Concession:Candy  0.118644    0.700000  1.332258
# 205                Payment:Credit Card, Concession:Popcorn, Concession:Candy → Concession:Soda  0.152542    0.900000  1.327500
# 275                      Concession:Candy, Concession:Soda → Payment:Credit Card, Ticket:Adult  0.152542    0.360000  1.327500
# 274                      Payment:Credit Card, Ticket:Adult → Concession:Candy, Concession:Soda  0.152542    0.562500  1.327500
# 310                    Concession:Popcorn, Concession:Soda → Payment:Credit Card, Ticket:Adult  0.169492    0.357143  1.316964
# 307                    Payment:Credit Card, Ticket:Adult → Concession:Popcorn, Concession:Soda  0.169492    0.625000  1.316964
# 98                                     Payment:Credit Card → Concession:Candy, Concession:Soda  0.186441    0.550000  1.298000
# 97                                     Concession:Candy, Concession:Soda → Payment:Credit Card  0.186441    0.440000  1.298000
# 134                                         Ticket:Adult, Concession:Hot Dog → Concession:Soda  0.118644    0.875000  1.290625
# 122                                    Concession:Hot Dog, Concession:Nachos → Concession:Soda  0.118644    0.875000  1.290625
# 161                                   Concession:Popcorn, Payment:Debit Card → Concession:Soda  0.118644    0.875000  1.290625
# 22                                                         Concession:Nachos → Concession:Soda  0.220339    0.866667  1.278333
# 21                                                         Concession:Soda → Concession:Nachos  0.220339    0.325000  1.278333
# 250                   Payment:Credit Card, Concession:Candy, Ticket:Adult → Concession:Popcorn  0.118644    0.777778  1.274691
# 337  Payment:Credit Card, Concession:Candy, Concession:Soda, Ticket:Adult → Concession:Popcorn  0.118644    0.777778  1.274691
# 162                                   Payment:Debit Card, Concession:Soda → Concession:Popcorn  0.118644    0.777778  1.274691
# 208                Concession:Popcorn, Concession:Candy, Concession:Soda → Payment:Credit Card  0.152542    0.428571  1.264286
# 104                                           Concession:Soda → Concession:Candy, Ticket:Adult  0.203390    0.300000  1.264286
# 215                Payment:Credit Card → Concession:Popcorn, Concession:Candy, Concession:Soda  0.152542    0.450000  1.264286
# 101                                           Concession:Candy, Ticket:Adult → Concession:Soda  0.203390    0.857143  1.264286
# 157                                  Concession:Popcorn, Concession:Soda → Payment:Credit Card  0.203390    0.428571  1.264286
# 158                                  Payment:Credit Card → Concession:Popcorn, Concession:Soda  0.203390    0.600000  1.264286
# 354  Payment:Credit Card, Ticket:Adult → Concession:Popcorn, Concession:Candy, Concession:Soda  0.118644    0.437500  1.229167
# 347  Concession:Popcorn, Concession:Candy, Concession:Soda → Payment:Credit Card, Ticket:Adult  0.118644    0.333333  1.229167
# 201                       Payment:Cash, Concession:Candy, Concession:Soda → Concession:Popcorn  0.101695    0.750000  1.229167
# 217                       Concession:Popcorn, Concession:Candy, Ticket:Adult → Concession:Soda  0.169492    0.833333  1.229167
# 169                                         Concession:Soda → Concession:Popcorn, Ticket:Adult  0.237288    0.350000  1.214706
# 164                                         Concession:Popcorn, Ticket:Adult → Concession:Soda  0.237288    0.823529  1.214706
# 20                                                           Concession:Hot Dog → Ticket:Adult  0.135593    0.615385  1.210256
# 204                       Payment:Cash, Concession:Soda → Concession:Popcorn, Concession:Candy  0.101695    0.545455  1.191919
# 153                                         Payment:Cash, Concession:Soda → Concession:Popcorn  0.135593    0.727273  1.191919
# 3                                                           Concession:Soda → Concession:Candy  0.423729    0.625000  1.189516
# 2                                                           Concession:Candy → Concession:Soda  0.423729    0.806452  1.189516
# 65                                      Concession:Soda → Concession:Popcorn, Concession:Candy  0.355932    0.525000  1.147222
# 60                                      Concession:Popcorn, Concession:Candy → Concession:Soda  0.355932    0.777778  1.147222
# 28                                                        Concession:Soda → Concession:Popcorn  0.474576    0.700000  1.147222
# 27                                                        Concession:Popcorn → Concession:Soda  0.474576    0.777778  1.147222
# 135                                         Concession:Soda, Concession:Hot Dog → Ticket:Adult  0.118644    0.583333  1.147222
# 6                                                       Payment:Credit Card → Concession:Candy  0.203390    0.600000  1.141935
# 7                                                       Concession:Candy → Payment:Credit Card  0.203390    0.387097  1.141935
# 127                                   Concession:Hot Dog → Concession:Popcorn, Concession:Soda  0.118644    0.538462  1.134615
# 316         Payment:Cash, Concession:Popcorn, Concession:Candy, Ticket:Child → Concession:Soda  0.101695    0.750000  1.106250
# 259                             Payment:Cash, Concession:Candy, Ticket:Child → Concession:Soda  0.101695    0.750000  1.106250
# 190                                               Payment:Cash, Ticket:Child → Concession:Soda  0.101695    0.750000  1.106250
# 293                           Payment:Cash, Concession:Popcorn, Ticket:Child → Concession:Soda  0.101695    0.750000  1.106250
# 99                                     Concession:Candy → Payment:Credit Card, Concession:Soda  0.186441    0.354839  1.101868
# 96                                     Payment:Credit Card, Concession:Soda → Concession:Candy  0.186441    0.578947  1.101868
# 30                                                           Concession:Popcorn → Payment:Cash  0.237288    0.388889  1.092593
# 74                                  Payment:Credit Card → Concession:Popcorn, Concession:Candy  0.169492    0.500000  1.092593
# 73                                  Concession:Popcorn, Concession:Candy → Payment:Credit Card  0.169492    0.370370  1.092593
# 38                                                         Ticket:Student → Concession:Popcorn  0.101695    0.666667  1.092593
# 29                                                           Payment:Cash → Concession:Popcorn  0.237288    0.666667  1.092593
# 5                                                              Concession:Candy → Payment:Cash  0.203390    0.387097  1.087558
# 4                                                              Payment:Cash → Concession:Candy  0.203390    0.571429  1.087558
# 48                                                              Concession:Soda → Ticket:Adult  0.372881    0.550000  1.081667
# 47                                                              Ticket:Adult → Concession:Soda  0.372881    0.733333  1.081667
# 107                                           Concession:Candy, Ticket:Child → Concession:Soda  0.135593    0.727273  1.072727
# 170                                         Concession:Popcorn, Ticket:Child → Concession:Soda  0.135593    0.727273  1.072727
# 229                       Concession:Popcorn, Concession:Candy, Ticket:Child → Concession:Soda  0.135593    0.727273  1.072727
# 49                                                              Ticket:Child → Concession:Soda  0.135593    0.727273  1.072727
# 270                      Payment:Credit Card, Concession:Soda, Ticket:Adult → Concession:Candy  0.152542    0.562500  1.070565
# 116                                       Payment:Credit Card, Ticket:Adult → Concession:Candy  0.152542    0.562500  1.070565
# 31                                                    Payment:Credit Card → Concession:Popcorn  0.220339    0.650000  1.065278
# 32                                                    Concession:Popcorn → Payment:Credit Card  0.220339    0.361111  1.065278
# 203                       Payment:Cash, Concession:Candy → Concession:Popcorn, Concession:Soda  0.101695    0.500000  1.053571
# 167                                         Concession:Popcorn → Ticket:Adult, Concession:Soda  0.237288    0.388889  1.042929
# 166                                         Ticket:Adult, Concession:Soda → Concession:Popcorn  0.237288    0.636364  1.042929
# 68                                         Concession:Popcorn, Concession:Candy → Payment:Cash  0.169492    0.370370  1.040564
# 69                                         Payment:Cash → Concession:Popcorn, Concession:Candy  0.169492    0.476190  1.040564
# 102                                           Concession:Soda, Ticket:Adult → Concession:Candy  0.203390    0.545455  1.038123
# 103                                           Concession:Candy → Concession:Soda, Ticket:Adult  0.203390    0.387097  1.038123
# 156                                  Payment:Credit Card, Concession:Soda → Concession:Popcorn  0.203390    0.631579  1.035088
# 211                Payment:Credit Card, Concession:Soda → Concession:Popcorn, Concession:Candy  0.152542    0.473684  1.035088
# 159                                  Concession:Popcorn → Payment:Credit Card, Concession:Soda  0.203390    0.333333  1.035088
# 212                Concession:Popcorn, Concession:Candy → Payment:Credit Card, Concession:Soda  0.152542    0.333333  1.035088
# 179                                     Payment:Credit Card, Ticket:Adult → Concession:Popcorn  0.169492    0.625000  1.024306
# 304                    Payment:Credit Card, Ticket:Adult, Concession:Soda → Concession:Popcorn  0.169492    0.625000  1.024306
# 202                       Payment:Cash, Concession:Popcorn → Concession:Candy, Concession:Soda  0.101695    0.428571  1.011429
# 220                       Concession:Popcorn, Concession:Candy → Concession:Soda, Ticket:Adult  0.169492    0.370370  0.993266
# 225                       Concession:Soda, Ticket:Adult → Concession:Popcorn, Concession:Candy  0.169492    0.454545  0.993266
# 165                                         Concession:Popcorn, Concession:Soda → Ticket:Adult  0.237288    0.500000  0.983333
# 53                                                             Concession:Water → Ticket:Adult  0.101695    0.500000  0.983333
# 168                                         Ticket:Adult → Concession:Popcorn, Concession:Soda  0.237288    0.466667  0.983333
# 50                                                            Ticket:Student → Concession:Soda  0.101695    0.666667  0.983333
# 91                                            Payment:Cash, Concession:Candy → Concession:Soda  0.135593    0.666667  0.983333
# 345  Payment:Credit Card, Concession:Soda, Ticket:Adult → Concession:Popcorn, Concession:Candy  0.118644    0.437500  0.956019
# 254                   Payment:Credit Card, Ticket:Adult → Concession:Popcorn, Concession:Candy  0.118644    0.437500  0.956019
# 126                                   Concession:Soda, Concession:Hot Dog → Concession:Popcorn  0.118644    0.583333  0.956019
# 105                                           Ticket:Adult → Concession:Candy, Concession:Soda  0.203390    0.400000  0.944000
# 100                                           Concession:Candy, Concession:Soda → Ticket:Adult  0.203390    0.480000  0.944000
# 227                       Ticket:Adult → Concession:Popcorn, Concession:Candy, Concession:Soda  0.169492    0.333333  0.936508
# 216                       Concession:Popcorn, Concession:Candy, Concession:Soda → Ticket:Adult  0.169492    0.476190  0.936508
# 35                                                           Ticket:Adult → Concession:Popcorn  0.288136    0.566667  0.928704
# 34                                                           Concession:Popcorn → Ticket:Adult  0.288136    0.472222  0.928704
# 59                                                           Payment:Debit Card → Ticket:Adult  0.135593    0.470588  0.925490
# 93                                            Concession:Candy, Concession:Soda → Payment:Cash  0.135593    0.320000  0.899048
# 94                                            Payment:Cash → Concession:Candy, Concession:Soda  0.135593    0.380952  0.899048
# 9                                                              Concession:Candy → Ticket:Adult  0.237288    0.451613  0.888172
# 10                                                             Ticket:Adult → Concession:Candy  0.237288    0.466667  0.888172
# 199                       Payment:Cash, Concession:Popcorn, Concession:Candy → Concession:Soda  0.101695    0.600000  0.885000
# 15                                                     Concession:Hot Dog → Concession:Popcorn  0.118644    0.538462  0.882479
# 79                                         Concession:Popcorn, Concession:Candy → Ticket:Adult  0.203390    0.444444  0.874074
# 84                                         Ticket:Adult → Concession:Popcorn, Concession:Candy  0.203390    0.400000  0.874074
# 163                                   Payment:Debit Card → Concession:Popcorn, Concession:Soda  0.118644    0.411765  0.867647
# 152                                         Payment:Cash, Concession:Popcorn → Concession:Soda  0.135593    0.571429  0.842857
# 154                                         Payment:Cash → Concession:Popcorn, Concession:Soda  0.135593    0.380952  0.802721
# 46                                                        Payment:Debit Card → Concession:Soda  0.152542    0.529412  0.780882
# 43                                                              Payment:Cash → Concession:Soda  0.186441    0.523810  0.772619
# 78                                   Payment:Debit Card → Concession:Popcorn, Concession:Candy  0.101695    0.352941  0.771242
# 33                                                     Payment:Debit Card → Concession:Popcorn  0.135593    0.470588  0.771242
# 8                                                        Payment:Debit Card → Concession:Candy  0.101695    0.352941  0.671727

# %%
# Display all rules sorted by CONFIDENCE
if len(rules) > 0:
    print("ALL ASSOCIATION RULES - SORTED BY CONFIDENCE:")
    print("="*100)
    print("Confidence shows how often the rule is true")
    print("Higher confidence = more reliable prediction\n")
    rules_by_conf = rules.sort_values('confidence', ascending=False)
    print(rules_by_conf[['rule', 'support', 'confidence', 'lift']].to_string())
# Out:
# ALL ASSOCIATION RULES - SORTED BY CONFIDENCE:
# ====================================================================================================
# Confidence shows how often the rule is true
# Higher confidence = more reliable prediction
#
#                                                                                           rule   support  confidence      lift
# 260                             Payment:Cash, Concession:Soda, Ticket:Child → Concession:Candy  0.101695    1.000000  1.903226
# 317         Payment:Cash, Concession:Popcorn, Concession:Soda, Ticket:Child → Concession:Candy  0.101695    1.000000  1.903226
# 138                                   Payment:Credit Card, Concession:Nachos → Concession:Soda  0.152542    1.000000  1.475000
# 315         Payment:Cash, Concession:Candy, Concession:Soda, Ticket:Child → Concession:Popcorn  0.101695    1.000000  1.638889
# 314         Payment:Cash, Concession:Popcorn, Concession:Candy, Concession:Soda → Ticket:Child  0.101695    1.000000  5.363636
# 37                                                           Ticket:Child → Concession:Popcorn  0.186441    1.000000  1.638889
# 302                    Payment:Credit Card, Concession:Popcorn, Ticket:Adult → Concession:Soda  0.169492    1.000000  1.475000
# 129                                  Payment:Credit Card, Concession:Hot Dog → Concession:Soda  0.101695    1.000000  1.475000
# 125                                   Concession:Popcorn, Concession:Hot Dog → Concession:Soda  0.118644    1.000000  1.475000
# 294                           Payment:Cash, Concession:Soda, Ticket:Child → Concession:Popcorn  0.101695    1.000000  1.638889
# 230                       Concession:Popcorn, Concession:Soda, Ticket:Child → Concession:Candy  0.135593    1.000000  1.903226
# 231                       Concession:Candy, Concession:Soda, Ticket:Child → Concession:Popcorn  0.135593    1.000000  1.638889
# 111                                              Payment:Cash, Ticket:Child → Concession:Candy  0.135593    1.000000  1.903226
# 108                                           Concession:Soda, Ticket:Child → Concession:Candy  0.135593    1.000000  1.903226
# 235                       Concession:Soda, Ticket:Child → Concession:Popcorn, Concession:Candy  0.135593    1.000000  2.185185
# 281                     Payment:Credit Card, Ticket:Adult, Concession:Nachos → Concession:Soda  0.135593    1.000000  1.475000
# 238                          Payment:Cash, Concession:Popcorn, Ticket:Child → Concession:Candy  0.135593    1.000000  1.903226
# 239                          Payment:Cash, Concession:Candy, Ticket:Child → Concession:Popcorn  0.135593    1.000000  1.638889
# 269                      Payment:Credit Card, Concession:Candy, Ticket:Adult → Concession:Soda  0.152542    1.000000  1.475000
# 243                          Payment:Cash, Ticket:Child → Concession:Popcorn, Concession:Candy  0.135593    1.000000  2.185185
# 77                                   Payment:Debit Card, Concession:Candy → Concession:Popcorn  0.101695    1.000000  1.638889
# 90                                         Ticket:Child → Concession:Popcorn, Concession:Candy  0.186441    1.000000  2.185185
# 87                                         Concession:Candy, Ticket:Child → Concession:Popcorn  0.186441    1.000000  1.638889
# 193                                        Payment:Credit Card, Ticket:Adult → Concession:Soda  0.271186    1.000000  1.475000
# 86                                         Concession:Popcorn, Ticket:Child → Concession:Candy  0.186441    1.000000  1.903226
# 338  Payment:Credit Card, Concession:Popcorn, Concession:Candy, Ticket:Adult → Concession:Soda  0.118644    1.000000  1.475000
# 171                                         Concession:Soda, Ticket:Child → Concession:Popcorn  0.135593    1.000000  1.638889
# 12                                                             Ticket:Child → Concession:Candy  0.186441    1.000000  1.903226
# 174                                            Payment:Cash, Ticket:Child → Concession:Popcorn  0.135593    1.000000  1.638889
# 323         Payment:Cash, Concession:Soda, Ticket:Child → Concession:Popcorn, Concession:Candy  0.101695    1.000000  2.185185
# 184                                  Concession:Pretzel, Payment:Debit Card → Concession:Water  0.101695    1.000000  4.916667
# 44                                                       Payment:Credit Card → Concession:Soda  0.322034    0.950000  1.401250
# 155                                  Payment:Credit Card, Concession:Popcorn → Concession:Soda  0.203390    0.923077  1.361538
# 17                                                        Concession:Hot Dog → Concession:Soda  0.203390    0.923077  1.361538
# 95                                     Payment:Credit Card, Concession:Candy → Concession:Soda  0.186441    0.916667  1.352083
# 143                                          Ticket:Adult, Concession:Nachos → Concession:Soda  0.169492    0.909091  1.340909
# 205                Payment:Credit Card, Concession:Popcorn, Concession:Candy → Concession:Soda  0.152542    0.900000  1.327500
# 286                     Payment:Credit Card, Concession:Nachos → Ticket:Adult, Concession:Soda  0.135593    0.888889  2.383838
# 148                                      Payment:Credit Card, Concession:Nachos → Ticket:Adult  0.135593    0.888889  1.748148
# 282                     Payment:Credit Card, Concession:Soda, Concession:Nachos → Ticket:Adult  0.135593    0.888889  1.748148
# 39                                                       Concession:Pretzel → Concession:Water  0.118644    0.875000  4.302083
# 122                                    Concession:Hot Dog, Concession:Nachos → Concession:Soda  0.118644    0.875000  1.290625
# 134                                         Ticket:Adult, Concession:Hot Dog → Concession:Soda  0.118644    0.875000  1.290625
# 161                                   Concession:Popcorn, Payment:Debit Card → Concession:Soda  0.118644    0.875000  1.290625
# 1                                                        Concession:Candy → Concession:Popcorn  0.457627    0.870968  1.427419
# 22                                                         Concession:Nachos → Concession:Soda  0.220339    0.866667  1.278333
# 101                                           Concession:Candy, Ticket:Adult → Concession:Soda  0.203390    0.857143  1.264286
# 183                                  Concession:Pretzel, Concession:Water → Payment:Debit Card  0.101695    0.857143  2.974790
# 81                                         Concession:Candy, Ticket:Adult → Concession:Popcorn  0.203390    0.857143  1.404762
# 194                                        Payment:Credit Card, Concession:Soda → Ticket:Adult  0.271186    0.842105  1.656140
# 62                                      Concession:Candy, Concession:Soda → Concession:Popcorn  0.355932    0.840000  1.376667
# 67                                         Payment:Cash, Concession:Candy → Concession:Popcorn  0.169492    0.833333  1.365741
# 72                                  Payment:Credit Card, Concession:Candy → Concession:Popcorn  0.169492    0.833333  1.365741
# 303                    Payment:Credit Card, Concession:Popcorn, Concession:Soda → Ticket:Adult  0.169492    0.833333  1.638889
# 219                       Concession:Candy, Concession:Soda, Ticket:Adult → Concession:Popcorn  0.169492    0.833333  1.365741
# 217                       Concession:Popcorn, Concession:Candy, Ticket:Adult → Concession:Soda  0.169492    0.833333  1.229167
# 164                                         Concession:Popcorn, Ticket:Adult → Concession:Soda  0.237288    0.823529  1.214706
# 268                      Payment:Credit Card, Concession:Candy, Concession:Soda → Ticket:Adult  0.152542    0.818182  1.609091
# 207                Payment:Credit Card, Concession:Candy, Concession:Soda → Concession:Popcorn  0.152542    0.818182  1.340909
# 2                                                           Concession:Candy → Concession:Soda  0.423729    0.806452  1.189516
# 196                                        Payment:Credit Card → Ticket:Adult, Concession:Soda  0.271186    0.800000  2.145455
# 283                     Ticket:Adult, Concession:Soda, Concession:Nachos → Payment:Credit Card  0.135593    0.800000  2.360000
# 237                          Payment:Cash, Concession:Popcorn, Concession:Candy → Ticket:Child  0.135593    0.800000  4.290909
# 57                                                          Payment:Credit Card → Ticket:Adult  0.271186    0.800000  1.573333
# 27                                                        Concession:Popcorn → Concession:Soda  0.474576    0.777778  1.147222
# 60                                      Concession:Popcorn, Concession:Candy → Concession:Soda  0.355932    0.777778  1.147222
# 336  Payment:Credit Card, Concession:Popcorn, Concession:Candy, Concession:Soda → Ticket:Adult  0.118644    0.777778  1.529630
# 337  Payment:Credit Card, Concession:Candy, Concession:Soda, Ticket:Adult → Concession:Popcorn  0.118644    0.777778  1.274691
# 250                   Payment:Credit Card, Concession:Candy, Ticket:Adult → Concession:Popcorn  0.118644    0.777778  1.274691
# 343  Payment:Credit Card, Concession:Candy, Ticket:Adult → Concession:Popcorn, Concession:Soda  0.118644    0.777778  1.638889
# 162                                   Payment:Debit Card, Concession:Soda → Concession:Popcorn  0.118644    0.777778  1.274691
# 144                                          Concession:Soda, Concession:Nachos → Ticket:Adult  0.169492    0.769231  1.512821
# 71                                  Payment:Credit Card, Concession:Popcorn → Concession:Candy  0.169492    0.769231  1.464020
# 306                    Payment:Credit Card, Concession:Popcorn → Ticket:Adult, Concession:Soda  0.169492    0.769231  2.062937
# 178                                     Payment:Credit Card, Concession:Popcorn → Ticket:Adult  0.169492    0.769231  1.512821
# 186                                  Concession:Pretzel → Concession:Water, Payment:Debit Card  0.101695    0.750000  4.916667
# 201                       Payment:Cash, Concession:Candy, Concession:Soda → Concession:Popcorn  0.101695    0.750000  1.229167
# 258                             Payment:Cash, Concession:Candy, Concession:Soda → Ticket:Child  0.101695    0.750000  4.022727
# 190                                               Payment:Cash, Ticket:Child → Concession:Soda  0.101695    0.750000  1.106250
# 191                                               Concession:Soda, Ticket:Child → Payment:Cash  0.101695    0.750000  2.107143
# 206                Payment:Credit Card, Concession:Popcorn, Concession:Soda → Concession:Candy  0.152542    0.750000  1.427419
# 210                Payment:Credit Card, Concession:Candy → Concession:Popcorn, Concession:Soda  0.152542    0.750000  1.580357
# 115                                       Payment:Credit Card, Concession:Candy → Ticket:Adult  0.152542    0.750000  1.475000
# 200                       Payment:Cash, Concession:Popcorn, Concession:Soda → Concession:Candy  0.101695    0.750000  1.427419
# 0                                                        Concession:Popcorn → Concession:Candy  0.457627    0.750000  1.427419
# 259                             Payment:Cash, Concession:Candy, Ticket:Child → Concession:Soda  0.101695    0.750000  1.106250
# 271                      Concession:Candy, Concession:Soda, Ticket:Adult → Payment:Credit Card  0.152542    0.750000  2.212500
# 293                           Payment:Cash, Concession:Popcorn, Ticket:Child → Concession:Soda  0.101695    0.750000  1.106250
# 51                                                       Concession:Water → Payment:Debit Card  0.152542    0.750000  2.602941
# 295                           Concession:Popcorn, Concession:Soda, Ticket:Child → Payment:Cash  0.101695    0.750000  2.107143
# 298                           Payment:Cash, Ticket:Child → Concession:Popcorn, Concession:Soda  0.101695    0.750000  1.580357
# 300                           Concession:Soda, Ticket:Child → Payment:Cash, Concession:Popcorn  0.101695    0.750000  3.160714
# 41                                                     Concession:Pretzel → Payment:Debit Card  0.101695    0.750000  2.602941
# 316         Payment:Cash, Concession:Popcorn, Concession:Candy, Ticket:Child → Concession:Soda  0.101695    0.750000  1.106250
# 61                                      Concession:Popcorn, Concession:Soda → Concession:Candy  0.355932    0.750000  1.427419
# 318         Concession:Popcorn, Concession:Candy, Concession:Soda, Ticket:Child → Payment:Cash  0.101695    0.750000  2.107143
# 319         Payment:Cash, Concession:Candy, Concession:Soda → Concession:Popcorn, Ticket:Child  0.101695    0.750000  4.022727
# 321         Payment:Cash, Concession:Candy, Ticket:Child → Concession:Popcorn, Concession:Soda  0.101695    0.750000  1.580357
# 322         Payment:Cash, Concession:Popcorn, Concession:Soda → Concession:Candy, Ticket:Child  0.101695    0.750000  4.022727
# 272                      Payment:Credit Card, Concession:Candy → Concession:Soda, Ticket:Adult  0.152542    0.750000  2.011364
# 292                           Payment:Cash, Concession:Popcorn, Concession:Soda → Ticket:Child  0.101695    0.750000  4.022727
# 261                             Concession:Candy, Concession:Soda, Ticket:Child → Payment:Cash  0.101695    0.750000  2.107143
# 76                                   Concession:Popcorn, Payment:Debit Card → Concession:Candy  0.101695    0.750000  1.427419
# 325         Concession:Candy, Concession:Soda, Ticket:Child → Payment:Cash, Concession:Popcorn  0.101695    0.750000  3.160714
# 266                             Concession:Soda, Ticket:Child → Payment:Cash, Concession:Candy  0.101695    0.750000  3.687500
# 327         Concession:Popcorn, Concession:Soda, Ticket:Child → Payment:Cash, Concession:Candy  0.101695    0.750000  3.687500
# 331         Payment:Cash, Ticket:Child → Concession:Popcorn, Concession:Candy, Concession:Soda  0.101695    0.750000  2.107143
# 324         Payment:Cash, Concession:Popcorn, Ticket:Child → Concession:Candy, Concession:Soda  0.101695    0.750000  1.770000
# 333         Concession:Soda, Ticket:Child → Payment:Cash, Concession:Popcorn, Concession:Candy  0.101695    0.750000  4.425000
# 264                             Payment:Cash, Ticket:Child → Concession:Candy, Concession:Soda  0.101695    0.750000  1.770000
# 26                                                            Concession:Nachos → Ticket:Adult  0.186441    0.733333  1.442222
# 47                                                              Ticket:Adult → Concession:Soda  0.372881    0.733333  1.081667
# 175                                            Concession:Popcorn, Ticket:Child → Payment:Cash  0.135593    0.727273  2.043290
# 172                                         Ticket:Child → Concession:Popcorn, Concession:Soda  0.135593    0.727273  1.532468
# 170                                         Concession:Popcorn, Ticket:Child → Concession:Soda  0.135593    0.727273  1.072727
# 149                                      Ticket:Adult, Concession:Nachos → Payment:Credit Card  0.135593    0.727273  2.145455
# 177                                            Ticket:Child → Payment:Cash, Concession:Popcorn  0.135593    0.727273  3.064935
# 153                                         Payment:Cash, Concession:Soda → Concession:Popcorn  0.135593    0.727273  1.191919
# 229                       Concession:Popcorn, Concession:Candy, Ticket:Child → Concession:Soda  0.135593    0.727273  1.072727
# 195                                        Ticket:Adult, Concession:Soda → Payment:Credit Card  0.271186    0.727273  2.145455
# 49                                                              Ticket:Child → Concession:Soda  0.135593    0.727273  1.072727
# 244                          Concession:Popcorn, Ticket:Child → Payment:Cash, Concession:Candy  0.135593    0.727273  3.575758
# 92                                            Payment:Cash, Concession:Soda → Concession:Candy  0.135593    0.727273  1.384164
# 245                          Concession:Candy, Ticket:Child → Payment:Cash, Concession:Popcorn  0.135593    0.727273  3.064935
# 236                       Ticket:Child → Concession:Popcorn, Concession:Candy, Concession:Soda  0.135593    0.727273  2.043290
# 232                       Concession:Popcorn, Ticket:Child → Concession:Candy, Concession:Soda  0.135593    0.727273  1.716364
# 55                                                                 Ticket:Child → Payment:Cash  0.135593    0.727273  2.043290
# 107                                           Concession:Candy, Ticket:Child → Concession:Soda  0.135593    0.727273  1.072727
# 114                                              Ticket:Child → Payment:Cash, Concession:Candy  0.135593    0.727273  3.575758
# 234                       Concession:Candy, Ticket:Child → Concession:Popcorn, Concession:Soda  0.135593    0.727273  1.532468
# 112                                              Concession:Candy, Ticket:Child → Payment:Cash  0.135593    0.727273  2.043290
# 288                     Ticket:Adult, Concession:Nachos → Payment:Credit Card, Concession:Soda  0.135593    0.727273  2.258373
# 247                          Ticket:Child → Payment:Cash, Concession:Popcorn, Concession:Candy  0.135593    0.727273  4.290909
# 109                                           Ticket:Child → Concession:Candy, Concession:Soda  0.135593    0.727273  1.716364
# 240                          Concession:Popcorn, Concession:Candy, Ticket:Child → Payment:Cash  0.135593    0.727273  2.043290
# 66                                         Payment:Cash, Concession:Popcorn → Concession:Candy  0.169492    0.714286  1.359447
# 224                       Concession:Candy, Ticket:Adult → Concession:Popcorn, Concession:Soda  0.169492    0.714286  1.505102
# 218                       Concession:Popcorn, Concession:Soda, Ticket:Adult → Concession:Candy  0.169492    0.714286  1.359447
# 305                    Concession:Popcorn, Ticket:Adult, Concession:Soda → Payment:Credit Card  0.169492    0.714286  2.107143
# 80                                         Concession:Popcorn, Ticket:Adult → Concession:Candy  0.203390    0.705882  1.343454
# 249                   Payment:Credit Card, Concession:Popcorn, Ticket:Adult → Concession:Candy  0.118644    0.700000  1.332258
# 248                   Payment:Credit Card, Concession:Popcorn, Concession:Candy → Ticket:Adult  0.118644    0.700000  1.376667
# 339  Payment:Credit Card, Concession:Popcorn, Concession:Soda, Ticket:Adult → Concession:Candy  0.118644    0.700000  1.332258
# 340  Concession:Popcorn, Concession:Candy, Concession:Soda, Ticket:Adult → Payment:Credit Card  0.118644    0.700000  2.065000
# 28                                                        Concession:Soda → Concession:Popcorn  0.474576    0.700000  1.147222
# 342  Payment:Credit Card, Concession:Popcorn, Concession:Candy → Concession:Soda, Ticket:Adult  0.118644    0.700000  1.877273
# 346  Payment:Credit Card, Concession:Popcorn, Ticket:Adult → Concession:Candy, Concession:Soda  0.118644    0.700000  1.652000
# 139                                   Concession:Soda, Concession:Nachos → Payment:Credit Card  0.152542    0.692308  2.042308
# 209                Payment:Credit Card, Concession:Popcorn → Concession:Candy, Concession:Soda  0.152542    0.692308  1.633846
# 64                                      Concession:Candy → Concession:Popcorn, Concession:Soda  0.355932    0.677419  1.427419
# 29                                                           Payment:Cash → Concession:Popcorn  0.237288    0.666667  1.092593
# 185                                  Concession:Water, Payment:Debit Card → Concession:Pretzel  0.101695    0.666667  4.916667
# 110                                              Payment:Cash, Concession:Candy → Ticket:Child  0.135593    0.666667  3.575758
# 50                                                            Ticket:Student → Concession:Soda  0.101695    0.666667  0.983333
# 56                                                                Ticket:Senior → Payment:Cash  0.101695    0.666667  1.873016
# 38                                                         Ticket:Student → Concession:Popcorn  0.101695    0.666667  1.092593
# 242                          Payment:Cash, Concession:Candy → Concession:Popcorn, Ticket:Child  0.135593    0.666667  3.575758
# 91                                            Payment:Cash, Concession:Candy → Concession:Soda  0.135593    0.666667  0.983333
# 146                                          Concession:Nachos → Ticket:Adult, Concession:Soda  0.169492    0.666667  1.787879
# 31                                                    Payment:Credit Card → Concession:Popcorn  0.220339    0.650000  1.065278
# 276                      Concession:Candy, Ticket:Adult → Payment:Credit Card, Concession:Soda  0.152542    0.642857  1.996241
# 117                                       Concession:Candy, Ticket:Adult → Payment:Credit Card  0.152542    0.642857  1.896429
# 341  Payment:Credit Card, Concession:Candy, Concession:Soda → Concession:Popcorn, Ticket:Adult  0.118644    0.636364  2.208556
# 166                                         Ticket:Adult, Concession:Soda → Concession:Popcorn  0.237288    0.636364  1.042929
# 156                                  Payment:Credit Card, Concession:Soda → Concession:Popcorn  0.203390    0.631579  1.035088
# 307                    Payment:Credit Card, Ticket:Adult → Concession:Popcorn, Concession:Soda  0.169492    0.625000  1.316964
# 304                    Payment:Credit Card, Ticket:Adult, Concession:Soda → Concession:Popcorn  0.169492    0.625000  1.024306
# 179                                     Payment:Credit Card, Ticket:Adult → Concession:Popcorn  0.169492    0.625000  1.024306
# 3                                                           Concession:Soda → Concession:Candy  0.423729    0.625000  1.189516
# 13                                                      Concession:Hot Dog → Concession:Nachos  0.135593    0.615385  2.420513
# 289                     Concession:Soda, Concession:Nachos → Payment:Credit Card, Ticket:Adult  0.135593    0.615385  2.269231
# 20                                                           Concession:Hot Dog → Ticket:Adult  0.135593    0.615385  1.210256
# 6                                                       Payment:Credit Card → Concession:Candy  0.203390    0.600000  1.141935
# 158                                  Payment:Credit Card → Concession:Popcorn, Concession:Soda  0.203390    0.600000  1.264286
# 24                                                     Concession:Nachos → Payment:Credit Card  0.152542    0.600000  1.770000
# 199                       Payment:Cash, Concession:Popcorn, Concession:Candy → Concession:Soda  0.101695    0.600000  0.885000
# 141                                   Concession:Nachos → Payment:Credit Card, Concession:Soda  0.152542    0.600000  1.863158
# 320         Payment:Cash, Concession:Popcorn, Concession:Candy → Concession:Soda, Ticket:Child  0.101695    0.600000  4.425000
# 180                                     Concession:Popcorn, Ticket:Adult → Payment:Credit Card  0.169492    0.588235  1.735294
# 309                    Concession:Popcorn, Ticket:Adult → Payment:Credit Card, Concession:Soda  0.169492    0.588235  1.826625
# 222                       Concession:Popcorn, Ticket:Adult → Concession:Candy, Concession:Soda  0.169492    0.588235  1.388235
# 348  Concession:Candy, Concession:Soda, Ticket:Adult → Payment:Credit Card, Concession:Popcorn  0.118644    0.583333  2.647436
# 120                                    Concession:Soda, Concession:Hot Dog → Concession:Nachos  0.118644    0.583333  2.294444
# 251                   Concession:Popcorn, Concession:Candy, Ticket:Adult → Payment:Credit Card  0.118644    0.583333  1.720833
# 344  Payment:Credit Card, Concession:Popcorn, Concession:Soda → Concession:Candy, Ticket:Adult  0.118644    0.583333  2.458333
# 126                                   Concession:Soda, Concession:Hot Dog → Concession:Popcorn  0.118644    0.583333  0.956019
# 63                                      Concession:Popcorn → Concession:Candy, Concession:Soda  0.355932    0.583333  1.376667
# 253                   Payment:Credit Card, Concession:Candy → Concession:Popcorn, Ticket:Adult  0.118644    0.583333  2.024510
# 351  Payment:Credit Card, Concession:Candy → Concession:Popcorn, Concession:Soda, Ticket:Adult  0.118644    0.583333  2.458333
# 40                                                       Concession:Water → Concession:Pretzel  0.118644    0.583333  4.302083
# 135                                         Concession:Soda, Concession:Hot Dog → Ticket:Adult  0.118644    0.583333  1.147222
# 349  Concession:Popcorn, Concession:Candy, Ticket:Adult → Payment:Credit Card, Concession:Soda  0.118644    0.583333  1.811404
# 96                                     Payment:Credit Card, Concession:Soda → Concession:Candy  0.186441    0.578947  1.101868
# 4                                                              Payment:Cash → Concession:Candy  0.203390    0.571429  1.087558
# 173                                            Payment:Cash, Concession:Popcorn → Ticket:Child  0.135593    0.571429  3.064935
# 241                          Payment:Cash, Concession:Popcorn → Concession:Candy, Ticket:Child  0.135593    0.571429  3.064935
# 152                                         Payment:Cash, Concession:Popcorn → Concession:Soda  0.135593    0.571429  0.842857
# 35                                                           Ticket:Adult → Concession:Popcorn  0.288136    0.566667  0.928704
# 116                                       Payment:Credit Card, Ticket:Adult → Concession:Candy  0.152542    0.562500  1.070565
# 274                      Payment:Credit Card, Ticket:Adult → Concession:Candy, Concession:Soda  0.152542    0.562500  1.327500
# 270                      Payment:Credit Card, Concession:Soda, Ticket:Adult → Concession:Candy  0.152542    0.562500  1.070565
# 48                                                              Concession:Soda → Ticket:Adult  0.372881    0.550000  1.081667
# 98                                     Payment:Credit Card → Concession:Candy, Concession:Soda  0.186441    0.550000  1.298000
# 299                           Concession:Popcorn, Ticket:Child → Payment:Cash, Concession:Soda  0.101695    0.545455  2.925620
# 297                           Payment:Cash, Concession:Soda → Concession:Popcorn, Ticket:Child  0.101695    0.545455  2.925620
# 301                           Ticket:Child → Payment:Cash, Concession:Popcorn, Concession:Soda  0.101695    0.545455  4.022727
# 102                                           Concession:Soda, Ticket:Adult → Concession:Candy  0.203390    0.545455  1.038123
# 267                             Ticket:Child → Payment:Cash, Concession:Candy, Concession:Soda  0.101695    0.545455  4.022727
# 263                             Payment:Cash, Concession:Soda → Concession:Candy, Ticket:Child  0.101695    0.545455  2.925620
# 265                             Concession:Candy, Ticket:Child → Payment:Cash, Concession:Soda  0.101695    0.545455  2.925620
# 329         Payment:Cash, Concession:Soda → Concession:Popcorn, Concession:Candy, Ticket:Child  0.101695    0.545455  2.925620
# 326         Concession:Popcorn, Concession:Candy, Ticket:Child → Payment:Cash, Concession:Soda  0.101695    0.545455  2.925620
# 332         Concession:Candy, Ticket:Child → Payment:Cash, Concession:Popcorn, Concession:Soda  0.101695    0.545455  4.022727
# 334         Concession:Popcorn, Ticket:Child → Payment:Cash, Concession:Candy, Concession:Soda  0.101695    0.545455  4.022727
# 192                                               Ticket:Child → Payment:Cash, Concession:Soda  0.101695    0.545455  2.925620
# 204                       Payment:Cash, Concession:Soda → Concession:Popcorn, Concession:Candy  0.101695    0.545455  1.191919
# 189                                               Payment:Cash, Concession:Soda → Ticket:Child  0.101695    0.545455  2.925620
# 335         Ticket:Child → Payment:Cash, Concession:Popcorn, Concession:Candy, Concession:Soda  0.101695    0.545455  5.363636
# 136                                         Concession:Hot Dog → Ticket:Adult, Concession:Soda  0.118644    0.538462  1.444056
# 121                                    Concession:Soda, Concession:Nachos → Concession:Hot Dog  0.118644    0.538462  2.443787
# 127                                   Concession:Hot Dog → Concession:Popcorn, Concession:Soda  0.118644    0.538462  1.134615
# 123                                    Concession:Hot Dog → Concession:Soda, Concession:Nachos  0.118644    0.538462  2.443787
# 252                   Payment:Credit Card, Concession:Popcorn → Concession:Candy, Ticket:Adult  0.118644    0.538462  2.269231
# 353  Payment:Credit Card, Concession:Popcorn → Concession:Candy, Concession:Soda, Ticket:Adult  0.118644    0.538462  2.647436
# 15                                                     Concession:Hot Dog → Concession:Popcorn  0.118644    0.538462  0.882479
# 58                                                          Ticket:Adult → Payment:Credit Card  0.271186    0.533333  1.573333
# 291                     Concession:Nachos → Payment:Credit Card, Ticket:Adult, Concession:Soda  0.135593    0.533333  1.966667
# 151                                      Concession:Nachos → Payment:Credit Card, Ticket:Adult  0.135593    0.533333  1.966667
# 14                                                      Concession:Nachos → Concession:Hot Dog  0.135593    0.533333  2.420513
# 197                                        Ticket:Adult → Payment:Credit Card, Concession:Soda  0.271186    0.533333  1.656140
# 46                                                        Payment:Debit Card → Concession:Soda  0.152542    0.529412  0.780882
# 52                                                       Payment:Debit Card → Concession:Water  0.152542    0.529412  2.602941
# 308                    Payment:Credit Card, Concession:Soda → Concession:Popcorn, Ticket:Adult  0.169492    0.526316  1.826625
# 65                                      Concession:Soda → Concession:Popcorn, Concession:Candy  0.355932    0.525000  1.147222
# 43                                                              Payment:Cash → Concession:Soda  0.186441    0.523810  0.772619
# 284                     Payment:Credit Card, Ticket:Adult → Concession:Soda, Concession:Nachos  0.135593    0.500000  2.269231
# 187                                  Concession:Water → Concession:Pretzel, Payment:Debit Card  0.101695    0.500000  4.916667
# 350  Concession:Popcorn, Concession:Soda, Ticket:Adult → Payment:Credit Card, Concession:Candy  0.118644    0.500000  2.458333
# 262                             Payment:Cash, Concession:Candy → Concession:Soda, Ticket:Child  0.101695    0.500000  3.687500
# 181                                     Payment:Credit Card → Concession:Popcorn, Ticket:Adult  0.169492    0.500000  1.735294
# 280                     Payment:Credit Card, Ticket:Adult, Concession:Soda → Concession:Nachos  0.135593    0.500000  1.966667
# 147                                      Payment:Credit Card, Ticket:Adult → Concession:Nachos  0.135593    0.500000  1.966667
# 256                   Concession:Candy, Ticket:Adult → Payment:Credit Card, Concession:Popcorn  0.118644    0.500000  2.269231
# 328         Payment:Cash, Concession:Candy → Concession:Popcorn, Concession:Soda, Ticket:Child  0.101695    0.500000  3.687500
# 312                    Payment:Credit Card → Concession:Popcorn, Ticket:Adult, Concession:Soda  0.169492    0.500000  2.107143
# 165                                         Concession:Popcorn, Concession:Soda → Ticket:Adult  0.237288    0.500000  0.983333
# 74                                  Payment:Credit Card → Concession:Popcorn, Concession:Candy  0.169492    0.500000  1.092593
# 53                                                             Concession:Water → Ticket:Adult  0.101695    0.500000  0.983333
# 355  Concession:Candy, Ticket:Adult → Payment:Credit Card, Concession:Popcorn, Concession:Soda  0.118644    0.500000  2.458333
# 203                       Payment:Cash, Concession:Candy → Concession:Popcorn, Concession:Soda  0.101695    0.500000  1.053571
# 130                                  Concession:Soda, Concession:Hot Dog → Payment:Credit Card  0.101695    0.500000  1.475000
# 100                                           Concession:Candy, Concession:Soda → Ticket:Adult  0.203390    0.480000  0.944000
# 216                       Concession:Popcorn, Concession:Candy, Concession:Soda → Ticket:Adult  0.169492    0.476190  0.936508
# 69                                         Payment:Cash → Concession:Popcorn, Concession:Candy  0.169492    0.476190  1.040564
# 45                                                       Concession:Soda → Payment:Credit Card  0.322034    0.475000  1.401250
# 273                      Payment:Credit Card, Concession:Soda → Concession:Candy, Ticket:Adult  0.152542    0.473684  1.996241
# 137                                   Payment:Credit Card, Concession:Soda → Concession:Nachos  0.152542    0.473684  1.863158
# 211                Payment:Credit Card, Concession:Soda → Concession:Popcorn, Concession:Candy  0.152542    0.473684  1.035088
# 34                                                           Concession:Popcorn → Ticket:Adult  0.288136    0.472222  0.928704
# 59                                                           Payment:Debit Card → Ticket:Adult  0.135593    0.470588  0.925490
# 33                                                     Payment:Debit Card → Concession:Popcorn  0.135593    0.470588  0.771242
# 10                                                             Ticket:Adult → Concession:Candy  0.237288    0.466667  0.888172
# 168                                         Ticket:Adult → Concession:Popcorn, Concession:Soda  0.237288    0.466667  0.983333
# 124                                    Concession:Nachos → Concession:Soda, Concession:Hot Dog  0.118644    0.466667  2.294444
# 19                                                    Concession:Hot Dog → Payment:Credit Card  0.101695    0.461538  1.361538
# 132                                  Concession:Hot Dog → Payment:Credit Card, Concession:Soda  0.101695    0.461538  1.433198
# 311                    Ticket:Adult, Concession:Soda → Payment:Credit Card, Concession:Popcorn  0.169492    0.454545  2.062937
# 142                                          Ticket:Adult, Concession:Soda → Concession:Nachos  0.169492    0.454545  1.787879
# 225                       Concession:Soda, Ticket:Adult → Concession:Popcorn, Concession:Candy  0.169492    0.454545  0.993266
# 9                                                              Concession:Candy → Ticket:Adult  0.237288    0.451613  0.888172
# 278                      Payment:Credit Card → Concession:Candy, Concession:Soda, Ticket:Adult  0.152542    0.450000  2.212500
# 140                                   Payment:Credit Card → Concession:Soda, Concession:Nachos  0.152542    0.450000  2.042308
# 23                                                     Payment:Credit Card → Concession:Nachos  0.152542    0.450000  1.770000
# 215                Payment:Credit Card → Concession:Popcorn, Concession:Candy, Concession:Soda  0.152542    0.450000  1.264286
# 118                                       Payment:Credit Card → Concession:Candy, Ticket:Adult  0.152542    0.450000  1.896429
# 79                                         Concession:Popcorn, Concession:Candy → Ticket:Adult  0.203390    0.444444  0.874074
# 97                                     Concession:Candy, Concession:Soda → Payment:Credit Card  0.186441    0.440000  1.298000
# 345  Payment:Credit Card, Concession:Soda, Ticket:Adult → Concession:Popcorn, Concession:Candy  0.118644    0.437500  0.956019
# 354  Payment:Credit Card, Ticket:Adult → Concession:Popcorn, Concession:Candy, Concession:Soda  0.118644    0.437500  1.229167
# 254                   Payment:Credit Card, Ticket:Adult → Concession:Popcorn, Concession:Candy  0.118644    0.437500  0.956019
# 208                Concession:Popcorn, Concession:Candy, Concession:Soda → Payment:Credit Card  0.152542    0.428571  1.264286
# 296                           Payment:Cash, Concession:Popcorn → Concession:Soda, Ticket:Child  0.101695    0.428571  3.160714
# 330         Payment:Cash, Concession:Popcorn → Concession:Candy, Concession:Soda, Ticket:Child  0.101695    0.428571  3.160714
# 202                       Payment:Cash, Concession:Popcorn → Concession:Candy, Concession:Soda  0.101695    0.428571  1.011429
# 157                                  Concession:Popcorn, Concession:Soda → Payment:Credit Card  0.203390    0.428571  1.264286
# 285                     Payment:Credit Card, Concession:Soda → Ticket:Adult, Concession:Nachos  0.135593    0.421053  2.258373
# 357  Concession:Popcorn, Ticket:Adult → Payment:Credit Card, Concession:Candy, Concession:Soda  0.118644    0.411765  2.208556
# 163                                   Payment:Debit Card → Concession:Popcorn, Concession:Soda  0.118644    0.411765  0.867647
# 255                   Concession:Popcorn, Ticket:Adult → Payment:Credit Card, Concession:Candy  0.118644    0.411765  2.024510
# 277                      Concession:Soda, Ticket:Adult → Payment:Credit Card, Concession:Candy  0.152542    0.409091  2.011364
# 85                                         Concession:Popcorn, Concession:Candy → Ticket:Child  0.186441    0.407407  2.185185
# 290                     Payment:Credit Card → Ticket:Adult, Concession:Soda, Concession:Nachos  0.135593    0.400000  2.360000
# 105                                           Ticket:Adult → Concession:Candy, Concession:Soda  0.203390    0.400000  0.944000
# 84                                         Ticket:Adult → Concession:Popcorn, Concession:Candy  0.203390    0.400000  0.874074
# 223                       Concession:Candy, Concession:Soda → Concession:Popcorn, Ticket:Adult  0.169492    0.400000  1.388235
# 150                                      Payment:Credit Card → Ticket:Adult, Concession:Nachos  0.135593    0.400000  2.145455
# 198                                        Concession:Soda → Payment:Credit Card, Ticket:Adult  0.271186    0.400000  1.475000
# 30                                                           Concession:Popcorn → Payment:Cash  0.237288    0.388889  1.092593
# 167                                         Concession:Popcorn → Ticket:Adult, Concession:Soda  0.237288    0.388889  1.042929
# 7                                                       Concession:Candy → Payment:Credit Card  0.203390    0.387097  1.141935
# 103                                           Concession:Candy → Concession:Soda, Ticket:Adult  0.203390    0.387097  1.038123
# 5                                                              Concession:Candy → Payment:Cash  0.203390    0.387097  1.087558
# 83                                         Concession:Candy → Concession:Popcorn, Ticket:Adult  0.203390    0.387097  1.343454
# 246                          Payment:Cash → Concession:Popcorn, Concession:Candy, Ticket:Child  0.135593    0.380952  2.043290
# 228                       Concession:Popcorn, Concession:Candy, Concession:Soda → Ticket:Child  0.135593    0.380952  2.043290
# 113                                              Payment:Cash → Concession:Candy, Ticket:Child  0.135593    0.380952  2.043290
# 176                                            Payment:Cash → Concession:Popcorn, Ticket:Child  0.135593    0.380952  2.043290
# 154                                         Payment:Cash → Concession:Popcorn, Concession:Soda  0.135593    0.380952  0.802721
# 54                                                                 Payment:Cash → Ticket:Child  0.135593    0.380952  2.043290
# 94                                            Payment:Cash → Concession:Candy, Concession:Soda  0.135593    0.380952  0.899048
# 73                                  Concession:Popcorn, Concession:Candy → Payment:Credit Card  0.169492    0.370370  1.092593
# 68                                         Concession:Popcorn, Concession:Candy → Payment:Cash  0.169492    0.370370  1.040564
# 220                       Concession:Popcorn, Concession:Candy → Concession:Soda, Ticket:Adult  0.169492    0.370370  0.993266
# 352  Payment:Credit Card, Concession:Soda → Concession:Popcorn, Concession:Candy, Ticket:Adult  0.118644    0.368421  1.811404
# 25                                                            Ticket:Adult → Concession:Nachos  0.186441    0.366667  1.442222
# 287                     Ticket:Adult, Concession:Soda → Payment:Credit Card, Concession:Nachos  0.135593    0.363636  2.383838
# 32                                                    Concession:Popcorn → Payment:Credit Card  0.220339    0.361111  1.065278
# 214                Concession:Candy, Concession:Soda → Payment:Credit Card, Concession:Popcorn  0.152542    0.360000  1.633846
# 275                      Concession:Candy, Concession:Soda → Payment:Credit Card, Ticket:Adult  0.152542    0.360000  1.327500
# 310                    Concession:Popcorn, Concession:Soda → Payment:Credit Card, Ticket:Adult  0.169492    0.357143  1.316964
# 221                       Concession:Popcorn, Concession:Soda → Concession:Candy, Ticket:Adult  0.169492    0.357143  1.505102
# 11                                                             Concession:Candy → Ticket:Child  0.186441    0.354839  1.903226
# 89                                         Concession:Candy → Concession:Popcorn, Ticket:Child  0.186441    0.354839  1.903226
# 99                                     Concession:Candy → Payment:Credit Card, Concession:Soda  0.186441    0.354839  1.101868
# 8                                                        Payment:Debit Card → Concession:Candy  0.101695    0.352941  0.671727
# 188                                  Payment:Debit Card → Concession:Pretzel, Concession:Water  0.101695    0.352941  2.974790
# 78                                   Payment:Debit Card → Concession:Popcorn, Concession:Candy  0.101695    0.352941  0.771242
# 42                                                     Payment:Debit Card → Concession:Pretzel  0.101695    0.352941  2.602941
# 169                                         Concession:Soda → Concession:Popcorn, Ticket:Adult  0.237288    0.350000  1.214706
# 358  Payment:Credit Card → Concession:Popcorn, Concession:Candy, Concession:Soda, Ticket:Adult  0.118644    0.350000  2.065000
# 257                   Payment:Credit Card → Concession:Popcorn, Concession:Candy, Ticket:Adult  0.118644    0.350000  1.720833
# 212                Concession:Popcorn, Concession:Candy → Payment:Credit Card, Concession:Soda  0.152542    0.333333  1.035088
# 347  Concession:Popcorn, Concession:Candy, Concession:Soda → Payment:Credit Card, Ticket:Adult  0.118644    0.333333  1.229167
# 313                    Ticket:Adult → Payment:Credit Card, Concession:Popcorn, Concession:Soda  0.169492    0.333333  1.638889
# 82                                         Concession:Popcorn → Concession:Candy, Ticket:Adult  0.203390    0.333333  1.404762
# 159                                  Concession:Popcorn → Payment:Credit Card, Concession:Soda  0.203390    0.333333  1.035088
# 227                       Ticket:Adult → Concession:Popcorn, Concession:Candy, Concession:Soda  0.169492    0.333333  0.936508
# 182                                     Ticket:Adult → Payment:Credit Card, Concession:Popcorn  0.169492    0.333333  1.512821
# 145                                          Ticket:Adult → Concession:Soda, Concession:Nachos  0.169492    0.333333  1.512821
# 21                                                         Concession:Soda → Concession:Nachos  0.220339    0.325000  1.278333
# 226                       Concession:Candy → Concession:Popcorn, Concession:Soda, Ticket:Adult  0.169492    0.322581  1.359447
# 75                                  Concession:Candy → Payment:Credit Card, Concession:Popcorn  0.169492    0.322581  1.464020
# 70                                         Concession:Candy → Payment:Cash, Concession:Popcorn  0.169492    0.322581  1.359447
# 213                Concession:Popcorn, Concession:Soda → Payment:Credit Card, Concession:Candy  0.152542    0.321429  1.580357
# 106                                           Concession:Candy, Concession:Soda → Ticket:Child  0.135593    0.320000  1.716364
# 93                                            Concession:Candy, Concession:Soda → Payment:Cash  0.135593    0.320000  0.899048
# 233                       Concession:Candy, Concession:Soda → Concession:Popcorn, Ticket:Child  0.135593    0.320000  1.716364
# 133                                         Ticket:Adult, Concession:Soda → Concession:Hot Dog  0.118644    0.318182  1.444056
# 356  Concession:Soda, Ticket:Adult → Payment:Credit Card, Concession:Popcorn, Concession:Candy  0.118644    0.318182  1.877273
# 128                                  Payment:Credit Card, Concession:Soda → Concession:Hot Dog  0.101695    0.315789  1.433198
# 36                                                           Concession:Popcorn → Ticket:Child  0.186441    0.305556  1.638889
# 88                                         Concession:Popcorn → Concession:Candy, Ticket:Child  0.186441    0.305556  1.638889
# 104                                           Concession:Soda → Concession:Candy, Ticket:Adult  0.203390    0.300000  1.264286
# 18                                                    Payment:Credit Card → Concession:Hot Dog  0.101695    0.300000  1.361538
# 160                                  Concession:Soda → Payment:Credit Card, Concession:Popcorn  0.203390    0.300000  1.361538
# 279                      Ticket:Adult → Payment:Credit Card, Concession:Candy, Concession:Soda  0.152542    0.300000  1.609091
# 119                                       Ticket:Adult → Payment:Credit Card, Concession:Candy  0.152542    0.300000  1.475000
# 16                                                        Concession:Soda → Concession:Hot Dog  0.203390    0.300000  1.361538
# 131                                  Payment:Credit Card → Concession:Soda, Concession:Hot Dog  0.101695    0.300000  1.475000

# %%
# Display all rules sorted by SUPPORT
if len(rules) > 0:
    print("ALL ASSOCIATION RULES - SORTED BY SUPPORT:")
    print("="*100)
    print("Support shows how frequently the combination appears")
    print("Higher support = more common pattern\n")
    rules_by_supp = rules.sort_values('support', ascending=False)
    print(rules_by_supp[['rule', 'support', 'confidence', 'lift']].to_string())
# Out:
# ALL ASSOCIATION RULES - SORTED BY SUPPORT:
# ====================================================================================================
# Support shows how frequently the combination appears
# Higher support = more common pattern
#
#                                                                                           rule   support  confidence      lift
# 28                                                        Concession:Soda → Concession:Popcorn  0.474576    0.700000  1.147222
# 27                                                        Concession:Popcorn → Concession:Soda  0.474576    0.777778  1.147222
# 1                                                        Concession:Candy → Concession:Popcorn  0.457627    0.870968  1.427419
# 0                                                        Concession:Popcorn → Concession:Candy  0.457627    0.750000  1.427419
# 3                                                           Concession:Soda → Concession:Candy  0.423729    0.625000  1.189516
# 2                                                           Concession:Candy → Concession:Soda  0.423729    0.806452  1.189516
# 47                                                              Ticket:Adult → Concession:Soda  0.372881    0.733333  1.081667
# 48                                                              Concession:Soda → Ticket:Adult  0.372881    0.550000  1.081667
# 64                                      Concession:Candy → Concession:Popcorn, Concession:Soda  0.355932    0.677419  1.427419
# 60                                      Concession:Popcorn, Concession:Candy → Concession:Soda  0.355932    0.777778  1.147222
# 62                                      Concession:Candy, Concession:Soda → Concession:Popcorn  0.355932    0.840000  1.376667
# 61                                      Concession:Popcorn, Concession:Soda → Concession:Candy  0.355932    0.750000  1.427419
# 65                                      Concession:Soda → Concession:Popcorn, Concession:Candy  0.355932    0.525000  1.147222
# 63                                      Concession:Popcorn → Concession:Candy, Concession:Soda  0.355932    0.583333  1.376667
# 45                                                       Concession:Soda → Payment:Credit Card  0.322034    0.475000  1.401250
# 44                                                       Payment:Credit Card → Concession:Soda  0.322034    0.950000  1.401250
# 35                                                           Ticket:Adult → Concession:Popcorn  0.288136    0.566667  0.928704
# 34                                                           Concession:Popcorn → Ticket:Adult  0.288136    0.472222  0.928704
# 197                                        Ticket:Adult → Payment:Credit Card, Concession:Soda  0.271186    0.533333  1.656140
# 193                                        Payment:Credit Card, Ticket:Adult → Concession:Soda  0.271186    1.000000  1.475000
# 196                                        Payment:Credit Card → Ticket:Adult, Concession:Soda  0.271186    0.800000  2.145455
# 198                                        Concession:Soda → Payment:Credit Card, Ticket:Adult  0.271186    0.400000  1.475000
# 58                                                          Ticket:Adult → Payment:Credit Card  0.271186    0.533333  1.573333
# 195                                        Ticket:Adult, Concession:Soda → Payment:Credit Card  0.271186    0.727273  2.145455
# 194                                        Payment:Credit Card, Concession:Soda → Ticket:Adult  0.271186    0.842105  1.656140
# 57                                                          Payment:Credit Card → Ticket:Adult  0.271186    0.800000  1.573333
# 169                                         Concession:Soda → Concession:Popcorn, Ticket:Adult  0.237288    0.350000  1.214706
# 167                                         Concession:Popcorn → Ticket:Adult, Concession:Soda  0.237288    0.388889  1.042929
# 10                                                             Ticket:Adult → Concession:Candy  0.237288    0.466667  0.888172
# 9                                                              Concession:Candy → Ticket:Adult  0.237288    0.451613  0.888172
# 164                                         Concession:Popcorn, Ticket:Adult → Concession:Soda  0.237288    0.823529  1.214706
# 166                                         Ticket:Adult, Concession:Soda → Concession:Popcorn  0.237288    0.636364  1.042929
# 165                                         Concession:Popcorn, Concession:Soda → Ticket:Adult  0.237288    0.500000  0.983333
# 30                                                           Concession:Popcorn → Payment:Cash  0.237288    0.388889  1.092593
# 29                                                           Payment:Cash → Concession:Popcorn  0.237288    0.666667  1.092593
# 168                                         Ticket:Adult → Concession:Popcorn, Concession:Soda  0.237288    0.466667  0.983333
# 32                                                    Concession:Popcorn → Payment:Credit Card  0.220339    0.361111  1.065278
# 21                                                         Concession:Soda → Concession:Nachos  0.220339    0.325000  1.278333
# 22                                                         Concession:Nachos → Concession:Soda  0.220339    0.866667  1.278333
# 31                                                    Payment:Credit Card → Concession:Popcorn  0.220339    0.650000  1.065278
# 17                                                        Concession:Hot Dog → Concession:Soda  0.203390    0.923077  1.361538
# 16                                                        Concession:Soda → Concession:Hot Dog  0.203390    0.300000  1.361538
# 84                                         Ticket:Adult → Concession:Popcorn, Concession:Candy  0.203390    0.400000  0.874074
# 5                                                              Concession:Candy → Payment:Cash  0.203390    0.387097  1.087558
# 83                                         Concession:Candy → Concession:Popcorn, Ticket:Adult  0.203390    0.387097  1.343454
# 82                                         Concession:Popcorn → Concession:Candy, Ticket:Adult  0.203390    0.333333  1.404762
# 81                                         Concession:Candy, Ticket:Adult → Concession:Popcorn  0.203390    0.857143  1.404762
# 6                                                       Payment:Credit Card → Concession:Candy  0.203390    0.600000  1.141935
# 80                                         Concession:Popcorn, Ticket:Adult → Concession:Candy  0.203390    0.705882  1.343454
# 79                                         Concession:Popcorn, Concession:Candy → Ticket:Adult  0.203390    0.444444  0.874074
# 7                                                       Concession:Candy → Payment:Credit Card  0.203390    0.387097  1.141935
# 160                                  Concession:Soda → Payment:Credit Card, Concession:Popcorn  0.203390    0.300000  1.361538
# 100                                           Concession:Candy, Concession:Soda → Ticket:Adult  0.203390    0.480000  0.944000
# 101                                           Concession:Candy, Ticket:Adult → Concession:Soda  0.203390    0.857143  1.264286
# 155                                  Payment:Credit Card, Concession:Popcorn → Concession:Soda  0.203390    0.923077  1.361538
# 156                                  Payment:Credit Card, Concession:Soda → Concession:Popcorn  0.203390    0.631579  1.035088
# 157                                  Concession:Popcorn, Concession:Soda → Payment:Credit Card  0.203390    0.428571  1.264286
# 158                                  Payment:Credit Card → Concession:Popcorn, Concession:Soda  0.203390    0.600000  1.264286
# 159                                  Concession:Popcorn → Payment:Credit Card, Concession:Soda  0.203390    0.333333  1.035088
# 105                                           Ticket:Adult → Concession:Candy, Concession:Soda  0.203390    0.400000  0.944000
# 104                                           Concession:Soda → Concession:Candy, Ticket:Adult  0.203390    0.300000  1.264286
# 103                                           Concession:Candy → Concession:Soda, Ticket:Adult  0.203390    0.387097  1.038123
# 102                                           Concession:Soda, Ticket:Adult → Concession:Candy  0.203390    0.545455  1.038123
# 4                                                              Payment:Cash → Concession:Candy  0.203390    0.571429  1.087558
# 96                                     Payment:Credit Card, Concession:Soda → Concession:Candy  0.186441    0.578947  1.101868
# 99                                     Concession:Candy → Payment:Credit Card, Concession:Soda  0.186441    0.354839  1.101868
# 85                                         Concession:Popcorn, Concession:Candy → Ticket:Child  0.186441    0.407407  2.185185
# 86                                         Concession:Popcorn, Ticket:Child → Concession:Candy  0.186441    1.000000  1.903226
# 98                                     Payment:Credit Card → Concession:Candy, Concession:Soda  0.186441    0.550000  1.298000
# 97                                     Concession:Candy, Concession:Soda → Payment:Credit Card  0.186441    0.440000  1.298000
# 87                                         Concession:Candy, Ticket:Child → Concession:Popcorn  0.186441    1.000000  1.638889
# 88                                         Concession:Popcorn → Concession:Candy, Ticket:Child  0.186441    0.305556  1.638889
# 89                                         Concession:Candy → Concession:Popcorn, Ticket:Child  0.186441    0.354839  1.903226
# 90                                         Ticket:Child → Concession:Popcorn, Concession:Candy  0.186441    1.000000  2.185185
# 95                                     Payment:Credit Card, Concession:Candy → Concession:Soda  0.186441    0.916667  1.352083
# 26                                                            Concession:Nachos → Ticket:Adult  0.186441    0.733333  1.442222
# 43                                                              Payment:Cash → Concession:Soda  0.186441    0.523810  0.772619
# 25                                                            Ticket:Adult → Concession:Nachos  0.186441    0.366667  1.442222
# 11                                                             Concession:Candy → Ticket:Child  0.186441    0.354839  1.903226
# 12                                                             Ticket:Child → Concession:Candy  0.186441    1.000000  1.903226
# 36                                                           Concession:Popcorn → Ticket:Child  0.186441    0.305556  1.638889
# 37                                                           Ticket:Child → Concession:Popcorn  0.186441    1.000000  1.638889
# 178                                     Payment:Credit Card, Concession:Popcorn → Ticket:Adult  0.169492    0.769231  1.512821
# 303                    Payment:Credit Card, Concession:Popcorn, Concession:Soda → Ticket:Adult  0.169492    0.833333  1.638889
# 307                    Payment:Credit Card, Ticket:Adult → Concession:Popcorn, Concession:Soda  0.169492    0.625000  1.316964
# 225                       Concession:Soda, Ticket:Adult → Concession:Popcorn, Concession:Candy  0.169492    0.454545  0.993266
# 226                       Concession:Candy → Concession:Popcorn, Concession:Soda, Ticket:Adult  0.169492    0.322581  1.359447
# 227                       Ticket:Adult → Concession:Popcorn, Concession:Candy, Concession:Soda  0.169492    0.333333  0.936508
# 302                    Payment:Credit Card, Concession:Popcorn, Ticket:Adult → Concession:Soda  0.169492    1.000000  1.475000
# 306                    Payment:Credit Card, Concession:Popcorn → Ticket:Adult, Concession:Soda  0.169492    0.769231  2.062937
# 308                    Payment:Credit Card, Concession:Soda → Concession:Popcorn, Ticket:Adult  0.169492    0.526316  1.826625
# 304                    Payment:Credit Card, Ticket:Adult, Concession:Soda → Concession:Popcorn  0.169492    0.625000  1.024306
# 305                    Concession:Popcorn, Ticket:Adult, Concession:Soda → Payment:Credit Card  0.169492    0.714286  2.107143
# 146                                          Concession:Nachos → Ticket:Adult, Concession:Soda  0.169492    0.666667  1.787879
# 145                                          Ticket:Adult → Concession:Soda, Concession:Nachos  0.169492    0.333333  1.512821
# 144                                          Concession:Soda, Concession:Nachos → Ticket:Adult  0.169492    0.769231  1.512821
# 224                       Concession:Candy, Ticket:Adult → Concession:Popcorn, Concession:Soda  0.169492    0.714286  1.505102
# 223                       Concession:Candy, Concession:Soda → Concession:Popcorn, Ticket:Adult  0.169492    0.400000  1.388235
# 309                    Concession:Popcorn, Ticket:Adult → Payment:Credit Card, Concession:Soda  0.169492    0.588235  1.826625
# 142                                          Ticket:Adult, Concession:Soda → Concession:Nachos  0.169492    0.454545  1.787879
# 181                                     Payment:Credit Card → Concession:Popcorn, Ticket:Adult  0.169492    0.500000  1.735294
# 182                                     Ticket:Adult → Payment:Credit Card, Concession:Popcorn  0.169492    0.333333  1.512821
# 313                    Ticket:Adult → Payment:Credit Card, Concession:Popcorn, Concession:Soda  0.169492    0.333333  1.638889
# 312                    Payment:Credit Card → Concession:Popcorn, Ticket:Adult, Concession:Soda  0.169492    0.500000  2.107143
# 311                    Ticket:Adult, Concession:Soda → Payment:Credit Card, Concession:Popcorn  0.169492    0.454545  2.062937
# 310                    Concession:Popcorn, Concession:Soda → Payment:Credit Card, Ticket:Adult  0.169492    0.357143  1.316964
# 216                       Concession:Popcorn, Concession:Candy, Concession:Soda → Ticket:Adult  0.169492    0.476190  0.936508
# 180                                     Concession:Popcorn, Ticket:Adult → Payment:Credit Card  0.169492    0.588235  1.735294
# 217                       Concession:Popcorn, Concession:Candy, Ticket:Adult → Concession:Soda  0.169492    0.833333  1.229167
# 218                       Concession:Popcorn, Concession:Soda, Ticket:Adult → Concession:Candy  0.169492    0.714286  1.359447
# 219                       Concession:Candy, Concession:Soda, Ticket:Adult → Concession:Popcorn  0.169492    0.833333  1.365741
# 220                       Concession:Popcorn, Concession:Candy → Concession:Soda, Ticket:Adult  0.169492    0.370370  0.993266
# 221                       Concession:Popcorn, Concession:Soda → Concession:Candy, Ticket:Adult  0.169492    0.357143  1.505102
# 222                       Concession:Popcorn, Ticket:Adult → Concession:Candy, Concession:Soda  0.169492    0.588235  1.388235
# 143                                          Ticket:Adult, Concession:Nachos → Concession:Soda  0.169492    0.909091  1.340909
# 179                                     Payment:Credit Card, Ticket:Adult → Concession:Popcorn  0.169492    0.625000  1.024306
# 70                                         Concession:Candy → Payment:Cash, Concession:Popcorn  0.169492    0.322581  1.359447
# 68                                         Concession:Popcorn, Concession:Candy → Payment:Cash  0.169492    0.370370  1.040564
# 73                                  Concession:Popcorn, Concession:Candy → Payment:Credit Card  0.169492    0.370370  1.092593
# 74                                  Payment:Credit Card → Concession:Popcorn, Concession:Candy  0.169492    0.500000  1.092593
# 75                                  Concession:Candy → Payment:Credit Card, Concession:Popcorn  0.169492    0.322581  1.464020
# 72                                  Payment:Credit Card, Concession:Candy → Concession:Popcorn  0.169492    0.833333  1.365741
# 69                                         Payment:Cash → Concession:Popcorn, Concession:Candy  0.169492    0.476190  1.040564
# 71                                  Payment:Credit Card, Concession:Popcorn → Concession:Candy  0.169492    0.769231  1.464020
# 67                                         Payment:Cash, Concession:Candy → Concession:Popcorn  0.169492    0.833333  1.365741
# 66                                         Payment:Cash, Concession:Popcorn → Concession:Candy  0.169492    0.714286  1.359447
# 269                      Payment:Credit Card, Concession:Candy, Ticket:Adult → Concession:Soda  0.152542    1.000000  1.475000
# 268                      Payment:Credit Card, Concession:Candy, Concession:Soda → Ticket:Adult  0.152542    0.818182  1.609091
# 205                Payment:Credit Card, Concession:Popcorn, Concession:Candy → Concession:Soda  0.152542    0.900000  1.327500
# 117                                       Concession:Candy, Ticket:Adult → Payment:Credit Card  0.152542    0.642857  1.896429
# 46                                                        Payment:Debit Card → Concession:Soda  0.152542    0.529412  0.780882
# 270                      Payment:Credit Card, Concession:Soda, Ticket:Adult → Concession:Candy  0.152542    0.562500  1.070565
# 271                      Concession:Candy, Concession:Soda, Ticket:Adult → Payment:Credit Card  0.152542    0.750000  2.212500
# 272                      Payment:Credit Card, Concession:Candy → Concession:Soda, Ticket:Adult  0.152542    0.750000  2.011364
# 116                                       Payment:Credit Card, Ticket:Adult → Concession:Candy  0.152542    0.562500  1.070565
# 52                                                       Payment:Debit Card → Concession:Water  0.152542    0.529412  2.602941
# 51                                                       Concession:Water → Payment:Debit Card  0.152542    0.750000  2.602941
# 274                      Payment:Credit Card, Ticket:Adult → Concession:Candy, Concession:Soda  0.152542    0.562500  1.327500
# 215                Payment:Credit Card → Concession:Popcorn, Concession:Candy, Concession:Soda  0.152542    0.450000  1.264286
# 214                Concession:Candy, Concession:Soda → Payment:Credit Card, Concession:Popcorn  0.152542    0.360000  1.633846
# 213                Concession:Popcorn, Concession:Soda → Payment:Credit Card, Concession:Candy  0.152542    0.321429  1.580357
# 212                Concession:Popcorn, Concession:Candy → Payment:Credit Card, Concession:Soda  0.152542    0.333333  1.035088
# 211                Payment:Credit Card, Concession:Soda → Concession:Popcorn, Concession:Candy  0.152542    0.473684  1.035088
# 210                Payment:Credit Card, Concession:Candy → Concession:Popcorn, Concession:Soda  0.152542    0.750000  1.580357
# 209                Payment:Credit Card, Concession:Popcorn → Concession:Candy, Concession:Soda  0.152542    0.692308  1.633846
# 208                Concession:Popcorn, Concession:Candy, Concession:Soda → Payment:Credit Card  0.152542    0.428571  1.264286
# 207                Payment:Credit Card, Concession:Candy, Concession:Soda → Concession:Popcorn  0.152542    0.818182  1.340909
# 273                      Payment:Credit Card, Concession:Soda → Concession:Candy, Ticket:Adult  0.152542    0.473684  1.996241
# 206                Payment:Credit Card, Concession:Popcorn, Concession:Soda → Concession:Candy  0.152542    0.750000  1.427419
# 275                      Concession:Candy, Concession:Soda → Payment:Credit Card, Ticket:Adult  0.152542    0.360000  1.327500
# 141                                   Concession:Nachos → Payment:Credit Card, Concession:Soda  0.152542    0.600000  1.863158
# 138                                   Payment:Credit Card, Concession:Nachos → Concession:Soda  0.152542    1.000000  1.475000
# 139                                   Concession:Soda, Concession:Nachos → Payment:Credit Card  0.152542    0.692308  2.042308
# 276                      Concession:Candy, Ticket:Adult → Payment:Credit Card, Concession:Soda  0.152542    0.642857  1.996241
# 140                                   Payment:Credit Card → Concession:Soda, Concession:Nachos  0.152542    0.450000  2.042308
# 24                                                     Concession:Nachos → Payment:Credit Card  0.152542    0.600000  1.770000
# 23                                                     Payment:Credit Card → Concession:Nachos  0.152542    0.450000  1.770000
# 137                                   Payment:Credit Card, Concession:Soda → Concession:Nachos  0.152542    0.473684  1.863158
# 277                      Concession:Soda, Ticket:Adult → Payment:Credit Card, Concession:Candy  0.152542    0.409091  2.011364
# 119                                       Ticket:Adult → Payment:Credit Card, Concession:Candy  0.152542    0.300000  1.475000
# 115                                       Payment:Credit Card, Concession:Candy → Ticket:Adult  0.152542    0.750000  1.475000
# 278                      Payment:Credit Card → Concession:Candy, Concession:Soda, Ticket:Adult  0.152542    0.450000  2.212500
# 279                      Ticket:Adult → Payment:Credit Card, Concession:Candy, Concession:Soda  0.152542    0.300000  1.609091
# 118                                       Payment:Credit Card → Concession:Candy, Ticket:Adult  0.152542    0.450000  1.896429
# 14                                                      Concession:Nachos → Concession:Hot Dog  0.135593    0.533333  2.420513
# 55                                                                 Ticket:Child → Payment:Cash  0.135593    0.727273  2.043290
# 283                     Ticket:Adult, Concession:Soda, Concession:Nachos → Payment:Credit Card  0.135593    0.800000  2.360000
# 284                     Payment:Credit Card, Ticket:Adult → Concession:Soda, Concession:Nachos  0.135593    0.500000  2.269231
# 285                     Payment:Credit Card, Concession:Soda → Ticket:Adult, Concession:Nachos  0.135593    0.421053  2.258373
# 54                                                                 Payment:Cash → Ticket:Child  0.135593    0.380952  2.043290
# 287                     Ticket:Adult, Concession:Soda → Payment:Credit Card, Concession:Nachos  0.135593    0.363636  2.383838
# 286                     Payment:Credit Card, Concession:Nachos → Ticket:Adult, Concession:Soda  0.135593    0.888889  2.383838
# 13                                                      Concession:Hot Dog → Concession:Nachos  0.135593    0.615385  2.420513
# 288                     Ticket:Adult, Concession:Nachos → Payment:Credit Card, Concession:Soda  0.135593    0.727273  2.258373
# 289                     Concession:Soda, Concession:Nachos → Payment:Credit Card, Ticket:Adult  0.135593    0.615385  2.269231
# 290                     Payment:Credit Card → Ticket:Adult, Concession:Soda, Concession:Nachos  0.135593    0.400000  2.360000
# 282                     Payment:Credit Card, Concession:Soda, Concession:Nachos → Ticket:Adult  0.135593    0.888889  1.748148
# 33                                                     Payment:Debit Card → Concession:Popcorn  0.135593    0.470588  0.771242
# 20                                                           Concession:Hot Dog → Ticket:Adult  0.135593    0.615385  1.210256
# 291                     Concession:Nachos → Payment:Credit Card, Ticket:Adult, Concession:Soda  0.135593    0.533333  1.966667
# 228                       Concession:Popcorn, Concession:Candy, Concession:Soda → Ticket:Child  0.135593    0.380952  2.043290
# 281                     Payment:Credit Card, Ticket:Adult, Concession:Nachos → Concession:Soda  0.135593    1.000000  1.475000
# 239                          Payment:Cash, Concession:Candy, Ticket:Child → Concession:Popcorn  0.135593    1.000000  1.638889
# 280                     Payment:Credit Card, Ticket:Adult, Concession:Soda → Concession:Nachos  0.135593    0.500000  1.966667
# 247                          Ticket:Child → Payment:Cash, Concession:Popcorn, Concession:Candy  0.135593    0.727273  4.290909
# 246                          Payment:Cash → Concession:Popcorn, Concession:Candy, Ticket:Child  0.135593    0.380952  2.043290
# 245                          Concession:Candy, Ticket:Child → Payment:Cash, Concession:Popcorn  0.135593    0.727273  3.064935
# 243                          Payment:Cash, Ticket:Child → Concession:Popcorn, Concession:Candy  0.135593    1.000000  2.185185
# 242                          Payment:Cash, Concession:Candy → Concession:Popcorn, Ticket:Child  0.135593    0.666667  3.575758
# 241                          Payment:Cash, Concession:Popcorn → Concession:Candy, Ticket:Child  0.135593    0.571429  3.064935
# 240                          Concession:Popcorn, Concession:Candy, Ticket:Child → Payment:Cash  0.135593    0.727273  2.043290
# 238                          Payment:Cash, Concession:Popcorn, Ticket:Child → Concession:Candy  0.135593    1.000000  1.903226
# 49                                                              Ticket:Child → Concession:Soda  0.135593    0.727273  1.072727
# 236                       Ticket:Child → Concession:Popcorn, Concession:Candy, Concession:Soda  0.135593    0.727273  2.043290
# 235                       Concession:Soda, Ticket:Child → Concession:Popcorn, Concession:Candy  0.135593    1.000000  2.185185
# 234                       Concession:Candy, Ticket:Child → Concession:Popcorn, Concession:Soda  0.135593    0.727273  1.532468
# 233                       Concession:Candy, Concession:Soda → Concession:Popcorn, Ticket:Child  0.135593    0.320000  1.716364
# 232                       Concession:Popcorn, Ticket:Child → Concession:Candy, Concession:Soda  0.135593    0.727273  1.716364
# 231                       Concession:Candy, Concession:Soda, Ticket:Child → Concession:Popcorn  0.135593    1.000000  1.638889
# 230                       Concession:Popcorn, Concession:Soda, Ticket:Child → Concession:Candy  0.135593    1.000000  1.903226
# 229                       Concession:Popcorn, Concession:Candy, Ticket:Child → Concession:Soda  0.135593    0.727273  1.072727
# 244                          Concession:Popcorn, Ticket:Child → Payment:Cash, Concession:Candy  0.135593    0.727273  3.575758
# 237                          Payment:Cash, Concession:Popcorn, Concession:Candy → Ticket:Child  0.135593    0.800000  4.290909
# 110                                              Payment:Cash, Concession:Candy → Ticket:Child  0.135593    0.666667  3.575758
# 170                                         Concession:Popcorn, Ticket:Child → Concession:Soda  0.135593    0.727273  1.072727
# 176                                            Payment:Cash → Concession:Popcorn, Ticket:Child  0.135593    0.380952  2.043290
# 175                                            Concession:Popcorn, Ticket:Child → Payment:Cash  0.135593    0.727273  2.043290
# 174                                            Payment:Cash, Ticket:Child → Concession:Popcorn  0.135593    1.000000  1.638889
# 173                                            Payment:Cash, Concession:Popcorn → Ticket:Child  0.135593    0.571429  3.064935
# 172                                         Ticket:Child → Concession:Popcorn, Concession:Soda  0.135593    0.727273  1.532468
# 171                                         Concession:Soda, Ticket:Child → Concession:Popcorn  0.135593    1.000000  1.638889
# 109                                           Ticket:Child → Concession:Candy, Concession:Soda  0.135593    0.727273  1.716364
# 94                                            Payment:Cash → Concession:Candy, Concession:Soda  0.135593    0.380952  0.899048
# 108                                           Concession:Soda, Ticket:Child → Concession:Candy  0.135593    1.000000  1.903226
# 154                                         Payment:Cash → Concession:Popcorn, Concession:Soda  0.135593    0.380952  0.802721
# 91                                            Payment:Cash, Concession:Candy → Concession:Soda  0.135593    0.666667  0.983333
# 92                                            Payment:Cash, Concession:Soda → Concession:Candy  0.135593    0.727273  1.384164
# 93                                            Concession:Candy, Concession:Soda → Payment:Cash  0.135593    0.320000  0.899048
# 107                                           Concession:Candy, Ticket:Child → Concession:Soda  0.135593    0.727273  1.072727
# 177                                            Ticket:Child → Payment:Cash, Concession:Popcorn  0.135593    0.727273  3.064935
# 106                                           Concession:Candy, Concession:Soda → Ticket:Child  0.135593    0.320000  1.716364
# 112                                              Concession:Candy, Ticket:Child → Payment:Cash  0.135593    0.727273  2.043290
# 147                                      Payment:Credit Card, Ticket:Adult → Concession:Nachos  0.135593    0.500000  1.966667
# 153                                         Payment:Cash, Concession:Soda → Concession:Popcorn  0.135593    0.727273  1.191919
# 152                                         Payment:Cash, Concession:Popcorn → Concession:Soda  0.135593    0.571429  0.842857
# 151                                      Concession:Nachos → Payment:Credit Card, Ticket:Adult  0.135593    0.533333  1.966667
# 150                                      Payment:Credit Card → Ticket:Adult, Concession:Nachos  0.135593    0.400000  2.145455
# 59                                                           Payment:Debit Card → Ticket:Adult  0.135593    0.470588  0.925490
# 149                                      Ticket:Adult, Concession:Nachos → Payment:Credit Card  0.135593    0.727273  2.145455
# 114                                              Ticket:Child → Payment:Cash, Concession:Candy  0.135593    0.727273  3.575758
# 113                                              Payment:Cash → Concession:Candy, Ticket:Child  0.135593    0.380952  2.043290
# 148                                      Payment:Credit Card, Concession:Nachos → Ticket:Adult  0.135593    0.888889  1.748148
# 111                                              Payment:Cash, Ticket:Child → Concession:Candy  0.135593    1.000000  1.903226
# 126                                   Concession:Soda, Concession:Hot Dog → Concession:Popcorn  0.118644    0.583333  0.956019
# 127                                   Concession:Hot Dog → Concession:Popcorn, Concession:Soda  0.118644    0.538462  1.134615
# 135                                         Concession:Soda, Concession:Hot Dog → Ticket:Adult  0.118644    0.583333  1.147222
# 123                                    Concession:Hot Dog → Concession:Soda, Concession:Nachos  0.118644    0.538462  2.443787
# 124                                    Concession:Nachos → Concession:Soda, Concession:Hot Dog  0.118644    0.466667  2.294444
# 125                                   Concession:Popcorn, Concession:Hot Dog → Concession:Soda  0.118644    1.000000  1.475000
# 134                                         Ticket:Adult, Concession:Hot Dog → Concession:Soda  0.118644    0.875000  1.290625
# 133                                         Ticket:Adult, Concession:Soda → Concession:Hot Dog  0.118644    0.318182  1.444056
# 39                                                       Concession:Pretzel → Concession:Water  0.118644    0.875000  4.302083
# 136                                         Concession:Hot Dog → Ticket:Adult, Concession:Soda  0.118644    0.538462  1.444056
# 122                                    Concession:Hot Dog, Concession:Nachos → Concession:Soda  0.118644    0.875000  1.290625
# 15                                                     Concession:Hot Dog → Concession:Popcorn  0.118644    0.538462  0.882479
# 357  Concession:Popcorn, Ticket:Adult → Payment:Credit Card, Concession:Candy, Concession:Soda  0.118644    0.411765  2.208556
# 356  Concession:Soda, Ticket:Adult → Payment:Credit Card, Concession:Popcorn, Concession:Candy  0.118644    0.318182  1.877273
# 355  Concession:Candy, Ticket:Adult → Payment:Credit Card, Concession:Popcorn, Concession:Soda  0.118644    0.500000  2.458333
# 354  Payment:Credit Card, Ticket:Adult → Concession:Popcorn, Concession:Candy, Concession:Soda  0.118644    0.437500  1.229167
# 353  Payment:Credit Card, Concession:Popcorn → Concession:Candy, Concession:Soda, Ticket:Adult  0.118644    0.538462  2.647436
# 352  Payment:Credit Card, Concession:Soda → Concession:Popcorn, Concession:Candy, Ticket:Adult  0.118644    0.368421  1.811404
# 351  Payment:Credit Card, Concession:Candy → Concession:Popcorn, Concession:Soda, Ticket:Adult  0.118644    0.583333  2.458333
# 350  Concession:Popcorn, Concession:Soda, Ticket:Adult → Payment:Credit Card, Concession:Candy  0.118644    0.500000  2.458333
# 349  Concession:Popcorn, Concession:Candy, Ticket:Adult → Payment:Credit Card, Concession:Soda  0.118644    0.583333  1.811404
# 348  Concession:Candy, Concession:Soda, Ticket:Adult → Payment:Credit Card, Concession:Popcorn  0.118644    0.583333  2.647436
# 347  Concession:Popcorn, Concession:Candy, Concession:Soda → Payment:Credit Card, Ticket:Adult  0.118644    0.333333  1.229167
# 346  Payment:Credit Card, Concession:Popcorn, Ticket:Adult → Concession:Candy, Concession:Soda  0.118644    0.700000  1.652000
# 345  Payment:Credit Card, Concession:Soda, Ticket:Adult → Concession:Popcorn, Concession:Candy  0.118644    0.437500  0.956019
# 344  Payment:Credit Card, Concession:Popcorn, Concession:Soda → Concession:Candy, Ticket:Adult  0.118644    0.583333  2.458333
# 343  Payment:Credit Card, Concession:Candy, Ticket:Adult → Concession:Popcorn, Concession:Soda  0.118644    0.777778  1.638889
# 342  Payment:Credit Card, Concession:Popcorn, Concession:Candy → Concession:Soda, Ticket:Adult  0.118644    0.700000  1.877273
# 341  Payment:Credit Card, Concession:Candy, Concession:Soda → Concession:Popcorn, Ticket:Adult  0.118644    0.636364  2.208556
# 340  Concession:Popcorn, Concession:Candy, Concession:Soda, Ticket:Adult → Payment:Credit Card  0.118644    0.700000  2.065000
# 339  Payment:Credit Card, Concession:Popcorn, Concession:Soda, Ticket:Adult → Concession:Candy  0.118644    0.700000  1.332258
# 338  Payment:Credit Card, Concession:Popcorn, Concession:Candy, Ticket:Adult → Concession:Soda  0.118644    1.000000  1.475000
# 337  Payment:Credit Card, Concession:Candy, Concession:Soda, Ticket:Adult → Concession:Popcorn  0.118644    0.777778  1.274691
# 336  Payment:Credit Card, Concession:Popcorn, Concession:Candy, Concession:Soda → Ticket:Adult  0.118644    0.777778  1.529630
# 121                                    Concession:Soda, Concession:Nachos → Concession:Hot Dog  0.118644    0.538462  2.443787
# 120                                    Concession:Soda, Concession:Hot Dog → Concession:Nachos  0.118644    0.583333  2.294444
# 358  Payment:Credit Card → Concession:Popcorn, Concession:Candy, Concession:Soda, Ticket:Adult  0.118644    0.350000  2.065000
# 254                   Payment:Credit Card, Ticket:Adult → Concession:Popcorn, Concession:Candy  0.118644    0.437500  0.956019
# 253                   Payment:Credit Card, Concession:Candy → Concession:Popcorn, Ticket:Adult  0.118644    0.583333  2.024510
# 162                                   Payment:Debit Card, Concession:Soda → Concession:Popcorn  0.118644    0.777778  1.274691
# 248                   Payment:Credit Card, Concession:Popcorn, Concession:Candy → Ticket:Adult  0.118644    0.700000  1.376667
# 255                   Concession:Popcorn, Ticket:Adult → Payment:Credit Card, Concession:Candy  0.118644    0.411765  2.024510
# 256                   Concession:Candy, Ticket:Adult → Payment:Credit Card, Concession:Popcorn  0.118644    0.500000  2.269231
# 163                                   Payment:Debit Card → Concession:Popcorn, Concession:Soda  0.118644    0.411765  0.867647
# 257                   Payment:Credit Card → Concession:Popcorn, Concession:Candy, Ticket:Adult  0.118644    0.350000  1.720833
# 252                   Payment:Credit Card, Concession:Popcorn → Concession:Candy, Ticket:Adult  0.118644    0.538462  2.269231
# 249                   Payment:Credit Card, Concession:Popcorn, Ticket:Adult → Concession:Candy  0.118644    0.700000  1.332258
# 250                   Payment:Credit Card, Concession:Candy, Ticket:Adult → Concession:Popcorn  0.118644    0.777778  1.274691
# 251                   Concession:Popcorn, Concession:Candy, Ticket:Adult → Payment:Credit Card  0.118644    0.583333  1.720833
# 40                                                       Concession:Water → Concession:Pretzel  0.118644    0.583333  4.302083
# 161                                   Concession:Popcorn, Payment:Debit Card → Concession:Soda  0.118644    0.875000  1.290625
# 332         Concession:Candy, Ticket:Child → Payment:Cash, Concession:Popcorn, Concession:Soda  0.101695    0.545455  4.022727
# 333         Concession:Soda, Ticket:Child → Payment:Cash, Concession:Popcorn, Concession:Candy  0.101695    0.750000  4.425000
# 334         Concession:Popcorn, Ticket:Child → Payment:Cash, Concession:Candy, Concession:Soda  0.101695    0.545455  4.022727
# 267                             Ticket:Child → Payment:Cash, Concession:Candy, Concession:Soda  0.101695    0.545455  4.022727
# 331         Payment:Cash, Ticket:Child → Concession:Popcorn, Concession:Candy, Concession:Soda  0.101695    0.750000  2.107143
# 77                                   Payment:Debit Card, Concession:Candy → Concession:Popcorn  0.101695    1.000000  1.638889
# 330         Payment:Cash, Concession:Popcorn → Concession:Candy, Concession:Soda, Ticket:Child  0.101695    0.428571  3.160714
# 329         Payment:Cash, Concession:Soda → Concession:Popcorn, Concession:Candy, Ticket:Child  0.101695    0.545455  2.925620
# 328         Payment:Cash, Concession:Candy → Concession:Popcorn, Concession:Soda, Ticket:Child  0.101695    0.500000  3.687500
# 327         Concession:Popcorn, Concession:Soda, Ticket:Child → Payment:Cash, Concession:Candy  0.101695    0.750000  3.687500
# 326         Concession:Popcorn, Concession:Candy, Ticket:Child → Payment:Cash, Concession:Soda  0.101695    0.545455  2.925620
# 325         Concession:Candy, Concession:Soda, Ticket:Child → Payment:Cash, Concession:Popcorn  0.101695    0.750000  3.160714
# 324         Payment:Cash, Concession:Popcorn, Ticket:Child → Concession:Candy, Concession:Soda  0.101695    0.750000  1.770000
# 323         Payment:Cash, Concession:Soda, Ticket:Child → Concession:Popcorn, Concession:Candy  0.101695    1.000000  2.185185
# 335         Ticket:Child → Payment:Cash, Concession:Popcorn, Concession:Candy, Concession:Soda  0.101695    0.545455  5.363636
# 42                                                     Payment:Debit Card → Concession:Pretzel  0.101695    0.352941  2.602941
# 76                                   Concession:Popcorn, Payment:Debit Card → Concession:Candy  0.101695    0.750000  1.427419
# 188                                  Payment:Debit Card → Concession:Pretzel, Concession:Water  0.101695    0.352941  2.974790
# 202                       Payment:Cash, Concession:Popcorn → Concession:Candy, Concession:Soda  0.101695    0.428571  1.011429
# 201                       Payment:Cash, Concession:Candy, Concession:Soda → Concession:Popcorn  0.101695    0.750000  1.229167
# 200                       Payment:Cash, Concession:Popcorn, Concession:Soda → Concession:Candy  0.101695    0.750000  1.427419
# 199                       Payment:Cash, Concession:Popcorn, Concession:Candy → Concession:Soda  0.101695    0.600000  0.885000
# 192                                               Ticket:Child → Payment:Cash, Concession:Soda  0.101695    0.545455  2.925620
# 191                                               Concession:Soda, Ticket:Child → Payment:Cash  0.101695    0.750000  2.107143
# 190                                               Payment:Cash, Ticket:Child → Concession:Soda  0.101695    0.750000  1.106250
# 189                                               Payment:Cash, Concession:Soda → Ticket:Child  0.101695    0.545455  2.925620
# 187                                  Concession:Water → Concession:Pretzel, Payment:Debit Card  0.101695    0.500000  4.916667
# 41                                                     Concession:Pretzel → Payment:Debit Card  0.101695    0.750000  2.602941
# 56                                                                Ticket:Senior → Payment:Cash  0.101695    0.666667  1.873016
# 186                                  Concession:Pretzel → Concession:Water, Payment:Debit Card  0.101695    0.750000  4.916667
# 185                                  Concession:Water, Payment:Debit Card → Concession:Pretzel  0.101695    0.666667  4.916667
# 53                                                             Concession:Water → Ticket:Adult  0.101695    0.500000  0.983333
# 184                                  Concession:Pretzel, Payment:Debit Card → Concession:Water  0.101695    1.000000  4.916667
# 183                                  Concession:Pretzel, Concession:Water → Payment:Debit Card  0.101695    0.857143  2.974790
# 50                                                            Ticket:Student → Concession:Soda  0.101695    0.666667  0.983333
# 321         Payment:Cash, Concession:Candy, Ticket:Child → Concession:Popcorn, Concession:Soda  0.101695    0.750000  1.580357
# 322         Payment:Cash, Concession:Popcorn, Concession:Soda → Concession:Candy, Ticket:Child  0.101695    0.750000  4.022727
# 314         Payment:Cash, Concession:Popcorn, Concession:Candy, Concession:Soda → Ticket:Child  0.101695    1.000000  5.363636
# 320         Payment:Cash, Concession:Popcorn, Concession:Candy → Concession:Soda, Ticket:Child  0.101695    0.600000  4.425000
# 294                           Payment:Cash, Concession:Soda, Ticket:Child → Concession:Popcorn  0.101695    1.000000  1.638889
# 292                           Payment:Cash, Concession:Popcorn, Concession:Soda → Ticket:Child  0.101695    0.750000  4.022727
# 128                                  Payment:Credit Card, Concession:Soda → Concession:Hot Dog  0.101695    0.315789  1.433198
# 129                                  Payment:Credit Card, Concession:Hot Dog → Concession:Soda  0.101695    1.000000  1.475000
# 130                                  Concession:Soda, Concession:Hot Dog → Payment:Credit Card  0.101695    0.500000  1.475000
# 131                                  Payment:Credit Card → Concession:Soda, Concession:Hot Dog  0.101695    0.300000  1.475000
# 132                                  Concession:Hot Dog → Payment:Credit Card, Concession:Soda  0.101695    0.461538  1.433198
# 204                       Payment:Cash, Concession:Soda → Concession:Popcorn, Concession:Candy  0.101695    0.545455  1.191919
# 258                             Payment:Cash, Concession:Candy, Concession:Soda → Ticket:Child  0.101695    0.750000  4.022727
# 259                             Payment:Cash, Concession:Candy, Ticket:Child → Concession:Soda  0.101695    0.750000  1.106250
# 260                             Payment:Cash, Concession:Soda, Ticket:Child → Concession:Candy  0.101695    1.000000  1.903226
# 261                             Concession:Candy, Concession:Soda, Ticket:Child → Payment:Cash  0.101695    0.750000  2.107143
# 262                             Payment:Cash, Concession:Candy → Concession:Soda, Ticket:Child  0.101695    0.500000  3.687500
# 263                             Payment:Cash, Concession:Soda → Concession:Candy, Ticket:Child  0.101695    0.545455  2.925620
# 264                             Payment:Cash, Ticket:Child → Concession:Candy, Concession:Soda  0.101695    0.750000  1.770000
# 265                             Concession:Candy, Ticket:Child → Payment:Cash, Concession:Soda  0.101695    0.545455  2.925620
# 293                           Payment:Cash, Concession:Popcorn, Ticket:Child → Concession:Soda  0.101695    0.750000  1.106250
# 295                           Concession:Popcorn, Concession:Soda, Ticket:Child → Payment:Cash  0.101695    0.750000  2.107143
# 319         Payment:Cash, Concession:Candy, Concession:Soda → Concession:Popcorn, Ticket:Child  0.101695    0.750000  4.022727
# 296                           Payment:Cash, Concession:Popcorn → Concession:Soda, Ticket:Child  0.101695    0.428571  3.160714
# 318         Concession:Popcorn, Concession:Candy, Concession:Soda, Ticket:Child → Payment:Cash  0.101695    0.750000  2.107143
# 317         Payment:Cash, Concession:Popcorn, Concession:Soda, Ticket:Child → Concession:Candy  0.101695    1.000000  1.903226
# 316         Payment:Cash, Concession:Popcorn, Concession:Candy, Ticket:Child → Concession:Soda  0.101695    0.750000  1.106250
# 315         Payment:Cash, Concession:Candy, Concession:Soda, Ticket:Child → Concession:Popcorn  0.101695    1.000000  1.638889
# 266                             Concession:Soda, Ticket:Child → Payment:Cash, Concession:Candy  0.101695    0.750000  3.687500
# 8                                                        Payment:Debit Card → Concession:Candy  0.101695    0.352941  0.671727
# 78                                   Payment:Debit Card → Concession:Popcorn, Concession:Candy  0.101695    0.352941  0.771242
# 18                                                    Payment:Credit Card → Concession:Hot Dog  0.101695    0.300000  1.361538
# 19                                                    Concession:Hot Dog → Payment:Credit Card  0.101695    0.461538  1.361538
# 38                                                         Ticket:Student → Concession:Popcorn  0.101695    0.666667  1.092593
# 301                           Ticket:Child → Payment:Cash, Concession:Popcorn, Concession:Soda  0.101695    0.545455  4.022727
# 300                           Concession:Soda, Ticket:Child → Payment:Cash, Concession:Popcorn  0.101695    0.750000  3.160714
# 299                           Concession:Popcorn, Ticket:Child → Payment:Cash, Concession:Soda  0.101695    0.545455  2.925620
# 298                           Payment:Cash, Ticket:Child → Concession:Popcorn, Concession:Soda  0.101695    0.750000  1.580357
# 297                           Payment:Cash, Concession:Soda → Concession:Popcorn, Ticket:Child  0.101695    0.545455  2.925620
# 203                       Payment:Cash, Concession:Candy → Concession:Popcorn, Concession:Soda  0.101695    0.500000  1.053571

# %%
# Detailed interpretation of top rules
if len(rules) > 0:
    print("DETAILED RULE INTERPRETATION (Top 10 by Lift):")
    print("="*100)
    
    for i, (idx, row) in enumerate(rules_by_lift.head(10).iterrows(), 1):
        print(f"\n{'='*100}")
        print(f"RULE #{i}: {row['rule']}")
        print(f"{'='*100}")
        print(f"Support:    {row['support']:.3f} ({row['support']*100:.1f}% of transactions)")
        print(f"Confidence: {row['confidence']:.3f} ({row['confidence']*100:.1f}%)")
        print(f"Lift:       {row['lift']:.3f}")
        print(f"\nInterpretation:")
        print(f"  • When customers buy {row['antecedents_str']},")
        print(f"    {row['confidence']*100:.1f}% of them also buy {row['consequents_str']}")
        print(f"  • This is {row['lift']:.2f}x more likely than buying {row['consequents_str']} alone")
        if row['lift'] > 1.5:
            print(f"  • STRONG positive correlation - excellent cross-selling opportunity!")
        elif row['lift'] > 1.2:
            print(f"  • MODERATE positive correlation - good cross-selling potential")
        else:
            print(f"  • WEAK positive correlation")
# Out:
# DETAILED RULE INTERPRETATION (Top 10 by Lift):
# ====================================================================================================
#
# ====================================================================================================
# RULE #1: Ticket:Child → Payment:Cash, Concession:Popcorn, Concession:Candy, Concession:Soda
# ====================================================================================================
# Support:    0.102 (10.2% of transactions)
# Confidence: 0.545 (54.5%)
# Lift:       5.364
#
# Interpretation:
#   • When customers buy Ticket:Child,
#     54.5% of them also buy Payment:Cash, Concession:Popcorn, Concession:Candy, Concession:Soda
#   • This is 5.36x more likely than buying Payment:Cash, Concession:Popcorn, Concession:Candy, Concession:Soda alone
#   • STRONG positive correlation - excellent cross-selling opportunity!
#
# ====================================================================================================
# RULE #2: Payment:Cash, Concession:Popcorn, Concession:Candy, Concession:Soda → Ticket:Child
# ====================================================================================================
# Support:    0.102 (10.2% of transactions)
# Confidence: 1.000 (100.0%)
# Lift:       5.364
#
# Interpretation:
#   • When customers buy Payment:Cash, Concession:Popcorn, Concession:Candy, Concession:Soda,
#     100.0% of them also buy Ticket:Child
#   • This is 5.36x more likely than buying Ticket:Child alone
#   • STRONG positive correlation - excellent cross-selling opportunity!
#
# ====================================================================================================
# RULE #3: Concession:Pretzel → Concession:Water, Payment:Debit Card
# ====================================================================================================
# Support:    0.102 (10.2% of transactions)
# Confidence: 0.750 (75.0%)
# Lift:       4.917
#
# Interpretation:
#   • When customers buy Concession:Pretzel,
#     75.0% of them also buy Concession:Water, Payment:Debit Card
#   • This is 4.92x more likely than buying Concession:Water, Payment:Debit Card alone
#   • STRONG positive correlation - excellent cross-selling opportunity!
#
# ====================================================================================================
# RULE #4: Concession:Water → Concession:Pretzel, Payment:Debit Card
# ====================================================================================================
# Support:    0.102 (10.2% of transactions)
# Confidence: 0.500 (50.0%)
# Lift:       4.917
#
# Interpretation:
#   • When customers buy Concession:Water,
#     50.0% of them also buy Concession:Pretzel, Payment:Debit Card
#   • This is 4.92x more likely than buying Concession:Pretzel, Payment:Debit Card alone
#   • STRONG positive correlation - excellent cross-selling opportunity!
#
# ====================================================================================================
# RULE #5: Concession:Pretzel, Payment:Debit Card → Concession:Water
# ====================================================================================================
# Support:    0.102 (10.2% of transactions)
# Confidence: 1.000 (100.0%)
# Lift:       4.917
#
# Interpretation:
#   • When customers buy Concession:Pretzel, Payment:Debit Card,
#     100.0% of them also buy Concession:Water
#   • This is 4.92x more likely than buying Concession:Water alone
#   • STRONG positive correlation - excellent cross-selling opportunity!
#
# ====================================================================================================
# RULE #6: Concession:Water, Payment:Debit Card → Concession:Pretzel
# ====================================================================================================
# Support:    0.102 (10.2% of transactions)
# Confidence: 0.667 (66.7%)
# Lift:       4.917
#
# Interpretation:
#   • When customers buy Concession:Water, Payment:Debit Card,
#     66.7% of them also buy Concession:Pretzel
#   • This is 4.92x more likely than buying Concession:Pretzel alone
#   • STRONG positive correlation - excellent cross-selling opportunity!
#
# ====================================================================================================
# RULE #7: Payment:Cash, Concession:Popcorn, Concession:Candy → Concession:Soda, Ticket:Child
# ====================================================================================================
# Support:    0.102 (10.2% of transactions)
# Confidence: 0.600 (60.0%)
# Lift:       4.425
#
# Interpretation:
#   • When customers buy Payment:Cash, Concession:Popcorn, Concession:Candy,
#     60.0% of them also buy Concession:Soda, Ticket:Child
#   • This is 4.43x more likely than buying Concession:Soda, Ticket:Child alone
#   • STRONG positive correlation - excellent cross-selling opportunity!
#
# ====================================================================================================
# RULE #8: Concession:Soda, Ticket:Child → Payment:Cash, Concession:Popcorn, Concession:Candy
# ====================================================================================================
# Support:    0.102 (10.2% of transactions)
# Confidence: 0.750 (75.0%)
# Lift:       4.425
#
# Interpretation:
#   • When customers buy Concession:Soda, Ticket:Child,
#     75.0% of them also buy Payment:Cash, Concession:Popcorn, Concession:Candy
#   • This is 4.42x more likely than buying Payment:Cash, Concession:Popcorn, Concession:Candy alone
#   • STRONG positive correlation - excellent cross-selling opportunity!
#
# ====================================================================================================
# RULE #9: Concession:Water → Concession:Pretzel
# ====================================================================================================
# Support:    0.119 (11.9% of transactions)
# Confidence: 0.583 (58.3%)
# Lift:       4.302
#
# Interpretation:
#   • When customers buy Concession:Water,
#     58.3% of them also buy Concession:Pretzel
#   • This is 4.30x more likely than buying Concession:Pretzel alone
#   • STRONG positive correlation - excellent cross-selling opportunity!
#
# ====================================================================================================
# RULE #10: Concession:Pretzel → Concession:Water
# ====================================================================================================
# Support:    0.119 (11.9% of transactions)
# Confidence: 0.875 (87.5%)
# Lift:       4.302
#
# Interpretation:
#   • When customers buy Concession:Pretzel,
#     87.5% of them also buy Concession:Water
#   • This is 4.30x more likely than buying Concession:Water alone
#   • STRONG positive correlation - excellent cross-selling opportunity!

# %%
# Save rules to CSV
if len(rules) > 0:
    rules_output = 'association_rules.csv'
    rules[['rule', 'antecedents_str', 'consequents_str', 'support', 'confidence', 'lift']].to_csv(rules_output, index=False)
    print(f"\n✓ Association rules saved to: {rules_output}")
# Out:
# ✓ Association rules saved to: association_rules.csv

# %% [markdown]
# ---
# ## STEP 12: Business Insights and Recommendations
#
# **Explanation:** Now we translate the statistical findings into actionable business strategies.

# %%
if len(rules) > 0:
    print("BUSINESS INSIGHTS AND RECOMMENDATIONS:")
    print("="*100)
    
    # Focus on concession-related rules
    concession_rules = rules[
        rules['antecedents_str'].str.contains('Concession') & 
        rules['consequents_str'].str.contains('Concession')
    ].sort_values('lift', ascending=False)
    
    if len(concession_rules) > 0:
        print("\nKEY CONCESSION ITEM COMBINATIONS:")
        print("-" * 100)
        for i, (idx, row) in enumerate(concession_rules.head(5).iterrows(), 1):
            print(f"\n{i}. {row['rule']}")
            print(f"   Confidence: {row['confidence']*100:.1f}% | Lift: {row['lift']:.2f}x | Support: {row['support']*100:.1f}%")
    
    print("\n" + "="*100)
    print("ACTIONABLE RECOMMENDATIONS:")
    print("="*100)
    
    print("\n1. BUNDLE PROMOTIONS:")
    print("   • Create combo deals based on high-confidence rules")
    print("   • Example: 'Popcorn + Soda Combo' at 10% discount")
    print("   • Focus on items with lift > 1.5 for strongest effect")
    
    print("\n2. CROSS-SELLING STRATEGY:")
    print("   • Train concession staff to suggest items based on purchase")
    print("   • Example: 'Would you like Candy with your Popcorn?'")
    print("   • Use high-confidence rules (>70%) for suggestions")
    
    print("\n3. PRODUCT PLACEMENT:")
    print("   • Place frequently co-purchased items near each other")
    print("   • Example: Display Soda coolers next to Popcorn station")
    print("   • Create visual prompts for complementary items")
    
    print("\n4. INVENTORY MANAGEMENT:")
    print("   • Ensure adequate stock of items with high support")
    print("   • Monitor stock levels of commonly paired items")
    print("   • Predict demand based on association patterns")
    
    print("\n5. PERSONALIZED MARKETING:")
    print("   • Send targeted promotions based on past purchases")
    print("   • Example: Email Soda discount to frequent Popcorn buyers")
    print("   • Use customer transaction history for recommendations")
    
    print("\n6. MENU DESIGN:")
    print("   • Group related items together on menu boards")
    print("   • Highlight popular combinations")
    print("   • Use visual cues to suggest pairings")

print("\n" + "="*100)
print("ANALYSIS COMPLETE!")
print("="*100)
print("\nGenerated Files:")
print("1. cleaned_transactions.csv - Cleaned and preprocessed data")
print("2. association_rules.csv - All discovered association rules")
# Out:
# BUSINESS INSIGHTS AND RECOMMENDATIONS:
# ====================================================================================================
#
# KEY CONCESSION ITEM COMBINATIONS:
# ----------------------------------------------------------------------------------------------------
#
# 1. Concession:Pretzel → Concession:Water, Payment:Debit Card
#    Confidence: 75.0% | Lift: 4.92x | Support: 10.2%
#
# 2. Concession:Pretzel, Payment:Debit Card → Concession:Water
#    Confidence: 100.0% | Lift: 4.92x | Support: 10.2%
#
# 3. Concession:Water, Payment:Debit Card → Concession:Pretzel
#    Confidence: 66.7% | Lift: 4.92x | Support: 10.2%
#
# 4. Concession:Water → Concession:Pretzel, Payment:Debit Card
#    Confidence: 50.0% | Lift: 4.92x | Support: 10.2%
#
# 5. Payment:Cash, Concession:Popcorn, Concession:Candy → Concession:Soda, Ticket:Child
#    Confidence: 60.0% | Lift: 4.43x | Support: 10.2%
#
# ====================================================================================================
# ACTIONABLE RECOMMENDATIONS:
# ====================================================================================================
#
# 1. BUNDLE PROMOTIONS:
#    • Create combo deals based on high-confidence rules
#    • Example: 'Popcorn + Soda Combo' at 10% discount
#    • Focus on items with lift > 1.5 for strongest effect
#
# 2. CROSS-SELLING STRATEGY:
#    • Train concession staff to suggest items based on purchase
#    • Example: 'Would you like Candy with your Popcorn?'
#    • Use high-confidence rules (>70%) for suggestions
#
# 3. PRODUCT PLACEMENT:
#    • Place frequently co-purchased items near each other
#    • Example: Display Soda coolers next to Popcorn station
#    • Create visual prompts for complementary items
#
# 4. INVENTORY MANAGEMENT:
#    • Ensure adequate stock of items with high support
#    • Monitor stock levels of commonly paired items
#    • Predict demand based on association patterns
#
# 5. PERSONALIZED MARKETING:
#    • Send targeted promotions based on past purchases
#    • Example: Email Soda discount to frequent Popcorn buyers
#    • Use customer transaction history for recommendations
#
# 6. MENU DESIGN:
#    • Group related items together on menu boards
#    • Highlight popular combinations
#    • Use visual cues to suggest pairings
#
# ====================================================================================================
# ANALYSIS COMPLETE!
# ====================================================================================================
#
# Generated Files:
# 1. cleaned_transactions.csv - Cleaned and preprocessed data
# 2. association_rules.csv - All discovered association rules
